# %% [markdown]
# # Step 0: setting the colab environment

# %% [markdown]
# Upload the [Logic-and-Language-Final-Project](https://github.com/madeofstardust/Logic-and-Language-Final-Project) folder to your google drive. Give google colab the access to your google drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Path should be the location of your Logic-and-Language-Final-Project folder.

# %%
import os
path="/content/drive/MyDrive/Logic-and-Language-Final-Project-main"
os.chdir(path)

# %% [markdown]
# # Step 1: preparing the data structure.

# %% [markdown]
# ## Loading the data
# The example we use in this project come from this repository: https://github.com/kovvalsky/LangPro
# They have been saved to a txt file after slight modification (replacing "\" with "\_"), which makes it easier to load them into python.

# %% [markdown]
# The "examples" list contains separate examples from the prolog file ""

# %%
examples = []
with open("SICK_trial_ccg.txt", "r") as f:
    lines = [line for line in f]
    curr_example = ""
    for line in lines:
        if line == '\n':
            examples.append(curr_example)
            curr_example = ""
        else:
            curr_example += line

# %% [markdown]
# ## Building the tree structure

# %%
from TreeNode import TreeNode
from build_tree_utils import get_line_dict, build_the_tree

# %% [markdown]
# The function "reload tree" creates trees from the list of examples; it can also be done for debugging purposes, as it creates a pure tree, without any parameters sepcified (only parents and children relationships are created)
# Parameter "n" specifies the number of examples that are being loaded.

# %%
# input: ccg derivation in string format
# output: tree
examples_roots = {}
def reload_tree():
    examples_roots = {}
    for i in range(0, 15):
        line_dict = get_line_dict(examples[i]) # ccg derivation -> lines
        roots, leaf = build_the_tree(line_dict) # lines -> tree
        examples_roots[i] = (examples[i], roots, leaf)
  
    return examples_roots

examples_roots = reload_tree()

# %% [markdown]
# At this point, the representation of each example is saved in examples_roots dictionary:
# * the keys are derivations ids;
# * first value is the prolog derivation in string format
# * the second one - the roots of the derivation, and
# * the third one - the leaf (which should, in the end, represent the final meaning of the derivation.

# %% [markdown]
# # Step 2: Getting First Order Logic Meaning Representation

# %% [markdown]
# We defined lexical semantic in a dictionary, which uses POS tags, types and some exceptions as keys. See the file lexical_semantic_rules.py to see it in details.
# The function "get_compositional_semantics" traverse the tree and sets compositional semantics to each node.

# %%
from lexical_semantic_rules import lexical_semantic_rules 
from get_semantics import get_compositional_semantics, get_lexical_semantics 

from nltk.sem.logic import *
read_expr = Expression.fromstring

# %% [markdown]
# The function "derivation_to_fol" takes id of the derivation as an argument, and return First Order Logic Formula representing the meaning of this derivation

# %%
# input: id of derivation
# output: the FOL representation of the derivation
def derivation_to_FOL(id, and_index = -1):
  line_dict = get_line_dict(examples[id - 1]) # ccg derivation -> lines
  roots, leaf = build_the_tree(line_dict) # lines -> tree
  examples_roots = (examples[id - 1], roots, leaf)

  and_node = -1
  # get lexical semantics for every word
  for i in range(0,len(examples_roots[1])):
    if (examples_roots[1][i].get_word() == 'and'):
      and_node = i
    get_lexical_semantics(examples_roots[1][i])
  
  get_compositional_semantics(examples_roots[2])

  # return FOL
  lr = examples_roots[2].get_lexical_semantics()
  fol = read_expr(f"({lr})(True)").simplify()
  return str(fol)

# %% [markdown]
# # Step 3: Get relations from WordNet and model them as FOL formulas

# %%
import nltk
from nltk.corpus import wordnet as wn
from nltk.corpus.reader.wordnet import Synset
from typing import List
nltk.download('wordnet')
nltk.download('omw-1.4')
import re
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# Define is_a relationship based on hypernym relationships from wordnet:

# %%
def is_a(w1: str, w2: str):
    ''' 
    return true if w1 is more specific than w2
    return false otherwise
    '''
    w1list = wn.synsets(w1)
    w2list = wn.synsets(w2)
    for syn in w1list:
        queue = []
        queue.append(syn)
        seen = set()
        seen.add(syn)
        while len(queue) > 0:
            start = queue.pop(0)
            end = start.hypernyms()
            for e in end:
              if e not in seen:
                  if e in w2list:
                    seen.add(e)
                    return True
              if e not in w2list:
                  queue.append(e)
                  seen.add(e)
    return False

# %%
def are_synonyms(w1: str, w2: str):
    ''' 
    return true if w1 and w2 are synonyms
    return false otherwise
    '''
    synonyms = [] 
    for syn in wn.synsets(w1): 
      for lm in syn.lemmas(): 
        synonyms.append(lm.name()) 
    if w2 in synonyms:
      return True
    else:
      return False

# %%
def are_antonyms(w1: str, w2: str):
    ''' 
    return true if w1 and w2 are synonyms
    return false otherwise
    '''
    for syn in wn.synsets(w1):
      for lm in syn.lemmas():
          if lm.antonyms():
              if w2 == lm.antonyms()[0].name():
                return True
    return False

# %%
knowledge_base = {}
with open("knowledge.txt", "r") as f:
  lines = [line for line in f]
  
for line in lines:
  res = re.findall(r'is_a\((.*?)\)', line)
  if len(res) == 1:
    res = res[0].split(', ')
  if len(res) == 2:
    knowledge_base[res[0]] = res[1]
    knowledge_base[res[1]] = res[0]

print(knowledge_base)
# Out:
# {'lark': 'bird', 'bird': 'lark', 'hound': 'dog', 'dog': 'animal', 'animal': 'dog', 'cat': 'animal', 'student': 'person', 'person': 'cyclist', 'bachelor': 'man', 'man': 'cowboy', 'woman': 'lady', 'human': 'person', 'european': 'person', 'fly': 'hover', 'hover': 'move', 'move': 'run', 'walk': 'move', 'run': 'move', 'obtain': 'receive', 'receive': 'obtain', 'build': 'finish', 'finish': 'build', 'kiss': 'touch', 'touch': 'kiss', 'snore': 'sleep', 'sleep': 'snore', "'girl'": "'young woman'", "'young woman'": "'girl'", "'boy'": "'young man'", "'young man'": "'boy'", "'polish'": "'clean'", "'clean'": "'polish'", "'trek'": "'hike'", "'hike'": "'trek'", "'dash'": "'jump'", "'jump'": "'dive'", "'bounce'": "'jump'", "'dive'": "'jump'", "'run'": "'sprint'", "'sprint'": "'run'", "'look'": "'stare'", "'stare'": "'look'", "'bikini'": "'swimming suite'", "'swimming suite'": "'bikini'", 'climb': 'climb_up', 'climb_up': 'climb', 'play': 'strum', 'practice': 'play', 'note': 'paper', 'paper': 'sheet', 'fit': 'apply', 'apply': 'fit', 'food': 'meal', 'meal': 'food', 'ringer': 'wrestler', 'wrestler': 'ringer', 'pour': 'put', 'put': 'pour', 'vegetable': 'ingredient', 'ingredient': 'vegetable', 'lunge': 'jump', 'jump': 'lunge', 'lady': 'person', 'girl': 'person', 'big': 'huge', 'huge': 'big', 'elder': 'elderly', 'elderly': 'elder', 'fight': 'match', 'match': 'fight', 'hat': 'haeddress', 'haeddress': 'hat', 'group': 'crowd', 'crowd': 'group', "'hole'": "'earth'", "'earth'": "'hole'", 'child': 'kid', 'snowboarder': 'person', 'skateboarder': 'person', 'keyboard': 'piano', 'piano': 'keyboard', 'rider': 'person', 'cliff': 'rock', 'rock': 'cliff', 'kid': 'child', 'wave': 'water', 'water': 'fountain', 'road': 'street', 'street': 'road', 'practitioner': 'trainer', 'trainer': 'practitioner', 'bicycle': 'bike', 'bike': 'bicycle', 'boy': 'person', 'ocean': 'water', 'cowboy': 'man', 'lake': 'water', 'player': 'person', 'grass': 'lawn', 'lawn': 'grass', 'car': 'vehicle', 'vehicle': 'car', 'whisk': 'wire', 'wire': 'whisk', 'fountain': 'water', 'cyclist': 'person', 'sheet': 'paper', 'wood': 'wooded area', 'wooded area': 'wood', 'stage': 'onstage', 'onstage': 'stage', 'strum': 'play', 'burrow': 'dig', 'dig': 'burrow'}

# %% [markdown]
# We only search word relations between the lemmas in the FOL formulas.We use the function below to extract lemmas from FOL formulas.

# %%
# extract words from FOL
def fol_to_word(s):
  # remove numbers
  s = re.sub(r'[0-9]+', '', s)
  # remove 'exists' 'all'
  s = s.replace("exists", "")
  s = s.replace("all", "")
  # "&" to "("
  s = s.replace("&", "(")
  # split "("
  l = s.split("(")
  ll = []
  for i in range(0,len(l)):
    if '.' in l[i]:
      ll.append(l[i])
    elif ')' in l[i]:
      ll.append(l[i])
    elif 'argu' in l[i]:
      ll.append(l[i])
    elif 'True' in l[i]:
      ll.append(l[i])
  s = list(set(l) - set(ll))
  return s

# %%
def get_knowledge(hypothesis: str, premises: List[str]):
  add_premises = []
  add_fol = []
  for premise in premises:
    p_word = premise.split(' ')
    h_word = hypothesis.split(' ')
    same_word = set(p_word).intersection(set(h_word))
    p_word = set(p_word) - same_word
    h_word = set(h_word) - same_word
    # print(p_word,h_word)
    for w1 in p_word:
      for w2 in h_word:
        # check knowledge base and wordnet for is_a relations for w1 and w1
        if is_a(w1, w2) or (w1 in knowledge_base.keys() and knowledge_base[w1] == w2):
          add_premises.append(f'{w1} is a {w2}')
          add_fol.append(f'all x.({w1}(x) -> {w2}(x))')
        # check wordnet for are_synonyms relations for w1 and w1
        if are_synonyms(w1, w2):
          add_premises.append(f'{w1} is equal to {w2}')
          add_fol.append(f'all x.({w1}(x) <-> {w2}(x))')
        # check wordnet for are_antonyms relations for w1 and w1
        if are_antonyms(w1, w2):
          add_premises.append(f'{w1} is not a {w2}')
          add_fol.append(f'all x.({w1}(x) -> -{w2}(x))')
          add_fol.append(f'all x.({w2}(x) -> -{w1}(x))')
  return add_premises, add_fol

# %% [markdown]
# # Step 4: Use Tableau prover to detect inference label

# %% [markdown]
# We decided to use prover9, which needs to be externally downloaded.

# %%
os.chdir("/content")

# %%
# %%bash
# prover9_file_name="p9m4-v05.tar.gz"
# [[ ${prover9_file_name} =~ (.+)\.tar\.gz ]]
# prover9_folder_name=${BASH_REMATCH[1]}
# if [[ ! -d ${prover9_folder_name} ]]; then
#   curl -L "https://www.cs.unm.edu/~mccune/prover9/gui/$prover9_file_name" -o ${prover9_file_name}
#   tar -xvzf ${prover9_file_name}
#   mv ${prover9_folder_name} 'prover9'
#   rm ${prover9_file_name}
# fi

# %%
def prover9_prove(conclusion: str, premises: List[str] = [], path=r"/content/prover9/bin") -> bool:
    """ 
    Give a conclusion and a list of premises, builds a tableau and
    detects whether the premises entail the conclusion.
    Returns a boolean value and optionally prints the tableau structure
    """
    str2exp = nltk.sem.Expression.fromstring
    c = str2exp(conclusion)
    ps = [ str2exp(p) for p in premises ] 
    prover9 = nltk.Prover9()
    if path: prover9.config_prover9(path) 
    return prover9.prove(c, ps)

# %% [markdown]
# ## A short test:

# %%
premise = derivation_to_FOL(15)
hypothesis = derivation_to_FOL(16)

# %%
def get_inference_label(hypothesis: str, premise: List[str]):
  try:
    entailment = prover9_prove('-(' + hypothesis + ')', premise)
    contradiction = prover9_prove(hypothesis, premise)
    # print(f'Contradiction is {contradiction} and entailment is {entailment}')
    if abs(len(premise[0]) - len(hypothesis)) == 1 and '-' in list(set(premise[0]) ^ set(hypothesis)):
      return 'no'
    if entailment and not contradiction:
      return 'no'
    if contradiction and not entailment:
      return 'yes'
    else: 
      return 'unknown'
  except:
    print("Could not find a proof: return \'neutral\'")
    return 'unknown'

# %%
get_inference_label(hypothesis,[premise,"all x.(tree(x) -> plant(x))"])
# Out:
# 'yes'

# %% [markdown]
# # Step 5: evaluation

# %%
import pandas as pd

# %% [markdown]
# ## Trial set

# %% [markdown]
# You can run our model on other datasets(for example, SICK train set) by modifying the value of ccg_path and sen_path. ccg_path is the path of the ccg derivation file, sen_path is the path of the problem file.

# %%
ccg_path = path + "/SICK_trial_ccg.txt"
sen_path = path + "/SICK_trial_sen.txt"

# %%
'''
run on data set. catch the error when running.
input: sick dataset file name + ccg derivation file name
output: data(dataframe) + error
data(dataframe): problem_id(int), p_sen(str), h_sen(str), p_dev(int), h_dev(int), label(str), p_fol(str), h_fol(str), add_p(list of str), add_fol(list of fol), result(str)
'''
data = pd.DataFrame(columns=['problem_id','p_sen','h_sen', 'p_dev', 'h_dev', 'label', 'add_p', 'add_fol', 'p_fol', 'h_fol', 'result'])
data.set_index('problem_id')
error_cnt = {'LogicalExpressionException':0, "UnboundLocalError":0, "OtherError":0}

# ccg_derivation txt file ---> examples
# example[x] ---> the xth derivation in LOLA_SICK_corrected_derivations.txt
examples = []
with open(ccg_path, "r") as f:
    lines = [line for line in f]
    curr_example = ""
    for line in lines:
        if line == '\n':
            examples.append(curr_example)
            curr_example = ""
        else:
            curr_example += line

# %%
with open(sen_path, "r") as file:
  line = [l for l in file]
  for i in range(0,len(line),3):
    # print(line[i])
    problem_id = int(line[i].split('=')[1].strip())
    p_sen = line[i+1].split('(')[1].split(',')[4][2:-4]
    h_sen = line[i+2].split('(')[1].split(',')[4][2:-4]
    p_dev = int(line[i+1].split('(')[1].split(',')[0])
    h_dev = int(line[i+2].split('(')[1].split(',')[0])
    label = line[i+1].split('(')[1].split(',')[3][2:-1]

    # add_p, add_fol = get_knowledge(h_sen, [p_sen])
    try: 
      p_fol = derivation_to_FOL(p_dev)
      h_fol = derivation_to_FOL(h_dev)
    except LogicalExpressionException as e:
      print(f"{problem_id}: can't get a FOL formula based on the given lexical semantics")
      error_cnt["LogicalExpressionException"] += 1
      result = "unknown"
      data.loc[problem_id] = [problem_id,p_sen,h_sen,p_dev,h_dev,label,'', '', '', '',result]
    except UnboundLocalError as e:
      print(f"{problem_id}: missing lexical semantics")
      error_cnt["UnboundLocalError"] += 1
      result = "unknown"
      data.loc[problem_id] = [problem_id,p_sen,h_sen,p_dev,h_dev,label,'', '', '', '',result]
    except:
      print(f"{problem_id}: other problems")
      error_cnt["OtherError"] += 1
      result = "unknown"
      data.loc[problem_id] = [problem_id,p_sen,h_sen,p_dev,h_dev,label,'', '', '', '',result]
    else:
      add_p, add_fol = get_knowledge(' '.join(fol_to_word(h_fol)), [' '.join(fol_to_word(p_fol))])
      if 'patient' in p_fol and 'by' in p_fol:
        add_fol.append('all x all y (patient(x,y) <-> argu2(x,y))')
        add_fol.append('all x all y (by(x,y) <-> argu1(x,y))')
      elif 'patient' in h_fol and 'by' in h_fol:
        add_fol.append('all x all y (patient(x,y) <-> argu2(x,y))')
        add_fol.append('all x all y (by(x,y) <-> argu1(x,y))')
      result = get_inference_label(h_fol,[p_fol] + add_fol)
      data.loc[problem_id] = [problem_id,p_sen,h_sen,p_dev,h_dev,label,add_p,add_fol,p_fol,h_fol,result]
# Out:
# 4: can't get a FOL formula based on the given lexical semantics
# 105: can't get a FOL formula based on the given lexical semantics
# 197: can't get a FOL formula based on the given lexical semantics
# 218: can't get a FOL formula based on the given lexical semantics
# 219: can't get a FOL formula based on the given lexical semantics
# 236: can't get a FOL formula based on the given lexical semantics
# 253: can't get a FOL formula based on the given lexical semantics
# 285: can't get a FOL formula based on the given lexical semantics
# 317: can't get a FOL formula based on the given lexical semantics
# 384: can't get a FOL formula based on the given lexical semantics
# 394: can't get a FOL formula based on the given lexical semantics
# 417: can't get a FOL formula based on the given lexical semantics
# 450: can't get a FOL formula based on the given lexical semantics
# 520: can't get a FOL formula based on the given lexical semantics
# 526: can't get a FOL formula based on the given lexical semantics
# 592: can't get a FOL formula based on the given lexical semantics
# 619: can't get a FOL formula based on the given lexical semantics
# 630: can't get a FOL formula based on the given lexical semantics
# 698: can't get a FOL formula based on the given lexical semantics
# 765: can't get a FOL formula based on the given lexical semantics
# 780: can't get a FOL formula based on the given lexical semantics
# 816: can't get a FOL formula based on the given lexical semantics
# 860: can't get a FOL formula based on the given lexical semantics
# 873: can't get a FOL formula based on the given lexical semantics
# 913: can't get a FOL formula based on the given lexical semantics
# 933: can't get a FOL formula based on the given lexical semantics
# 947: can't get a FOL formula based on the given lexical semantics
# 980: can't get a FOL formula based on the given lexical semantics
# 987: can't get a FOL formula based on the given lexical semantics
# 988: can't get a FOL formula based on the given lexical semantics
# 1102: can't get a FOL formula based on the given lexical semantics
# 1178: can't get a FOL formula based on the given lexical semantics
# 1236: can't get a FOL formula based on the given lexical semantics
# 1237: can't get a FOL formula based on the given lexical semantics
# 1241: can't get a FOL formula based on the given lexical semantics
# 1469: can't get a FOL formula based on the given lexical semantics
# 1470: can't get a FOL formula based on the given lexical semantics
# 1703: can't get a FOL formula based on the given lexical semantics
# 1711: can't get a FOL formula based on the given lexical semantics
# 2058: can't get a FOL formula based on the given lexical semantics
# 2157: can't get a FOL formula based on the given lexical semantics
# 2166: can't get a FOL formula based on the given lexical semantics
# 2221: can't get a FOL formula based on the given lexical semantics
# 2284: can't get a FOL formula based on the given lexical semantics
# 2286: can't get a FOL formula based on the given lexical semantics
# 2404: can't get a FOL formula based on the given lexical semantics
# 2430: can't get a FOL formula based on the given lexical semantics
# 2525: can't get a FOL formula based on the given lexical semantics
# 2527: can't get a FOL formula based on the given lexical semantics
# 2535: can't get a FOL formula based on the given lexical semantics
# 2662: can't get a FOL formula based on the given lexical semantics
# 2668: can't get a FOL formula based on the given lexical semantics
# 2712: can't get a FOL formula based on the given lexical semantics
# 2720: can't get a FOL formula based on the given lexical semantics
# 2722: can't get a FOL formula based on the given lexical semantics
# 2726: can't get a FOL formula based on the given lexical semantics
# 2791: can't get a FOL formula based on the given lexical semantics
# 2795: can't get a FOL formula based on the given lexical semantics
# 2911: can't get a FOL formula based on the given lexical semantics
# 2936: can't get a FOL formula based on the given lexical semantics
# 2996: can't get a FOL formula based on the given lexical semantics
# 3002: can't get a FOL formula based on the given lexical semantics
# 3061: can't get a FOL formula based on the given lexical semantics
# 3107: can't get a FOL formula based on the given lexical semantics
# 3122: can't get a FOL formula based on the given lexical semantics
# 3123: can't get a FOL formula based on the given lexical semantics
# 3174: can't get a FOL formula based on the given lexical semantics
# 3222: can't get a FOL formula based on the given lexical semantics
# 3275: can't get a FOL formula based on the given lexical semantics
# 3291: can't get a FOL formula based on the given lexical semantics
# 3338: can't get a FOL formula based on the given lexical semantics
# 3485: can't get a FOL formula based on the given lexical semantics
# 3505: can't get a FOL formula based on the given lexical semantics
# 3625: can't get a FOL formula based on the given lexical semantics
# 3680: can't get a FOL formula based on the given lexical semantics
# 3855: can't get a FOL formula based on the given lexical semantics
# 3861: can't get a FOL formula based on the given lexical semantics
# 3862: can't get a FOL formula based on the given lexical semantics
# 3880: can't get a FOL formula based on the given lexical semantics
# 3897: can't get a FOL formula based on the given lexical semantics
# 3909: can't get a FOL formula based on the given lexical semantics
# 3910: can't get a FOL formula based on the given lexical semantics
# 3941: can't get a FOL formula based on the given lexical semantics
# 3996: can't get a FOL formula based on the given lexical semantics
# 4006: can't get a FOL formula based on the given lexical semantics
# 4011: can't get a FOL formula based on the given lexical semantics
# 4015: can't get a FOL formula based on the given lexical semantics
# 4031: can't get a FOL formula based on the given lexical semantics
# 4086: can't get a FOL formula based on the given lexical semantics
# 4114: can't get a FOL formula based on the given lexical semantics
# 4140: can't get a FOL formula based on the given lexical semantics
# 4155: can't get a FOL formula based on the given lexical semantics
# 4157: can't get a FOL formula based on the given lexical semantics
# 4187: can't get a FOL formula based on the given lexical semantics
# 4288: can't get a FOL formula based on the given lexical semantics
# 4321: can't get a FOL formula based on the given lexical semantics
# 4330: can't get a FOL formula based on the given lexical semantics
# 4376: can't get a FOL formula based on the given lexical semantics
# 4429: can't get a FOL formula based on the given lexical semantics
# 4520: can't get a FOL formula based on the given lexical semantics
# 4614: can't get a FOL formula based on the given lexical semantics
# 4650: can't get a FOL formula based on the given lexical semantics
# 4755: can't get a FOL formula based on the given lexical semantics
# 4767: can't get a FOL formula based on the given lexical semantics
# 4776: can't get a FOL formula based on the given lexical semantics
# 4803: can't get a FOL formula based on the given lexical semantics
# 4816: can't get a FOL formula based on the given lexical semantics
# 4843: can't get a FOL formula based on the given lexical semantics
# 4891: can't get a FOL formula based on the given lexical semantics
# 4916: can't get a FOL formula based on the given lexical semantics
# 4966: can't get a FOL formula based on the given lexical semantics
# 5003: can't get a FOL formula based on the given lexical semantics
# 5051: can't get a FOL formula based on the given lexical semantics
# 5082: can't get a FOL formula based on the given lexical semantics
# 5310: can't get a FOL formula based on the given lexical semantics
# 5352: can't get a FOL formula based on the given lexical semantics
# 5904: can't get a FOL formula based on the given lexical semantics
# 6001: can't get a FOL formula based on the given lexical semantics
# 6005: can't get a FOL formula based on the given lexical semantics
# 6042: can't get a FOL formula based on the given lexical semantics
# 6047: can't get a FOL formula based on the given lexical semantics
# 6078: can't get a FOL formula based on the given lexical semantics
# 6119: can't get a FOL formula based on the given lexical semantics
# 6131: can't get a FOL formula based on the given lexical semantics
# 6146: can't get a FOL formula based on the given lexical semantics
# 6153: can't get a FOL formula based on the given lexical semantics
# 6158: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# 6219: can't get a FOL formula based on the given lexical semantics
# 6228: can't get a FOL formula based on the given lexical semantics
# 6231: can't get a FOL formula based on the given lexical semantics
# 6330: can't get a FOL formula based on the given lexical semantics
# 6344: can't get a FOL formula based on the given lexical semantics
# 6358: can't get a FOL formula based on the given lexical semantics
# 6450: can't get a FOL formula based on the given lexical semantics
# 6544: can't get a FOL formula based on the given lexical semantics
# 6568: can't get a FOL formula based on the given lexical semantics
# 6598: can't get a FOL formula based on the given lexical semantics
# 6625: can't get a FOL formula based on the given lexical semantics
# 6634: can't get a FOL formula based on the given lexical semantics
# 6673: can't get a FOL formula based on the given lexical semantics
# 6705: can't get a FOL formula based on the given lexical semantics
# 6709: can't get a FOL formula based on the given lexical semantics
# 6729: can't get a FOL formula based on the given lexical semantics
# 6784: can't get a FOL formula based on the given lexical semantics
# 6849: can't get a FOL formula based on the given lexical semantics
# 6866: can't get a FOL formula based on the given lexical semantics
# 6912: can't get a FOL formula based on the given lexical semantics
# 6955: can't get a FOL formula based on the given lexical semantics
# 6971: can't get a FOL formula based on the given lexical semantics
# 7002: can't get a FOL formula based on the given lexical semantics
# 7007: can't get a FOL formula based on the given lexical semantics
# 7018: can't get a FOL formula based on the given lexical semantics
# 7043: can't get a FOL formula based on the given lexical semantics
# 7044: can't get a FOL formula based on the given lexical semantics
# 7093: can't get a FOL formula based on the given lexical semantics
# 7214: can't get a FOL formula based on the given lexical semantics
# 7228: can't get a FOL formula based on the given lexical semantics
# 7311: can't get a FOL formula based on the given lexical semantics
# 7319: can't get a FOL formula based on the given lexical semantics
# 7363: can't get a FOL formula based on the given lexical semantics
# 7394: can't get a FOL formula based on the given lexical semantics
# 7410: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# 7448: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# Could not find a proof: return 'neutral'
# 7501: can't get a FOL formula based on the given lexical semantics
# 7533: can't get a FOL formula based on the given lexical semantics
# 7541: can't get a FOL formula based on the given lexical semantics
# 7582: can't get a FOL formula based on the given lexical semantics
# 7590: can't get a FOL formula based on the given lexical semantics
# 7649: can't get a FOL formula based on the given lexical semantics
# 7718: can't get a FOL formula based on the given lexical semantics
# 7720: can't get a FOL formula based on the given lexical semantics
# 7743: can't get a FOL formula based on the given lexical semantics
# 7820: can't get a FOL formula based on the given lexical semantics
# 7932: can't get a FOL formula based on the given lexical semantics
# 7937: can't get a FOL formula based on the given lexical semantics
# 7938: can't get a FOL formula based on the given lexical semantics
# 7947: can't get a FOL formula based on the given lexical semantics
# 7950: can't get a FOL formula based on the given lexical semantics
# 7951: can't get a FOL formula based on the given lexical semantics
# 8057: can't get a FOL formula based on the given lexical semantics
# 8138: can't get a FOL formula based on the given lexical semantics
# 8141: can't get a FOL formula based on the given lexical semantics
# 8212: can't get a FOL formula based on the given lexical semantics
# 8263: can't get a FOL formula based on the given lexical semantics
# 8313: can't get a FOL formula based on the given lexical semantics
# 8326: can't get a FOL formula based on the given lexical semantics
# 8343: can't get a FOL formula based on the given lexical semantics
# 8362: can't get a FOL formula based on the given lexical semantics
# 8375: can't get a FOL formula based on the given lexical semantics
# 8383: can't get a FOL formula based on the given lexical semantics
# 8471: can't get a FOL formula based on the given lexical semantics
# 8558: can't get a FOL formula based on the given lexical semantics
# 8576: can't get a FOL formula based on the given lexical semantics
# 8632: can't get a FOL formula based on the given lexical semantics
# 8633: can't get a FOL formula based on the given lexical semantics
# 8660: can't get a FOL formula based on the given lexical semantics
# 8678: can't get a FOL formula based on the given lexical semantics
# 8700: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# Could not find a proof: return 'neutral'
# 8855: can't get a FOL formula based on the given lexical semantics
# 9014: can't get a FOL formula based on the given lexical semantics
# 9056: can't get a FOL formula based on the given lexical semantics
# 9069: can't get a FOL formula based on the given lexical semantics
# 9136: can't get a FOL formula based on the given lexical semantics
# 9188: can't get a FOL formula based on the given lexical semantics
# 9198: can't get a FOL formula based on the given lexical semantics
# 9200: can't get a FOL formula based on the given lexical semantics
# 9224: can't get a FOL formula based on the given lexical semantics
# 9242: can't get a FOL formula based on the given lexical semantics
# 9287: can't get a FOL formula based on the given lexical semantics
# 9314: can't get a FOL formula based on the given lexical semantics
# 9336: can't get a FOL formula based on the given lexical semantics
# 9401: can't get a FOL formula based on the given lexical semantics
# 9424: can't get a FOL formula based on the given lexical semantics
# 9425: can't get a FOL formula based on the given lexical semantics
# 9433: can't get a FOL formula based on the given lexical semantics
# 9545: can't get a FOL formula based on the given lexical semantics
# 9571: can't get a FOL formula based on the given lexical semantics
# 9623: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# 9677: can't get a FOL formula based on the given lexical semantics
# 9706: can't get a FOL formula based on the given lexical semantics
# 9713: can't get a FOL formula based on the given lexical semantics
# 9722: can't get a FOL formula based on the given lexical semantics
# 9745: can't get a FOL formula based on the given lexical semantics
# 9747: can't get a FOL formula based on the given lexical semantics
# 9759: can't get a FOL formula based on the given lexical semantics
# 9771: can't get a FOL formula based on the given lexical semantics
# 9788: can't get a FOL formula based on the given lexical semantics
# 9789: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# result analysis
# accuracy(total)
print("correct problems: ",len(data[data['label'] == data['result']]))
print("total problems: ",len(data))
print("total accuracy: ",len(data[data['label'] == data['result']])/len(data))
print("\n")
# accuracy(translated problems)
translate_data = data[data['p_fol'] != '']
print("correct problems: ",len(translate_data[translate_data['label'] == translate_data['result']]))
print("translated problems: ",len(translate_data))
print("accuracy(translated problems): ",len(translate_data[translate_data['label'] == translate_data['result']])/len(translate_data))
print("\n")
# label distribution
print("the distribution of gold labels:")
print(data['label'].value_counts(normalize = True))
print("\nthe distribution of labels we get:")
print(data['result'].value_counts(normalize = True))
# confusion matrix
print("\nconfusion matrix")
print("contradiction neutral entailment")
print(confusion_matrix(data['label'], data['result']))
print("\n")
# precision
print("precise: ")
print(precision_score(data['label'], data['result'], average=None))
print("\n")
# recall
print("recall: ")
print(recall_score(data['label'], data['result'], average=None))
# Out:
# correct problems:  341
# total problems:  500
# total accuracy:  0.682
#
#
# correct problems:  214
# translated problems:  272
# accuracy(translated problems):  0.7867647058823529
#
#
# the distribution of gold labels:
# unknown    0.564
# yes        0.288
# no         0.148
# Name: label, dtype: float64
#
# the distribution of labels we get:
# unknown    0.864
# yes        0.108
# no         0.028
# Name: result, dtype: float64
#
# confusion matrix
# contradiction neutral entailment
# [[ 10  64   0]
#  [  3 278   1]
#  [  1  90  53]]
#
#
# precise:
# [0.71428571 0.64351852 0.98148148]
#
#
# recall:
# [0.13513514 0.9858156  0.36805556]

# %%
# problems we labeled wrong
wrong_data = data[data['label'] != data['result']]

print("wrong problems: \n")
for i in range(0,len(wrong_data)):
    print(wrong_data.iloc[i]['problem_id'], "label: ", wrong_data.iloc[i]['label'], "   result: ", wrong_data.iloc[i]['result'])
    print("premise: ", wrong_data.iloc[i]['p_sen'])
    print("add_premise: ", wrong_data.iloc[i]['add_fol'])
    print("hypothesis: ", wrong_data.iloc[i]['h_sen'])
    print("\n")
# Out:
# wrong problems:
#
# 4 label:  no    result:  unknown
# premise:  The young boys are playing outdoors and the man is smiling nearby
# add_premise:
# hypothesis:  There is no boy playing outdoors and there is no man smiling
#
#
# 218 label:  yes    result:  unknown
# premise:  A girl in white is dancing
# add_premise:
# hypothesis:  A girl is wearing white clothes and is dancing
#
#
# 219 label:  no    result:  unknown
# premise:  There is no girl in white dancing
# add_premise:
# hypothesis:  A girl in white is dancing
#
#
# 253 label:  yes    result:  unknown
# premise:  A hiker is on top of the mountain and is doing a joyful dance
# add_premise:
# hypothesis:  A hiker is on top of the mountain and is dancing
#
#
# 384 label:  yes    result:  unknown
# premise:  A white and tan dog is running through the tall and green grass
# add_premise:
# hypothesis:  A white and tan dog is running through a field
#
#
# 592 label:  no    result:  unknown
# premise:  A woman is taking off a cl
# add_premise:
# hypothesis:  A woman is putting on a cl
#
#
# 630 label:  no    result:  unknown
# premise:  A man is not tossing a kid into the swimming pool that is near the ocean
# add_premise:
# hypothesis:  The man is tossing a kid into the swimming pool that is near the ocean
#
#
# 717 label:  no    result:  unknown
# premise:  A few men in a competition are running outside
# add_premise:  ['all x.(outside(x) -> -indoor(x))', 'all x.(indoor(x) -> -outside(x))']
# hypothesis:  A few men in a competition are running indoors
#
#
# 816 label:  yes    result:  unknown
# premise:  A group of people is equipped with protective gear
# add_premise:
# hypothesis:  A group of people is equipped with gear used for protection
#
#
# 860 label:  yes    result:  unknown
# premise:  One white dog and one black one are running side by side on the grass
# add_premise:
# hypothesis:  A
#
#
# 913 label:  no    result:  unknown
# premise:  A woman is being kissed by a man
# add_premise:
# hypothesis:  There is no woman being kissed by a man
#
#
# 947 label:  yes    result:  unknown
# premise:  Some corndogs are being eaten by two toddlers who are in a wa
# add_premise:
# hypothesis:  Two toddlers are eating corndogs in a wa
#
#
# 987 label:  no    result:  unknown
# premise:  An adult is in the amphitheater and is talking to a boy
# add_premise:
# hypothesis:  There is no adult in the amphitheater talking to a boy
#
#
# 1178 label:  no    result:  unknown
# premise:  A woman is combing her hair
# add_premise:
# hypothesis:  There is no woman combing her hair
#
#
# 1190 label:  yes    result:  unknown
# premise:  A man and a woman are hiking through a wooded area
# add_premise:  ['all x.(hike(x) -> walk(x))']
# hypothesis:  A man and a woman are walking together through the woods
#
#
# 1192 label:  yes    result:  unknown
# premise:  A man and a woman are walking together through the woods
# add_premise:  []
# hypothesis:  A man and a woman are walking through a wooded area
#
#
# 1236 label:  no    result:  unknown
# premise:  A woman is dancing and singing alone
# add_premise:
# hypothesis:  A woman is dancing and singing with other women
#
#
# 1266 label:  yes    result:  unknown
# premise:  A band is playing on a stage
# add_premise:  ['all x.(stage(x) -> onstage(x))']
# hypothesis:  A band is playing onstage
#
#
# 1333 label:  yes    result:  no
# premise:  The woman is measuring the other woman
# add_premise:  ['all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  A woman is being measured by another woman
#
#
# 1400 label:  unknown    result:  yes
# premise:  A sad man is crying
# add_premise:  ['all x.(cry(x) <-> scream(x))']
# hypothesis:  A man is screaming
#
#
# 1469 label:  no    result:  unknown
# premise:  Three young men are runn
# add_premise:
# hypothesis:  There is no man runn
#
#
# 1584 label:  yes    result:  unknown
# premise:  A hole is being burrowed by the badger
# add_premise:  ['all x.(burrow(x) -> dig(x))', 'all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  A badger is shrewdly digging the earth
#
#
# 1703 label:  yes    result:  unknown
# premise:  A man is emptying a container made of plastic completely
# add_premise:
# hypothesis:  A man is emptying a container made of plastic
#
#
# 1839 label:  yes    result:  unknown
# premise:  The g
# add_premise:  []
# hypothesis:  The g
#
#
# 1881 label:  yes    result:  unknown
# premise:  The food on the trays is being eaten by the kittens
# add_premise:  ['all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  A few kittens are eating
#
#
# 2058 label:  yes    result:  unknown
# premise:  A lady is cutting up some meat precisely
# add_premise:
# hypothesis:  Some meat is being cut into pieces by a woman
#
#
# 2089 label:  no    result:  unknown
# premise:  The man is denying an interview
# add_premise:  []
# hypothesis:  The man is granting an interview
#
#
# 2166 label:  yes    result:  unknown
# premise:  A woman is sewing with a machine
# add_premise:
# hypothesis:  A woman is using a machine made for sewing
#
#
# 2284 label:  yes    result:  unknown
# premise:  The cat is playing passionately with a watermelon
# add_premise:
# hypothesis:  The cat is playing with a watermelon
#
#
# 2286 label:  yes    result:  unknown
# premise:  The cat is playing passionately with a watermelon
# add_premise:
# hypothesis:  A cat is playing with a watermelon
#
#
# 2364 label:  yes    result:  unknown
# premise:  Some cameras are being burned by a person with a blow torch
# add_premise:  ['all x.(torch(x) -> fire(x))', 'all x.(burn(x) <-> fire(x))', 'all x.(blow(x) -> set(x))', 'all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  The person is setting fire to the cameras
#
#
# 2404 label:  no    result:  unknown
# premise:  The lady is slicing a tomato
# add_premise:
# hypothesis:  There is no one cutting a tomato
#
#
# 2430 label:  yes    result:  unknown
# premise:  One man is running down the road
# add_premise:
# hypothesis:  A man is running
#
#
# 2476 label:  yes    result:  unknown
# premise:  Some people are singing
# add_premise:  []
# hypothesis:  A group of people is singing
#
#
# 2566 label:  yes    result:  unknown
# premise:  Three women are dancing
# add_premise:  []
# hypothesis:  A few women are dancing
#
#
# 2704 label:  yes    result:  unknown
# premise:  Noodles are being boiled in water by a woman
# add_premise:  ['all x.(noodles(x) <-> noodle(x))', 'all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  A woman is boiling noodles in water
#
#
# 2712 label:  no    result:  unknown
# premise:  There is no karate practitioner kicking at another man who is wearing protective boxing gloves
# add_premise:
# hypothesis:  A karate practitioner is kicking at another man who is wearing protective boxing gloves
#
#
# 2721 label:  unknown    result:  no
# premise:  The man is kick boxing with a trainer
# add_premise:  ['all x.(trainer(x) -> practitioner(x))']
# hypothesis:  A karate practitioner is kicking at another man who is wearing protective boxing gloves
#
#
# 2722 label:  yes    result:  unknown
# premise:  A wo
# add_premise:
# hypothesis:  A seated woman is singing a song and playing the guitar
#
#
# 2772 label:  yes    result:  unknown
# premise:  A person is pouring oil for cooking into a pot
# add_premise:  []
# hypothesis:  A person is pouring cooking oil into a pot
#
#
# 2791 label:  yes    result:  unknown
# premise:  A guinea
# add_premise:
# hypothesis:  A small guinea pig is gnawing and eating a piece of carrot on the floor
#
#
# 2795 label:  yes    result:  unknown
# premise:  A small guinea pig is gnawing and eating a piece of carrot on the floor
# add_premise:
# hypothesis:  A guinea pig is devouring a carrot
#
#
# 2911 label:  no    result:  unknown
# premise:  A woman is putting on makeup
# add_premise:
# hypothesis:  There is no woman putting on makeup
#
#
# 2967 label:  yes    result:  unknown
# premise:  A large green ball is hitting a potato
# add_premise:  []
# hypothesis:  A large green colored ball is hitting a potato
#
#
# 2972 label:  no    result:  unknown
# premise:  A large green ball is hitting a potato
# add_premise:  ['all x.(large(x) <-> big(x))', 'all x.(hit(x) -> -miss(x))', 'all x.(miss(x) -> -hit(x))']
# hypothesis:  A big green ball is missing a potato
#
#
# 3036 label:  no    result:  unknown
# premise:  The puppy is not playing with a plastic container
# add_premise:  []
# hypothesis:  The puppy is playing with a plastic container
#
#
# 3061 label:  no    result:  unknown
# premise:  A woman is driving a car and is talking to the man who is seated beside her
# add_premise:
# hypothesis:  There is no woman driving a car and talking to the man seated beside her
#
#
# 3122 label:  yes    result:  unknown
# premise:  A woman is using a pencil for eyes and is applying eye liner to her eyelid
# add_premise:
# hypothesis:  A woman is applying cosmetics to her eyelid
#
#
# 3123 label:  no    result:  unknown
# premise:  There is no woman using an eye pencil and applying eye liner to her eyelid
# add_premise:
# hypothesis:  A woman is applying cosmetics to her eyelid
#
#
# 3181 label:  unknown    result:  no
# premise:  A man is trekking in the woods
# add_premise:  []
# hypothesis:  The man is not hiking in the woods
#
#
# 3222 label:  no    result:  unknown
# premise:  There is no boy walking across a bridge
# add_premise:
# hypothesis:  A boy is walking across a bridge
#
#
# 3250 label:  yes    result:  unknown
# premise:  A woman is placing two eggs into a pot of water
# add_premise:  ['all x.(place(x) -> put(x))', 'all x.(place(x) <-> put(x))']
# hypothesis:  A woman is putting two eggs into a pot of water
#
#
# 3258 label:  no    result:  unknown
# premise:  A man is playing the guitar
# add_premise:  []
# hypothesis:  Nobody is playing the guitar
#
#
# 3275 label:  yes    result:  unknown
# premise:  A child is running in and out of the waves of the ocean
# add_premise:
# hypothesis:  A child is running in and out of the ocean waves
#
#
# 3338 label:  no    result:  unknown
# premise:  There is no man standing on a roof top and playing a violin
# add_premise:
# hypothesis:  A man is standing on a roof top and playing a violin
#
#
# 3373 label:  yes    result:  unknown
# premise:  A woman is riding a water scooter
# add_premise:  []
# hypothesis:  A woman is riding a scooter for water
#
#
# 3518 label:  unknown    result:  no
# premise:  The man is not dancing
# add_premise:  ['all x.(man(x) -> -woman(x))', 'all x.(woman(x) -> -man(x))']
# hypothesis:  A woman is dancing
#
#
# 3536 label:  yes    result:  unknown
# premise:  Someone is cooking okra in a pan
# add_premise:  ['all x.(cooking(x) <-> cook(x))']
# hypothesis:  Okra is being cooked in a pan
#
#
# 3586 label:  yes    result:  unknown
# premise:  A man is playing the drum
# add_premise:  []
# hypothesis:  A man is practicing the drum
#
#
# 3625 label:  no    result:  unknown
# premise:  A woman is putting meat in a pan
# add_premise:
# hypothesis:  There is no woman putting meat in a pan
#
#
# 3626 label:  yes    result:  unknown
# premise:  Someone is dropping the meat into a pan
# add_premise:  []
# hypothesis:  The meat is being dropped into a pan
#
#
# 3657 label:  yes    result:  unknown
# premise:  A boy is filling a pitcher with water
# add_premise:  []
# hypothesis:  A pitcher is being filled with water by a boy
#
#
# 3670 label:  yes    result:  unknown
# premise:  It is raining on a walking man
# add_premise:  ['all x.(walking(x) <-> walk(x))']
# hypothesis:  A man is walking in the rain
#
#
# 3680 label:  no    result:  unknown
# premise:  Racers are running down a track
# add_premise:
# hypothesis:  There are no racers running down a track
#
#
# 3711 label:  no    result:  unknown
# premise:  A toy train is striking a toy car
# add_premise:  ['all x.(strike(x) -> -miss(x))', 'all x.(miss(x) -> -strike(x))']
# hypothesis:  A toy train is missing a toy car
#
#
# 3721 label:  yes    result:  unknown
# premise:  The person is slicing onions
# add_premise:  ['all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  Onions are being sliced by the person
#
#
# 3733 label:  yes    result:  unknown
# premise:  Swimmers are racing in a lake
# add_premise:  []
# hypothesis:  Some racers are swimming in a lake
#
#
# 3812 label:  yes    result:  unknown
# premise:  A woman is slicing a pepper which is green
# add_premise:  []
# hypothesis:  A woman is slicing a green pepper
#
#
# 3880 label:  yes    result:  unknown
# premise:  A man is dancing on the ceiling of a room
# add_premise:
# hypothesis:  The man is dancing upside-down on the ceiling
#
#
# 3897 label:  no    result:  unknown
# premise:  There is no man exercising
# add_premise:
# hypothesis:  A man is exercising
#
#
# 3909 label:  yes    result:  unknown
# premise:  The man is singing and playing the guitar
# add_premise:
# hypothesis:  The guitar is being played by a man
#
#
# 3941 label:  no    result:  unknown
# premise:  A boy is looking at a calendar
# add_premise:
# hypothesis:  There is no boy checking a calendar
#
#
# 4006 label:  yes    result:  unknown
# premise:  A man is climbing a rope
# add_premise:
# hypothesis:  The man is climbing up a rope
#
#
# 4011 label:  yes    result:  unknown
# premise:  A man is climbing a rope
# add_premise:
# hypothesis:  A man is climbing up a rope
#
#
# 4015 label:  yes    result:  unknown
# premise:  The lady is picking up the kangaroo
# add_premise:
# hypothesis:  The woman is picking up the kangaroo
#
#
# 4066 label:  yes    result:  unknown
# premise:  The man is hurling knives at a tree
# add_premise:  ['all x.(hurl(x) -> throw(x))', 'all x.(hurl(x) <-> throw(x))']
# hypothesis:  The man is throwing knives at a tree
#
#
# 4086 label:  no    result:  unknown
# premise:  There is no man drawing a picture
# add_premise:
# hypothesis:  A man is drawing a picture
#
#
# 4114 label:  no    result:  unknown
# premise:  There is no man eating food
# add_premise:
# hypothesis:  A man is eating a pizza
#
#
# 4155 label:  no    result:  unknown
# premise:  A man is playing a wooden flute
# add_premise:
# hypothesis:  There is no man playing a wooden flute
#
#
# 4157 label:  no    result:  unknown
# premise:  There is no man playing the piano
# add_premise:
# hypothesis:  A man is playing the piano
#
#
# 4187 label:  no    result:  unknown
# premise:  There is no dog playing with a toy
# add_premise:
# hypothesis:  A dog is eating a doll
#
#
# 4288 label:  yes    result:  unknown
# premise:  The woman is slicing cooked octopus
# add_premise:
# hypothesis:  A woman is chopping up an octopus
#
#
# 4321 label:  no    result:  unknown
# premise:  A man is drawing
# add_premise:
# hypothesis:  There is no man drawing
#
#
# 4330 label:  no    result:  unknown
# premise:  The man is drawing
# add_premise:
# hypothesis:  There is no man drawing
#
#
# 4505 label:  yes    result:  unknown
# premise:  The doctors are healing a man
# add_premise:  ['all x.(heal(x) -> help(x))', 'all x.(man(x) -> help(x))']
# hypothesis:  The doctor is helping the patient
#
#
# 4520 label:  no    result:  unknown
# premise:  There is no man playing a guitar
# add_premise:
# hypothesis:  A man is playing a guitar
#
#
# 4614 label:  no    result:  unknown
# premise:  There is no man driving a car
# add_premise:
# hypothesis:  A man is driving a car
#
#
# 4650 label:  no    result:  unknown
# premise:  A man is cutting a thick rope with a sword
# add_premise:
# hypothesis:  There is no man cutting a rope with a sword
#
#
# 4734 label:  yes    result:  unknown
# premise:  A man is fitting a silencer to a pistol
# add_premise:  ['all x.(fit(x) -> apply(x))', 'all x.(pistol(x) -> gun(x))']
# hypothesis:  A man is applying a silencer to a gun
#
#
# 4767 label:  no    result:  unknown
# premise:  A man is cooking a snake
# add_premise:
# hypothesis:  There is no man cooking a snake
#
#
# 4776 label:  no    result:  unknown
# premise:  There is no boy playing guitar
# add_premise:
# hypothesis:  A boy is playing guitar
#
#
# 4803 label:  no    result:  unknown
# premise:  There is no monkey teasing a dog at the zoo
# add_premise:
# hypothesis:  A monkey is teasing a dog at the zoo
#
#
# 4816 label:  no    result:  unknown
# premise:  There is no person cutting some ginger
# add_premise:
# hypothesis:  A person is cutting some ginger
#
#
# 4831 label:  no    result:  unknown
# premise:  A man is slicing a potato into pieces
# add_premise:  ['all x.(slice(x) -> cut(x))', 'all x.(slice(x) <-> cut(x))']
# hypothesis:  A man is not cutting a potato
#
#
# 4843 label:  no    result:  unknown
# premise:  A man is opening a box with a knife
# add_premise:
# hypothesis:  There is no man opening a box with a knife
#
#
# 4916 label:  yes    result:  unknown
# premise:  A man is singing and playing a guitar
# add_premise:
# hypothesis:  A man is singing and playing a musical instrument
#
#
# 4966 label:  no    result:  unknown
# premise:  A woman is slicing a fish
# add_premise:
# hypothesis:  There is no woman slicing a fish
#
#
# 5003 label:  yes    result:  unknown
# premise:  A big cat is opening a plastic drawer with its paws and is jumping inside
# add_premise:
# hypothesis:  A cat is opening a drawer and jumping inside
#
#
# 5051 label:  no    result:  unknown
# premise:  A man is opening a door
# add_premise:
# hypothesis:  There is no man opening a door
#
#
# 5203 label:  yes    result:  unknown
# premise:  The woman is putting pasta into a dish
# add_premise:  []
# hypothesis:  Pasta is being put into a dish by a woman
#
#
# 5310 label:  no    result:  unknown
# premise:  There is no girl playing a flute
# add_premise:
# hypothesis:  A girl is playing a flute
#
#
# 5352 label:  no    result:  unknown
# premise:  A man is playing a large flute
# add_premise:
# hypothesis:  There is no man playing a flute
#
#
# 5938 label:  yes    result:  unknown
# premise:  Vegetables are being put into a pot by a man
# add_premise:  ['all x.(put(x) -> pour(x))', 'all x.(man(x) -> someone(x))']
# hypothesis:  Someone is pouring ingredients into a pot
#
#
# 6047 label:  yes    result:  unknown
# premise:  A man and a woman are in a room painted be
# add_premise:
# hypothesis:  A man and a woman are in a beige r
#
#
# 6146 label:  no    result:  unknown
# premise:  Two people are standing in the ocean and watching the sunset
# add_premise:
# hypothesis:  Nobody is standing in the ocean and watching the sunset
#
#
# 6219 label:  yes    result:  unknown
# premise:  A man is standing on a boat in front of the sunset near a flag
# add_premise:
# hypothesis:  A man is on a boat in front of the sunset
#
#
# 6280 label:  yes    result:  unknown
# premise:  A
# add_premise:  []
# hypothesis:  A black dog is running in the grass
#
#
# 6358 label:  no    result:  unknown
# premise:  The woman in a red costume is leaning against a brick wall and playing an instrument
# add_premise:
# hypothesis:  The woman in a red costume is not leaning against a brick wall and is not playing an instrument
#
#
# 6544 label:  no    result:  unknown
# premise:  The ice hockey goalkeeper is wearing a yellow jersey and is defending the goal
# add_premise:
# hypothesis:  There is no hockey player in a yellow jersey guarding the goal
#
#
# 6634 label:  yes    result:  unknown
# premise:  A hurdle is being leapt by a horse that has a rider on its back
# add_premise:
# hypothesis:  A horse and its rider are leaping over a barrier
#
#
# 6649 label:  yes    result:  unknown
# premise:  Two teenage girls are wearing fancy dresses at an event
# add_premise:  []
# hypothesis:  Two girls in their teens are wearing fancy dresses at an event
#
#
# 6705 label:  yes    result:  unknown
# premise:  A ch
# add_premise:
# hypothesis:  A small child is outdoors climbing steps in a grassy area
#
#
# 6784 label:  no    result:  unknown
# premise:  There is no man dressed in black wearing an elaborate black mask
# add_premise:
# hypothesis:  A man dressed in black is wearing an elaborate black mask
#
#
# 6932 label:  yes    result:  unknown
# premise:  The snowboarder is doing a flip over a mound of snow
# add_premise:  ['all x.(snowboarder(x) -> somebody(x))']
# hypothesis:  Somebody is jumping in the air on a board
#
#
# 6971 label:  no    result:  unknown
# premise:  There is no man in a red uniform making a jump in a dirt bike race
# add_premise:
# hypothesis:  A man in a red uniform is making a jump in a dirt bike race
#
#
# 7018 label:  yes    result:  unknown
# premise:  A child in clothing which is light colored is standing with his arms extended outward
# add_premise:
# hypothesis:  A child in light colored clothing is standing with his arms extended outward
#
#
# 7093 label:  yes    result:  unknown
# premise:  The group of people is standing together and looking at the camera
# add_premise:
# hypothesis:  A group of people is standing together and looking at the camera
#
#
# 7214 label:  no    result:  unknown
# premise:  A brown dog is running across the yard with a toy in its mouth
# add_premise:
# hypothesis:  There is no brown dog running across the yard with a toy in its mouth
#
#
# 7311 label:  yes    result:  unknown
# premise:  A cigarette is being smoked by the man in the straw hat
# add_premise:
# hypothesis:  A man is wearing a straw hat and smoking a cigarette
#
#
# 7445 label:  yes    result:  unknown
# premise:  The little girl is swinging and the woman is standing behind her
# add_premise:  []
# hypothesis:  The g
#
#
# 7466 label:  yes    result:  unknown
# premise:  The group of people is sitting in a dim room
# add_premise:  []
# hypothesis:  The group of people is sitting in a room which is dim
#
#
# 7471 label:  yes    result:  unknown
# premise:  A man and two women in a dark room are sitting at a table with candles
# add_premise:  ['all x.(woman(x) -> people(x))', 'all x.(woman(x) -> group(x))', 'all x.(table(x) -> group(x))', 'all x.(man(x) -> group(x))', 'all x.(at(x) -> group(x))']
# hypothesis:  The group of people is sitting in a dim room
#
#
# 7477 label:  yes    result:  unknown
# premise:  A man in a white shirt and sunglasses and a man in a black shirt and sunglasses are sitting at a table with four bottles of beer
# add_premise:  []
# hypothesis:  A man in a white shirt and sunglasses and a man in a black shirt and sunglasses are sitting at a table with four beer bottles
#
#
# 7546 label:  yes    result:  unknown
# premise:  A young girl in a blue leotard is jumping in the air
# add_premise:  []
# hypothesis:  A young girl in a leotard colored in blue is jumping in the air
#
#
# 7582 label:  yes    result:  unknown
# premise:  The bunch of men are playing rugby on a field full of mud
# add_premise:
# hypothesis:  Some men are playing rugby
#
#
# 7649 label:  no    result:  unknown
# premise:  There is no little boy wearing a green soccer strip and running on the grass
# add_premise:
# hypothesis:  A little boy is wearing a green soccer strip and is running on the grass
#
#
# 7667 label:  no    result:  unknown
# premise:  The man at the beach is not doing a handstand on the wet sand at the edge of the water
# add_premise:  []
# hypothesis:  The man is doing a handstand on the wet sand at the edge of the water at the beach
#
#
# 7677 label:  yes    result:  unknown
# premise:  A young mother is playing with her boy in the park
# add_premise:  ['all x.(female(x) -> -male(x))', 'all x.(male(x) -> -female(x))']
# hypothesis:  A young boy is playing in the park with his mother
#
#
# 7718 label:  no    result:  unknown
# premise:  A man is spraying a super soaker into the mouth of a dog
# add_premise:
# hypothesis:  There is no man spraying a super soaker into the mouth of a dog
#
#
# 7772 label:  no    result:  unknown
# premise:  A surfer is riding a big wave across dark green water
# add_premise:  []
# hypothesis:  The surfer is riding a small wave
#
#
# 8057 label:  yes    result:  unknown
# premise:  A young girl is wearing a blue patterned swim s
# add_premise:
# hypothesis:  A little girl is wearing a blue patterned swim s
#
#
# 8138 label:  yes    result:  unknown
# premise:  The girl has red hair and eyebr
# add_premise:
# hypothesis:  The girl has red hair and eyebr
#
#
# 8163 label:  yes    result:  unknown
# premise:  Two people are driving a jeep and a lady is sitting on the top of it
# add_premise:  []
# hypothesis:  Two people are driving a jeep and a girl is sitting on the top of it
#
#
# 8193 label:  no    result:  unknown
# premise:  The adults and children are not gathered near an outdoor seating arrangement
# add_premise:  []
# hypothesis:  The adults and children are being gathered near an outdoor seating arrangement
#
#
# 8263 label:  no    result:  unknown
# premise:  Some people and vehicles are on a crowded street
# add_premise:
# hypothesis:  Some people and vehicles are on a almost empty street
#
#
# 8326 label:  no    result:  unknown
# premise:  There is no bmx biker jumping dirt ramps in front of a body of water
# add_premise:
# hypothesis:  Two bmx bikers are jumping dirt ramps in front of a body of water
#
#
# 8343 label:  yes    result:  unknown
# premise:  A man in a motocross uniform is wearing a helmet and rides a red motorcycle
# add_premise:
# hypothesis:  A person in a motocross uniform is wearing a helmet and rides a red motorcycle
#
#
# 8383 label:  yes    result:  unknown
# premise:  A girl in blue is sliding down a green slide
# add_premise:
# hypothesis:  The young girl in blue is enjoying a slide
#
#
# 8471 label:  yes    result:  unknown
# premise:  A girl in blue sweater is holding a multicolor toy and is sitting on the shoulders of an old man with grey hair
# add_premise:
# hypothesis:  A girl in blue sweater is holding a multicolor toy and is sitting on the shoulders of a man with grey hair
#
#
# 8576 label:  yes    result:  unknown
# premise:  A black dog and a small white and black dog are looking up at a kitchen countertop
# add_premise:
# hypothesis:  A large dog and a small dog are standing next to the kitchen counter and are investigating
#
#
# 8632 label:  no    result:  unknown
# premise:  A man is not rock climbing and a city and a bay are in the background
# add_premise:
# hypothesis:  A man is rock climbing and a city and a bay are in the background
#
#
# 8633 label:  yes    result:  unknown
# premise:  A man is rock climb
# add_premise:
# hypothesis:  A man is rock climb
#
#
# 8660 label:  yes    result:  unknown
# premise:  A group of rollerbladers is lining up on the street
# add_premise:
# hypothesis:  A group of rollerbladers is lining up on the road
#
#
# 8678 label:  yes    result:  unknown
# premise:  A skateboarder is jumping off a ramp
# add_premise:
# hypothesis:  A skateboarder is making a jump off a ramp
#
#
# 8727 label:  yes    result:  unknown
# premise:  A group of people are standing around a sound mixing table
# add_premise:  []
# hypothesis:  Some people is looking at sound equipment
#
#
# 8786 label:  yes    result:  unknown
# premise:  A girl is skipping rope on a sidewalk
# add_premise:  []
# hypothesis:  A girl is skipping rope on near a street
#
#
# 8986 label:  yes    result:  unknown
# premise:  A young girl in a bikini is jumping on the beach
# add_premise:  []
# hypothesis:  A young girl in swimming suite is jumping on the beach
#
#
# 9014 label:  no    result:  unknown
# premise:  A blond child is going down a slide and throwing up his arms
# add_premise:
# hypothesis:  A child with dark hair is going down a slide and throwing up his arms
#
#
# 9069 label:  yes    result:  unknown
# premise:  Two boys are laying in the ocean close to the beach
# add_premise:
# hypothesis:  Two boys are laying in the water close to the beach
#
#
# 9132 label:  yes    result:  unknown
# premise:  A man in a jersey which is black is standing in a gym
# add_premise:  []
# hypothesis:  A man in a black jersey is standing in a gym
#
#
# 9136 label:  yes    result:  unknown
# premise:  A man in a black jersey is standing in a gym
# add_premise:
# hypothesis:  A man is standing in a gym and is wearing a jersey
#
#
# 9425 label:  no    result:  unknown
# premise:  No dog is in the sand that is blowing in the wind
# add_premise:
# hypothesis:  A dog is in a sandy area with the sand that is being stirred up into the air and several plants are in the background
#
#
# 9433 label:  yes    result:  unknown
# premise:  The black and white dog is running in a green yard
# add_premise:
# hypothesis:  A black and white dog is running outdoors
#
#
# 9490 label:  no    result:  unknown
# premise:  A cluster of four brown dogs are playing in a field of brown grass
# add_premise:  ['all x.(field(x) <-> area(x))']
# hypothesis:  Four dogs are not playing in a grassy area
#
#
# 9571 label:  yes    result:  unknown
# premise:  An elder man is sitting on a bench and is wearing a gray jacket and black pants
# add_premise:
# hypothesis:  An elderly man is sitting on a bench
#
#
# 9669 label:  yes    result:  unknown
# premise:  The young girl is playing on the edge of a fountain and an older woman is watching her
# add_premise:  []
# hypothesis:  A young girl is playing on the edge of a fountain and an older woman is watching her
#
#
# 9706 label:  no    result:  unknown
# premise:  A black and white dog with a large branch is standing in the field
# add_premise:
# hypothesis:  A black and white dog with a large branch is running in the field
#
#
# 9713 label:  yes    result:  unknown
# premise:  A black and white dog is carrying a huge stick on the green grass
# add_premise:
# hypothesis:  A black and white dog with a large branch is running in the field
#
#
# 9747 label:  yes    result:  unknown
# premise:  A little boy is sticking his tongue out for the camera and another boy is looking on
# add_premise:
# hypothesis:  Two kids are looking up at the camera and one is sticking out his tongue

# %%
# examples of problems we translated successfully

print("translated problems: \n")
for i in range(0,int(len(translate_data)/10)):
  print(translate_data.iloc[i]['problem_id'], "gold label: ", translate_data.iloc[i]['label'], "   result: ", translate_data.iloc[i]['result'])
  print("premise: ", translate_data.iloc[i]['p_sen'])
  print("premise fol: ", translate_data.iloc[i]['p_fol'])
  print("add_premise: ", translate_data.iloc[i]['add_fol'])
  print("hypothesis: ", translate_data.iloc[i]['h_sen'])
  print("hypothesis fol: ", translate_data.iloc[i]['h_fol'])
  print("\n")
# Out:
# translated problems:
#
# 24 gold label:  unknown    result:  unknown
# premise:  A person in a black jacket is doing tricks on a motorbike
# premise fol:  exists x.(person(x) & exists z13.(exists z12.(black(z12) & argu1(z13,z12) & jacket(z13)) & in(x,z13) & exists z14.(trick(z14) & exists e.(do(e) & argu1(e,x) & argu2(e,z14) & exists z14.(motorbike(z14) & on(e,z14) & True(e))))))
# add_premise:  ['all x.(motorbike(x) -> ride(x))']
# hypothesis:  A skilled person is riding a bicycle on one wheel
# hypothesis fol:  exists x.(exists z15.(skilled(z15) & argu1(x,z15) & person(x)) & exists z17.(bicycle(z17) & exists e.(ride(e) & argu1(e,x) & argu2(e,z17) & exists z17.(exists z16.(one(z16) & argu1(z17,z16) & wheel(z17)) & on(e,z17) & True(e)))))
#
#
# 116 gold label:  unknown    result:  unknown
# premise:  A player is throwing the ball
# premise fol:  exists x.(player(x) & exists z22.(ball(z22) & exists e.(throw(e) & argu1(e,x) & argu2(e,z22) & True(e))))
# add_premise:  ['all x.(player(x) -> match(x))']
# hypothesis:  Two teams are competing in a football match
# hypothesis fol:  exists x.(exists z23.(two(z23) & argu1(x,z23) & team(x)) & exists e.(compete(e) & argu1(e,x) & exists z25.(exists z24.(football(z24) & argu1(z25,z24) & match(z25)) & in(e,z25)) & True(e)))
#
#
# 119 gold label:  unknown    result:  unknown
# premise:  Five children are standing in front of a wooden hut
# premise fol:  exists x.(exists z26.(five(z26) & argu1(x,z26) & child(x)) & exists z30.(stand(z30) & argu1(z30,x) & exists z29.(front(z29) & exists z28.(exists z27.(wooden(z27) & argu1(z28,z27) & hut(z28)) & of(z29,z28) & in(z30,z29) & True(z30)))))
# add_premise:  []
# hypothesis:  Five children are standing in a wooden hut
# hypothesis fol:  exists x.(exists z31.(five(z31) & argu1(x,z31) & child(x)) & exists z34.(stand(z34) & argu1(z34,x) & exists z33.(exists z32.(wooden(z32) & argu1(z33,z32) & hut(z33)) & in(z34,z33) & True(z34))))
#
#
# 185 gold label:  unknown    result:  unknown
# premise:  Few people are eating at red tables in a restaurant without lights
# premise fol:  exists x.(exists z35.(few(z35) & argu1(x,z35) & people(x)) & exists e.(eat(e) & argu1(e,x) & exists z39.(exists z36.(red(z36) & argu1(z39,z36) & table(z39)) & exists z38.(restaurant(z38) & exists z37.(light(z37) & without(z38,z37) & in(z39,z38) & at(e,z39)))) & True(e)))
# add_premise:  ['all x.(table(x) -> group(x))', 'all x.(few(x) -> group(x))']
# hypothesis:  A large group of Asian people is eating at a restaurant
# hypothesis fol:  exists x.(exists z40.(large(z40) & argu1(x,z40) & group(x)) & exists z42.(exists z41.(asian(z41) & argu1(z42,z41) & people(z42)) & of(x,z42) & exists e.(eat(e) & argu1(e,x) & exists z43.(restaurant(z43) & at(e,z43)) & True(e))))
#
#
# 211 gold label:  yes    result:  yes
# premise:  Two dogs are playing by a tree
# premise fol:  exists x.(exists z44.(two(z44) & argu1(x,z44) & dog(x)) & exists z46.(play(z46) & argu1(z46,x) & exists z45.(tree(z45) & by(z46,z45) & True(z46))))
# add_premise:  ['all x.(tree(x) -> plant(x))']
# hypothesis:  Two dogs are playing by a plant
# hypothesis fol:  exists x.(exists z47.(two(z47) & argu1(x,z47) & dog(x)) & exists z49.(play(z49) & argu1(z49,x) & exists z48.(plant(z48) & by(z49,z48) & True(z49))))
#
#
# 225 gold label:  unknown    result:  unknown
# premise:  The equipment in front of the blond dancing girl is sound
# premise fol:  exists x.(equipment(x) & exists z61.(front(z61) & exists z60.(exists z59.(blond(z59) & argu1(z60,z59) & exists z59.(dancing(z59) & argu1(z60,z59) & girl(z60))) & of(z61,z60) & in(x,z61) & exists z63.(sound(z63) & argu1(z63,x) & True(z63)))))
# add_premise:  ['all x.(dancing(x) <-> dance(x))']
# hypothesis:  A girl in white is dancing
# hypothesis fol:  exists x.(girl(x) & exists z64.(white(z64) & in(x,z64) & exists z66.(dance(z66) & argu1(z66,x) & True(z66))))
#
#
# 228 gold label:  unknown    result:  unknown
# premise:  A girl in white is dancing
# premise fol:  exists x.(girl(x) & exists z67.(white(z67) & in(x,z67) & exists z69.(dance(z69) & argu1(z69,x) & True(z69))))
# add_premise:  ['all x.(white(x) -> equipment(x))']
# hypothesis:  The blond girl is dancing in front of the sound equipment
# hypothesis fol:  exists x.(exists z70.(blond(z70) & argu1(x,z70) & girl(x)) & exists z74.(dance(z74) & argu1(z74,x) & exists z73.(front(z73) & exists z72.(exists z71.(sound(z71) & argu1(z72,z71) & equipment(z72)) & of(z73,z72) & in(z74,z73) & True(z74)))))
#
#
# 280 gold label:  unknown    result:  unknown
# premise:  A boy is standing outside the water
# premise fol:  exists x.(boy(x) & exists z82.(stand(z82) & argu1(z82,x) & exists z81.(water(z81) & outside(z82,z81) & True(z82))))
# add_premise:  []
# hypothesis:  The boy is wading through the blue ocean
# hypothesis fol:  exists x.(boy(x) & exists z85.(wade(z85) & argu1(z85,x) & exists z84.(exists z83.(blue(z83) & argu1(z84,z83) & ocean(z84)) & through(z85,z84) & True(z85))))
#
#
# 304 gold label:  unknown    result:  unknown
# premise:  An
# premise fol:  exists x.(exists z92.(old(z92) & argu1(x,z92) & exists z92.(topless(z92) & argu1(x,z92) & woman(x))) & exists e.(cover(e) & argu1(e,x) & exists z93.(paint(z93) & in(e,z93)) & True(e)))
# add_premise:  ['all x.(old(x) -> -young(x))', 'all x.(young(x) -> -old(x))']
# hypothesis:  A yo
# hypothesis fol:  exists x.(exists z94.(young(z94) & argu1(x,z94) & exists z94.(topless(z94) & argu1(x,z94) & woman(x))) & exists e.(cover(e) & argu1(e,x) & exists z95.(paint(z95) & in(e,z95)) & True(e)))
#
#
# 382 gold label:  unknown    result:  unknown
# premise:  A brown and white dog is running through the tall grass
# premise fol:  (exists x.(brown(x) & exists z104.(run(z104) & argu1(z104,x) & exists z103.(exists z102.(tall(z102) & argu1(z103,z102) & grass(z103)) & through(z104,z103) & True(z104)))) & exists x.(exists z101.(white(z101) & argu1(x,z101) & dog(x)) & exists z105.(run(z105) & argu1(z105,x) & exists z103.(exists z102.(tall(z102) & argu1(z103,z102) & grass(z103)) & through(z105,z103) & True(z105)))))
# add_premise:  ['all x.(run(x) -> move(x))', 'all x.(run(x) <-> move(x))']
# hypothesis:  A brown and white dog is moving through the wild grass
# hypothesis fol:  (exists x.(brown(x) & exists z109.(move(z109) & argu1(z109,x) & exists z108.(exists z107.(wild(z107) & argu1(z108,z107) & grass(z108)) & through(z109,z108) & True(z109)))) & exists x.(exists z106.(white(z106) & argu1(x,z106) & dog(x)) & exists z110.(move(z110) & argu1(z110,x) & exists z108.(exists z107.(wild(z107) & argu1(z108,z107) & grass(z108)) & through(z110,z108) & True(z110)))))
#
#
# 402 gold label:  unknown    result:  unknown
# premise:  A group of scouts are hiking through the grass
# premise fol:  exists x.(group(x) & exists z115.(scout(z115) & of(x,z115) & exists z117.(hike(z117) & argu1(z117,x) & exists z116.(grass(z116) & through(z117,z116) & True(z117)))))
# add_premise:  ['all x.(hike(x) -> walk(x))']
# hypothesis:  A group of explorers are walking through the grass
# hypothesis fol:  exists x.(group(x) & exists z118.(explorer(z118) & of(x,z118) & exists z120.(walk(z120) & argu1(z120,x) & exists z119.(grass(z119) & through(z120,z119) & True(z120)))))
#
#
# 530 gold label:  unknown    result:  unknown
# premise:  A biker is wearing gear which is black
# premise fol:  exists z144.(biker(z144) & exists z143.(gear(z143) & exists z142.(black(z142) & argu1(z142,z143) & x) & exists e.(wear(e) & argu1(e,z144) & argu2(e,z143) & True(e))))
# add_premise:  []
# hypothesis:  A biker wearing black is breaking the gears
# hypothesis fol:  exists x.(exists z145.(biker(z145) & argu1(x,z145) & exists z145.(wear(z145) & argu1(x,z145) & black(x))) & exists z146.(gear(z146) & exists e.(break(e) & argu1(e,x) & argu2(e,z146) & True(e))))
#
#
# 647 gold label:  unknown    result:  unknown
# premise:  One man is climbing a cliff with a rope
# premise fol:  exists x.(exists z156.(one(z156) & argu1(x,z156) & man(x)) & exists z157.(cliff(z157) & exists e.(climb(e) & argu1(e,x) & argu2(e,z157) & exists z157.(rope(z157) & with(e,z157) & True(e)))))
# add_premise:  ['all x.(man(x) -> person(x))', 'all x.(cliff(x) -> rock(x))']
# hypothesis:  A person with pink climbing gear roped the rock
# hypothesis fol:  exists x.(person(x) & exists z159.(exists z158.(pink(z158) & argu1(z159,z158) & exists z158.(climb(z158) & argu1(z159,z158) & gear(z159))) & with(x,z159) & exists z160.(rock(z160) & exists e.(rope(e) & argu1(e,x) & argu2(e,z160) & True(e)))))
#
#
# 651 gold label:  unknown    result:  unknown
# premise:  A person is climbing a rock with a r
# premise fol:  exists z165.(person(z165) & exists z164.(rock(z164) & exists e.(climb(e) & argu1(e,z165) & argu2(e,z164) & exists z163.(rope(z163) & exists z162.(pink(z162) & argu1(z162,z163) & x) & with(e,z163) & True(e)))))
# add_premise:  ['all x.(rock(x) -> cliff(x))']
# hypothesis:  One man is climbing a cliff with a rope
# hypothesis fol:  exists x.(exists z166.(one(z166) & argu1(x,z166) & man(x)) & exists z167.(cliff(z167) & exists e.(climb(e) & argu1(e,x) & argu2(e,z167) & exists z167.(rope(z167) & with(e,z167) & True(e)))))
#
#
# 687 gold label:  unknown    result:  unknown
# premise:  One white dog is staring at the black street
# premise fol:  exists x.(exists z168.(one(z168) & argu1(x,z168) & exists z168.(white(z168) & argu1(x,z168) & dog(x))) & exists e.(stare(e) & argu1(e,x) & exists z170.(exists z169.(black(z169) & argu1(z170,z169) & street(z170)) & at(e,z170)) & True(e)))
# add_premise:  ['all x.(stare(x) -> look(x))']
# hypothesis:  Two dogs of different breeds are looking at each other across a street
# hypothesis fol:  exists z177.(exists z171.(two(z171) & argu1(z177,z171) & dog(z177)) & exists z173.(exists z172.(different(z172) & argu1(z173,z172) & breed(z173)) & of(z177,z173) & exists e.(look(e) & argu1(e,z177) & -(exists x.-at(e,x) & other(x)) & exists z174.(street(z174) & across(e,z174) & True(e)))))
#
#
# 717 gold label:  no    result:  unknown
# premise:  A few men in a competition are running outside
# premise fol:  exists x.(exists z181.(few(z181) & argu1(x,z181) & man(x)) & exists z182.(competition(z182) & in(x,z182) & exists z184.(run(z184) & argu1(z184,x) & exists s.(outside(s) & argu1(z184,s) & True(z184)))))
# add_premise:  ['all x.(outside(x) -> -indoor(x))', 'all x.(indoor(x) -> -outside(x))']
# hypothesis:  A few men in a competition are running indoors
# hypothesis fol:  exists x.(exists z185.(few(z185) & argu1(x,z185) & man(x)) & exists z186.(competition(z186) & in(x,z186) & exists z188.(run(z188) & argu1(z188,x) & exists s.(indoor(s) & argu1(z188,s) & True(z188)))))
#
#
# 718 gold label:  unknown    result:  unknown
# premise:  A few men in a competition are running outside
# premise fol:  exists x.(exists z189.(few(z189) & argu1(x,z189) & man(x)) & exists z190.(competition(z190) & in(x,z190) & exists z192.(run(z192) & argu1(z192,x) & exists s.(outside(s) & argu1(z192,s) & True(z192)))))
# add_premise:  []
# hypothesis:  A few men are running competitions outside
# hypothesis fol:  exists x.(exists z193.(few(z193) & argu1(x,z193) & man(x)) & exists z194.(competition(z194) & exists e.(run(e) & argu1(e,x) & argu2(e,z194) & exists s.(outside(s) & argu1(e,s) & True(e)))))
#
#
# 882 gold label:  unknown    result:  unknown
# premise:  The girl in the blue and white uniform is cheering
# premise fol:  exists x.(girl(x) & exists z215.(blue(z215) & in(x,z215) & exists z218.(cheer(z218) & argu1(z218,x) & True(z218))) & exists z216.(exists z214.(white(z214) & argu1(z216,z214) & uniform(z216)) & in(x,z216) & exists z219.(cheer(z219) & argu1(z219,x) & True(z219))))
# add_premise:  []
# hypothesis:  The girl is cheering the man in the blue and white uniform
# hypothesis fol:  exists x.(girl(x) & exists z223.(man(z223) & exists z221.(blue(z221) & in(z223,z221) & exists e.(cheer(e) & argu1(e,x) & argu2(e,z223) & True(e))) & exists z222.(exists z220.(white(z220) & argu1(z222,z220) & uniform(z222)) & in(z223,z222) & exists e.(cheer(e) & argu1(e,x) & argu2(e,z223) & True(e)))))
#
#
# 1039 gold label:  unknown    result:  unknown
# premise:  The snowboarder is not leaping over white snow
# premise fol:  exists x.(snowboarder(x) & -exists z246.(leap(z246) & argu1(z246,x) & exists z245.(exists z244.(white(z244) & argu1(z245,z244) & snow(z245)) & over(z246,z245) & True(z246))))
# add_premise:  ['all x.(white(x) -> person(x))', 'all x.(leap(x) -> jump(x))', 'all x.(leap(x) <-> jump(x))', 'all x.(snowboarder(x) -> person(x))']
# hypothesis:  A person who is practicing snowboarding jumps into the air
# hypothesis fol:  exists z248.(person(z248) & exists z247.(snowboard(z247) & exists e.(practice(e) & argu1(e,z248) & argu2(e,z247) & x)) & exists e.(jump(e) & argu1(e,z248) & exists z249.(air(z249) & into(e,z249)) & True(e)))
#
#
# 1137 gold label:  unknown    result:  unknown
# premise:  A fish is hunting for a turtle in the sea
# premise fol:  exists x.(fish(x) & exists e.(hunt(e) & argu1(e,x) & exists z254.(turtle(z254) & exists z253.(sea(z253) & in(z254,z253) & for(e,z254))) & True(e)))
# add_premise:  ['all x.(hunt(x) -> follow(x))']
# hypothesis:  The turtle is following the fish
# hypothesis fol:  exists x.(turtle(x) & exists z255.(fish(z255) & exists e.(follow(e) & argu1(e,x) & argu2(e,z255) & True(e))))
#
#
# 1170 gold label:  unknown    result:  unknown
# premise:  A potato is being sliced by a woman
# premise fol:  exists x.(potato(x) & exists z257.(slice(z257) & patient(z257,x) & exists z256.(woman(z256) & by(z257,z256) & True(z257))))
# add_premise:  ['all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  A woman is slicing a carrot
# hypothesis fol:  exists x.(woman(x) & exists z258.(carrot(z258) & exists e.(slice(e) & argu1(e,x) & argu2(e,z258) & True(e))))
#
#
# 1177 gold label:  unknown    result:  unknown
# premise:  A woman is combing her hair
# premise fol:  exists x.(woman(x) & exists z259.(female(z259) & exists y.(user(y,z259) & hair(y) & exists e.(comb(e) & argu1(e,x) & argu2(e,y) & True(e)))))
# add_premise:  []
# hypothesis:  A woman is arranging her hair
# hypothesis fol:  exists x.(woman(x) & exists z260.(female(z260) & exists y.(user(y,z260) & hair(y) & exists e.(arrange(e) & argu1(e,x) & argu2(e,y) & True(e)))))
#
#
# 1190 gold label:  yes    result:  unknown
# premise:  A man and a woman are hiking through a wooded area
# premise fol:  (exists x.(man(x) & exists z265.(hike(z265) & argu1(z265,x) & exists z264.(exists z263.(wooded(z263) & argu1(z264,z263) & area(z264)) & through(z265,z264) & True(z265)))) & exists x.(woman(x) & exists z266.(hike(z266) & argu1(z266,x) & exists z264.(exists z263.(wooded(z263) & argu1(z264,z263) & area(z264)) & through(z266,z264) & True(z266)))))
# add_premise:  ['all x.(hike(x) -> walk(x))']
# hypothesis:  A man and a woman are walking together through the woods
# hypothesis fol:  (exists x.(man(x) & exists z269.(walk(z269) & argu1(z269,x) & exists s.(together(s) & argu1(z269,s) & exists z268.(wood(z268) & through(z269,z268) & True(z269))))) & exists x.(woman(x) & exists z270.(walk(z270) & argu1(z270,x) & exists s.(together(s) & argu1(z270,s) & exists z268.(wood(z268) & through(z270,z268) & True(z270))))))
#
#
# 1192 gold label:  yes    result:  unknown
# premise:  A man and a woman are walking together through the woods
# premise fol:  (exists x.(man(x) & exists z273.(walk(z273) & argu1(z273,x) & exists s.(together(s) & argu1(z273,s) & exists z272.(wood(z272) & through(z273,z272) & True(z273))))) & exists x.(woman(x) & exists z274.(walk(z274) & argu1(z274,x) & exists s.(together(s) & argu1(z274,s) & exists z272.(wood(z272) & through(z274,z272) & True(z274))))))
# add_premise:  []
# hypothesis:  A man and a woman are walking through a wooded area
# hypothesis fol:  (exists x.(man(x) & exists z277.(walk(z277) & argu1(z277,x) & exists z276.(exists z275.(wooded(z275) & argu1(z276,z275) & area(z276)) & through(z277,z276) & True(z277)))) & exists x.(woman(x) & exists z278.(walk(z278) & argu1(z278,x) & exists z276.(exists z275.(wooded(z275) & argu1(z276,z275) & area(z276)) & through(z278,z276) & True(z278)))))
#
#
# 1232 gold label:  unknown    result:  unknown
# premise:  A man is slicing a bun
# premise fol:  exists x.(man(x) & exists z279.(bun(z279) & exists e.(slice(e) & argu1(e,x) & argu2(e,z279) & True(e))))
# add_premise:  []
# hypothesis:  A man is slicing a tomato
# hypothesis fol:  exists x.(man(x) & exists z280.(tomato(z280) & exists e.(slice(e) & argu1(e,x) & argu2(e,z280) & True(e))))
#
#
# 1266 gold label:  yes    result:  unknown
# premise:  A band is playing on a stage
# premise fol:  exists x.(band(x) & exists z292.(play(z292) & argu1(z292,x) & exists z291.(stage(z291) & on(z292,z291) & True(z292))))
# add_premise:  ['all x.(stage(x) -> onstage(x))']
# hypothesis:  A band is playing onstage
# hypothesis fol:  exists x.(band(x) & exists z294.(play(z294) & argu1(z294,x) & exists s.(onstage(s) & argu1(z294,s) & True(z294))))
#
#
# 1302 gold label:  unknown    result:  unknown
# premise:  A man is playing flute
# premise fol:  exists x.(man(x) & exists z295.(flute(z295) & exists e.(play(e) & argu1(e,x) & argu2(e,z295) & True(e))))
# add_premise:  []
# hypothesis:  A man is playing a game with a ball
# hypothesis fol:  exists x.(man(x) & exists z296.(game(z296) & exists e.(play(e) & argu1(e,x) & argu2(e,z296) & exists z296.(ball(z296) & with(e,z296) & True(e)))))

# %% [markdown]
# ## Test set

# %%
ccg_path = path + "/SICK_test_ccg.txt"
sen_path = path + "/SICK_test_sen.txt"

# %%
'''
run on data set. catch the error when running.
input: sick dataset file name + ccg derivation file name
output: data(dataframe) + error
data(dataframe): problem_id(int), p_sen(str), h_sen(str), p_dev(int), h_dev(int), label(str), p_fol(str), h_fol(str), add_p(list of str), add_fol(list of fol), result(str)
'''
data = pd.DataFrame(columns=['problem_id','p_sen','h_sen', 'p_dev', 'h_dev', 'label', 'add_p', 'add_fol', 'p_fol', 'h_fol', 'result'])
data.set_index('problem_id')
error_cnt = {'LogicalExpressionException':0, "UnboundLocalError":0, "OtherError":0}

# ccg_derivation txt file ---> examples
# example[x] ---> the xth derivation in LOLA_SICK_corrected_derivations.txt
examples = []
with open(ccg_path, "r") as f:
    lines = [line for line in f]
    curr_example = ""
    for line in lines:
        if line == '\n':
            examples.append(curr_example)
            curr_example = ""
        else:
            curr_example += line

# %%
with open(sen_path, "r") as file:
  line = [l for l in file]
  for i in range(0,len(line),3):
    # print(line[i])
    problem_id = int(line[i].split('=')[1].strip())
    p_sen = line[i+1].split('(')[1].split(',')[4][2:-4]
    h_sen = line[i+2].split('(')[1].split(',')[4][2:-4]
    p_dev = int(line[i+1].split('(')[1].split(',')[0])
    h_dev = int(line[i+2].split('(')[1].split(',')[0])
    label = line[i+1].split('(')[1].split(',')[3][2:-1]

    # add_p, add_fol = get_knowledge(h_sen, [p_sen])
    try: 
      p_fol = derivation_to_FOL(p_dev)
      h_fol = derivation_to_FOL(h_dev)
    except LogicalExpressionException as e:
      print(f"{problem_id}: can't get a FOL formula based on the given lexical semantics")
      error_cnt["LogicalExpressionException"] += 1
      result = "unknown"
      data.loc[problem_id] = [problem_id,p_sen,h_sen,p_dev,h_dev,label,'', '', '', '',result]
    except UnboundLocalError as e:
      print(f"{problem_id}: missing lexical semantics")
      error_cnt["UnboundLocalError"] += 1
      result = "unknown"
      data.loc[problem_id] = [problem_id,p_sen,h_sen,p_dev,h_dev,label,'', '', '', '',result]
    except:
      print(f"{problem_id}: other problems")
      error_cnt["OtherError"] += 1
      result = "unknown"
      data.loc[problem_id] = [problem_id,p_sen,h_sen,p_dev,h_dev,label,'', '', '', '',result]
    else:
      add_p, add_fol = get_knowledge(' '.join(fol_to_word(h_fol)), [' '.join(fol_to_word(p_fol))])
      if 'patient' in p_fol and 'by' in p_fol:
        add_fol.append('all x all y (patient(x,y) <-> argu2(x,y))')
        add_fol.append('all x all y (by(x,y) <-> argu1(x,y))')
      elif 'patient' in h_fol and 'by' in h_fol:
        add_fol.append('all x all y (patient(x,y) <-> argu2(x,y))')
        add_fol.append('all x all y (by(x,y) <-> argu1(x,y))')
      result = get_inference_label(h_fol,[p_fol] + add_fol)
      data.loc[problem_id] = [problem_id,p_sen,h_sen,p_dev,h_dev,label,add_p,add_fol,p_fol,h_fol,result]
# Out:
# 6: can't get a FOL formula based on the given lexical semantics
# 8: can't get a FOL formula based on the given lexical semantics
# 13: can't get a FOL formula based on the given lexical semantics
# 15: can't get a FOL formula based on the given lexical semantics
# 16: can't get a FOL formula based on the given lexical semantics
# 17: can't get a FOL formula based on the given lexical semantics
# 20: can't get a FOL formula based on the given lexical semantics
# 27: can't get a FOL formula based on the given lexical semantics
# 31: can't get a FOL formula based on the given lexical semantics
# 32: can't get a FOL formula based on the given lexical semantics
# 33: can't get a FOL formula based on the given lexical semantics
# 34: can't get a FOL formula based on the given lexical semantics
# 36: can't get a FOL formula based on the given lexical semantics
# 37: can't get a FOL formula based on the given lexical semantics
# 38: can't get a FOL formula based on the given lexical semantics
# 39: can't get a FOL formula based on the given lexical semantics
# 54: can't get a FOL formula based on the given lexical semantics
# 61: can't get a FOL formula based on the given lexical semantics
# 63: can't get a FOL formula based on the given lexical semantics
# 64: can't get a FOL formula based on the given lexical semantics
# 66: can't get a FOL formula based on the given lexical semantics
# 67: can't get a FOL formula based on the given lexical semantics
# 68: can't get a FOL formula based on the given lexical semantics
# 69: can't get a FOL formula based on the given lexical semantics
# 71: can't get a FOL formula based on the given lexical semantics
# 86: can't get a FOL formula based on the given lexical semantics
# 96: can't get a FOL formula based on the given lexical semantics
# 101: can't get a FOL formula based on the given lexical semantics
# 102: can't get a FOL formula based on the given lexical semantics
# 103: can't get a FOL formula based on the given lexical semantics
# 104: can't get a FOL formula based on the given lexical semantics
# 106: can't get a FOL formula based on the given lexical semantics
# 118: can't get a FOL formula based on the given lexical semantics
# 121: can't get a FOL formula based on the given lexical semantics
# 123: can't get a FOL formula based on the given lexical semantics
# 125: can't get a FOL formula based on the given lexical semantics
# 128: can't get a FOL formula based on the given lexical semantics
# 132: can't get a FOL formula based on the given lexical semantics
# 134: can't get a FOL formula based on the given lexical semantics
# 135: can't get a FOL formula based on the given lexical semantics
# 137: can't get a FOL formula based on the given lexical semantics
# 138: can't get a FOL formula based on the given lexical semantics
# 142: can't get a FOL formula based on the given lexical semantics
# 143: can't get a FOL formula based on the given lexical semantics
# 145: can't get a FOL formula based on the given lexical semantics
# 147: can't get a FOL formula based on the given lexical semantics
# 152: can't get a FOL formula based on the given lexical semantics
# 154: can't get a FOL formula based on the given lexical semantics
# 158: can't get a FOL formula based on the given lexical semantics
# 160: can't get a FOL formula based on the given lexical semantics
# 162: can't get a FOL formula based on the given lexical semantics
# 165: can't get a FOL formula based on the given lexical semantics
# 166: can't get a FOL formula based on the given lexical semantics
# 171: can't get a FOL formula based on the given lexical semantics
# 174: can't get a FOL formula based on the given lexical semantics
# 191: can't get a FOL formula based on the given lexical semantics
# 193: can't get a FOL formula based on the given lexical semantics
# 195: can't get a FOL formula based on the given lexical semantics
# 196: can't get a FOL formula based on the given lexical semantics
# 198: can't get a FOL formula based on the given lexical semantics
# 199: can't get a FOL formula based on the given lexical semantics
# ((s\np)\ (s\np))/ ((s\np)\ (s\np)) no such category
# 206: missing lexical semantics
# 207: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# 210: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# Could not find a proof: return 'neutral'
# 229: can't get a FOL formula based on the given lexical semantics
# 230: can't get a FOL formula based on the given lexical semantics
# 235: can't get a FOL formula based on the given lexical semantics
# 239: can't get a FOL formula based on the given lexical semantics
# conj no such category
# 244: missing lexical semantics
# conj no such category
# 247: missing lexical semantics
# 255: can't get a FOL formula based on the given lexical semantics
# 261: can't get a FOL formula based on the given lexical semantics
# 262: can't get a FOL formula based on the given lexical semantics
# 263: can't get a FOL formula based on the given lexical semantics
# 264: can't get a FOL formula based on the given lexical semantics
# 267: can't get a FOL formula based on the given lexical semantics
# 268: can't get a FOL formula based on the given lexical semantics
# 270: can't get a FOL formula based on the given lexical semantics
# 271: can't get a FOL formula based on the given lexical semantics
# 284: can't get a FOL formula based on the given lexical semantics
# 288: can't get a FOL formula based on the given lexical semantics
# 290: can't get a FOL formula based on the given lexical semantics
# 292: can't get a FOL formula based on the given lexical semantics
# 295: can't get a FOL formula based on the given lexical semantics
# 297: can't get a FOL formula based on the given lexical semantics
# 299: can't get a FOL formula based on the given lexical semantics
# 308: can't get a FOL formula based on the given lexical semantics
# 314: can't get a FOL formula based on the given lexical semantics
# 316: can't get a FOL formula based on the given lexical semantics
# 318: can't get a FOL formula based on the given lexical semantics
# 319: can't get a FOL formula based on the given lexical semantics
# 320: can't get a FOL formula based on the given lexical semantics
# 321: can't get a FOL formula based on the given lexical semantics
# 322: can't get a FOL formula based on the given lexical semantics
# 325: can't get a FOL formula based on the given lexical semantics
# 326: can't get a FOL formula based on the given lexical semantics
# 328: can't get a FOL formula based on the given lexical semantics
# 330: can't get a FOL formula based on the given lexical semantics
# 334: can't get a FOL formula based on the given lexical semantics
# 336: can't get a FOL formula based on the given lexical semantics
# 337: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# 345: can't get a FOL formula based on the given lexical semantics
# 348: can't get a FOL formula based on the given lexical semantics
# 349: can't get a FOL formula based on the given lexical semantics
# 350: can't get a FOL formula based on the given lexical semantics
# conj no such category
# 352: missing lexical semantics
# 353: can't get a FOL formula based on the given lexical semantics
# 355: can't get a FOL formula based on the given lexical semantics
# 356: can't get a FOL formula based on the given lexical semantics
# 357: can't get a FOL formula based on the given lexical semantics
# conj no such category
# 359: missing lexical semantics
# 371: can't get a FOL formula based on the given lexical semantics
# 376: can't get a FOL formula based on the given lexical semantics
# 385: can't get a FOL formula based on the given lexical semantics
# 388: can't get a FOL formula based on the given lexical semantics
# 389: can't get a FOL formula based on the given lexical semantics
# conj no such category
# 399: missing lexical semantics
# 400: can't get a FOL formula based on the given lexical semantics
# 401: can't get a FOL formula based on the given lexical semantics
# 411: can't get a FOL formula based on the given lexical semantics
# 414: can't get a FOL formula based on the given lexical semantics
# 416: can't get a FOL formula based on the given lexical semantics
# 418: can't get a FOL formula based on the given lexical semantics
# 419: can't get a FOL formula based on the given lexical semantics
# 420: can't get a FOL formula based on the given lexical semantics
# 421: can't get a FOL formula based on the given lexical semantics
# 424: can't get a FOL formula based on the given lexical semantics
# 425: can't get a FOL formula based on the given lexical semantics
# 426: can't get a FOL formula based on the given lexical semantics
# 430: can't get a FOL formula based on the given lexical semantics
# 431: can't get a FOL formula based on the given lexical semantics
# 432: can't get a FOL formula based on the given lexical semantics
# 444: can't get a FOL formula based on the given lexical semantics
# 445: can't get a FOL formula based on the given lexical semantics
# 448: can't get a FOL formula based on the given lexical semantics
# 452: can't get a FOL formula based on the given lexical semantics
# 456: can't get a FOL formula based on the given lexical semantics
# 458: can't get a FOL formula based on the given lexical semantics
# 463: can't get a FOL formula based on the given lexical semantics
# 464: can't get a FOL formula based on the given lexical semantics
# 466: can't get a FOL formula based on the given lexical semantics
# 467: can't get a FOL formula based on the given lexical semantics
# 468: can't get a FOL formula based on the given lexical semantics
# 472: can't get a FOL formula based on the given lexical semantics
# 474: can't get a FOL formula based on the given lexical semantics
# conj no such category
# 478: missing lexical semantics
# 479: can't get a FOL formula based on the given lexical semantics
# 480: can't get a FOL formula based on the given lexical semantics
# 481: can't get a FOL formula based on the given lexical semantics
# 482: can't get a FOL formula based on the given lexical semantics
# 483: can't get a FOL formula based on the given lexical semantics
# 487: can't get a FOL formula based on the given lexical semantics
# 488: can't get a FOL formula based on the given lexical semantics
# 490: can't get a FOL formula based on the given lexical semantics
# 492: can't get a FOL formula based on the given lexical semantics
# 493: can't get a FOL formula based on the given lexical semantics
# 501: can't get a FOL formula based on the given lexical semantics
# 504: can't get a FOL formula based on the given lexical semantics
# 509: can't get a FOL formula based on the given lexical semantics
# (np\np)/ (s/np) no such category
# 510: missing lexical semantics
# 511: can't get a FOL formula based on the given lexical semantics
# 512: can't get a FOL formula based on the given lexical semantics
# 517: can't get a FOL formula based on the given lexical semantics
# 518: can't get a FOL formula based on the given lexical semantics
# 519: can't get a FOL formula based on the given lexical semantics
# 521: can't get a FOL formula based on the given lexical semantics
# 523: can't get a FOL formula based on the given lexical semantics
# 525: can't get a FOL formula based on the given lexical semantics
# 532: can't get a FOL formula based on the given lexical semantics
# 533: can't get a FOL formula based on the given lexical semantics
# 537: can't get a FOL formula based on the given lexical semantics
# 539: can't get a FOL formula based on the given lexical semantics
# 540: can't get a FOL formula based on the given lexical semantics
# 543: can't get a FOL formula based on the given lexical semantics
# 544: can't get a FOL formula based on the given lexical semantics
# 546: can't get a FOL formula based on the given lexical semantics
# 547: can't get a FOL formula based on the given lexical semantics
# 549: can't get a FOL formula based on the given lexical semantics
# 553: can't get a FOL formula based on the given lexical semantics
# 554: can't get a FOL formula based on the given lexical semantics
# 562: can't get a FOL formula based on the given lexical semantics
# 563: can't get a FOL formula based on the given lexical semantics
# 566: can't get a FOL formula based on the given lexical semantics
# 567: can't get a FOL formula based on the given lexical semantics
# 569: can't get a FOL formula based on the given lexical semantics
# 571: can't get a FOL formula based on the given lexical semantics
# 572: can't get a FOL formula based on the given lexical semantics
# 573: can't get a FOL formula based on the given lexical semantics
# 574: can't get a FOL formula based on the given lexical semantics
# 575: can't get a FOL formula based on the given lexical semantics
# 576: can't get a FOL formula based on the given lexical semantics
# 577: can't get a FOL formula based on the given lexical semantics
# 578: can't get a FOL formula based on the given lexical semantics
# 579: can't get a FOL formula based on the given lexical semantics
# 580: can't get a FOL formula based on the given lexical semantics
# 582: can't get a FOL formula based on the given lexical semantics
# 585: can't get a FOL formula based on the given lexical semantics
# 589: can't get a FOL formula based on the given lexical semantics
# 590: can't get a FOL formula based on the given lexical semantics
# 591: can't get a FOL formula based on the given lexical semantics
# 593: can't get a FOL formula based on the given lexical semantics
# 594: can't get a FOL formula based on the given lexical semantics
# 595: can't get a FOL formula based on the given lexical semantics
# 596: can't get a FOL formula based on the given lexical semantics
# 598: can't get a FOL formula based on the given lexical semantics
# 600: can't get a FOL formula based on the given lexical semantics
# 602: can't get a FOL formula based on the given lexical semantics
# 607: can't get a FOL formula based on the given lexical semantics
# 608: can't get a FOL formula based on the given lexical semantics
# 610: can't get a FOL formula based on the given lexical semantics
# 612: can't get a FOL formula based on the given lexical semantics
# 613: can't get a FOL formula based on the given lexical semantics
# 614: can't get a FOL formula based on the given lexical semantics
# 615: can't get a FOL formula based on the given lexical semantics
# 616: can't get a FOL formula based on the given lexical semantics
# 618: can't get a FOL formula based on the given lexical semantics
# 620: can't get a FOL formula based on the given lexical semantics
# 623: can't get a FOL formula based on the given lexical semantics
# 624: can't get a FOL formula based on the given lexical semantics
# 627: can't get a FOL formula based on the given lexical semantics
# 633: can't get a FOL formula based on the given lexical semantics
# 635: can't get a FOL formula based on the given lexical semantics
# 636: can't get a FOL formula based on the given lexical semantics
# 652: can't get a FOL formula based on the given lexical semantics
# 654: can't get a FOL formula based on the given lexical semantics
# 656: can't get a FOL formula based on the given lexical semantics
# 658: can't get a FOL formula based on the given lexical semantics
# 659: can't get a FOL formula based on the given lexical semantics
# 662: can't get a FOL formula based on the given lexical semantics
# 664: can't get a FOL formula based on the given lexical semantics
# (s/s)/np no such category
# 681: missing lexical semantics
# 682: can't get a FOL formula based on the given lexical semantics
# 683: can't get a FOL formula based on the given lexical semantics
# (s/s)/np no such category
# 684: missing lexical semantics
# 694: can't get a FOL formula based on the given lexical semantics
# 695: can't get a FOL formula based on the given lexical semantics
# 700: can't get a FOL formula based on the given lexical semantics
# 701: can't get a FOL formula based on the given lexical semantics
# 707: can't get a FOL formula based on the given lexical semantics
# 708: can't get a FOL formula based on the given lexical semantics
# 710: can't get a FOL formula based on the given lexical semantics
# 711: can't get a FOL formula based on the given lexical semantics
# 712: can't get a FOL formula based on the given lexical semantics
# 714: can't get a FOL formula based on the given lexical semantics
# 740: can't get a FOL formula based on the given lexical semantics
# 742: can't get a FOL formula based on the given lexical semantics
# 744: can't get a FOL formula based on the given lexical semantics
# 763: can't get a FOL formula based on the given lexical semantics
# 767: can't get a FOL formula based on the given lexical semantics
# 770: can't get a FOL formula based on the given lexical semantics
# 771: can't get a FOL formula based on the given lexical semantics
# 775: can't get a FOL formula based on the given lexical semantics
# 776: can't get a FOL formula based on the given lexical semantics
# 778: can't get a FOL formula based on the given lexical semantics
# 779: can't get a FOL formula based on the given lexical semantics
# 782: can't get a FOL formula based on the given lexical semantics
# 786: can't get a FOL formula based on the given lexical semantics
# 795: can't get a FOL formula based on the given lexical semantics
# 798: can't get a FOL formula based on the given lexical semantics
# 800: can't get a FOL formula based on the given lexical semantics
# 801: can't get a FOL formula based on the given lexical semantics
# 803: can't get a FOL formula based on the given lexical semantics
# 805: can't get a FOL formula based on the given lexical semantics
# 808: can't get a FOL formula based on the given lexical semantics
# 809: can't get a FOL formula based on the given lexical semantics
# 810: can't get a FOL formula based on the given lexical semantics
# 814: can't get a FOL formula based on the given lexical semantics
# 815: can't get a FOL formula based on the given lexical semantics
# 818: can't get a FOL formula based on the given lexical semantics
# 819: can't get a FOL formula based on the given lexical semantics
# 821: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# 828: can't get a FOL formula based on the given lexical semantics
# 829: can't get a FOL formula based on the given lexical semantics
# 832: can't get a FOL formula based on the given lexical semantics
# 833: can't get a FOL formula based on the given lexical semantics
# 834: can't get a FOL formula based on the given lexical semantics
# 835: can't get a FOL formula based on the given lexical semantics
# 837: can't get a FOL formula based on the given lexical semantics
# 838: can't get a FOL formula based on the given lexical semantics
# 840: can't get a FOL formula based on the given lexical semantics
# 842: can't get a FOL formula based on the given lexical semantics
# 847: can't get a FOL formula based on the given lexical semantics
# 849: can't get a FOL formula based on the given lexical semantics
# 850: can't get a FOL formula based on the given lexical semantics
# 853: can't get a FOL formula based on the given lexical semantics
# 854: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# 861: can't get a FOL formula based on the given lexical semantics
# 865: can't get a FOL formula based on the given lexical semantics
# 871: can't get a FOL formula based on the given lexical semantics
# 875: can't get a FOL formula based on the given lexical semantics
# 890: can't get a FOL formula based on the given lexical semantics
# 891: can't get a FOL formula based on the given lexical semantics
# 894: can't get a FOL formula based on the given lexical semantics
# 896: can't get a FOL formula based on the given lexical semantics
# 897: can't get a FOL formula based on the given lexical semantics
# 903: can't get a FOL formula based on the given lexical semantics
# 907: can't get a FOL formula based on the given lexical semantics
# 921: can't get a FOL formula based on the given lexical semantics
# 923: can't get a FOL formula based on the given lexical semantics
# 925: can't get a FOL formula based on the given lexical semantics
# 926: can't get a FOL formula based on the given lexical semantics
# 928: can't get a FOL formula based on the given lexical semantics
# 929: can't get a FOL formula based on the given lexical semantics
# 930: can't get a FOL formula based on the given lexical semantics
# 934: can't get a FOL formula based on the given lexical semantics
# 939: can't get a FOL formula based on the given lexical semantics
# 941: can't get a FOL formula based on the given lexical semantics
# 942: can't get a FOL formula based on the given lexical semantics
# 946: can't get a FOL formula based on the given lexical semantics
# 952: can't get a FOL formula based on the given lexical semantics
# 955: can't get a FOL formula based on the given lexical semantics
# 958: can't get a FOL formula based on the given lexical semantics
# 964: can't get a FOL formula based on the given lexical semantics
# 965: can't get a FOL formula based on the given lexical semantics
# 969: can't get a FOL formula based on the given lexical semantics
# 971: can't get a FOL formula based on the given lexical semantics
# 972: can't get a FOL formula based on the given lexical semantics
# 974: can't get a FOL formula based on the given lexical semantics
# 976: can't get a FOL formula based on the given lexical semantics
# 977: can't get a FOL formula based on the given lexical semantics
# 981: can't get a FOL formula based on the given lexical semantics
# 982: can't get a FOL formula based on the given lexical semantics
# 983: can't get a FOL formula based on the given lexical semantics
# 986: can't get a FOL formula based on the given lexical semantics
# 990: can't get a FOL formula based on the given lexical semantics
# 992: can't get a FOL formula based on the given lexical semantics
# 993: can't get a FOL formula based on the given lexical semantics
# 995: can't get a FOL formula based on the given lexical semantics
# 997: can't get a FOL formula based on the given lexical semantics
# 999: can't get a FOL formula based on the given lexical semantics
# 1001: can't get a FOL formula based on the given lexical semantics
# 1003: can't get a FOL formula based on the given lexical semantics
# 1005: can't get a FOL formula based on the given lexical semantics
# 1006: can't get a FOL formula based on the given lexical semantics
# 1011: can't get a FOL formula based on the given lexical semantics
# 1012: can't get a FOL formula based on the given lexical semantics
# 1013: can't get a FOL formula based on the given lexical semantics
# 1014: can't get a FOL formula based on the given lexical semantics
# 1015: can't get a FOL formula based on the given lexical semantics
# 1017: can't get a FOL formula based on the given lexical semantics
# 1020: can't get a FOL formula based on the given lexical semantics
# 1023: can't get a FOL formula based on the given lexical semantics
# 1024: can't get a FOL formula based on the given lexical semantics
# 1025: can't get a FOL formula based on the given lexical semantics
# 1027: can't get a FOL formula based on the given lexical semantics
# 1030: can't get a FOL formula based on the given lexical semantics
# 1051: can't get a FOL formula based on the given lexical semantics
# 1056: can't get a FOL formula based on the given lexical semantics
# 1062: can't get a FOL formula based on the given lexical semantics
# 1063: can't get a FOL formula based on the given lexical semantics
# 1067: can't get a FOL formula based on the given lexical semantics
# 1070: can't get a FOL formula based on the given lexical semantics
# 1071: can't get a FOL formula based on the given lexical semantics
# 1072: can't get a FOL formula based on the given lexical semantics
# 1075: can't get a FOL formula based on the given lexical semantics
# 1077: can't get a FOL formula based on the given lexical semantics
# 1078: can't get a FOL formula based on the given lexical semantics
# 1081: can't get a FOL formula based on the given lexical semantics
# 1085: can't get a FOL formula based on the given lexical semantics
# 1086: can't get a FOL formula based on the given lexical semantics
# 1089: can't get a FOL formula based on the given lexical semantics
# 1100: can't get a FOL formula based on the given lexical semantics
# 1101: can't get a FOL formula based on the given lexical semantics
# 1103: can't get a FOL formula based on the given lexical semantics
# 1106: can't get a FOL formula based on the given lexical semantics
# 1107: can't get a FOL formula based on the given lexical semantics
# 1110: can't get a FOL formula based on the given lexical semantics
# 1113: can't get a FOL formula based on the given lexical semantics
# 1114: can't get a FOL formula based on the given lexical semantics
# 1116: can't get a FOL formula based on the given lexical semantics
# 1124: can't get a FOL formula based on the given lexical semantics
# 1140: can't get a FOL formula based on the given lexical semantics
# 1142: can't get a FOL formula based on the given lexical semantics
# 1144: can't get a FOL formula based on the given lexical semantics
# 1146: can't get a FOL formula based on the given lexical semantics
# 1151: can't get a FOL formula based on the given lexical semantics
# 1171: can't get a FOL formula based on the given lexical semantics
# 1173: can't get a FOL formula based on the given lexical semantics
# 1197: can't get a FOL formula based on the given lexical semantics
# 1203: can't get a FOL formula based on the given lexical semantics
# s/s no such category
# 1204: missing lexical semantics
# 1216: can't get a FOL formula based on the given lexical semantics
# 1225: can't get a FOL formula based on the given lexical semantics
# 1229: can't get a FOL formula based on the given lexical semantics
# 1231: can't get a FOL formula based on the given lexical semantics
# 1233: can't get a FOL formula based on the given lexical semantics
# 1234: can't get a FOL formula based on the given lexical semantics
# 1235: can't get a FOL formula based on the given lexical semantics
# 1238: can't get a FOL formula based on the given lexical semantics
# 1243: can't get a FOL formula based on the given lexical semantics
# 1245: can't get a FOL formula based on the given lexical semantics
# 1247: can't get a FOL formula based on the given lexical semantics
# 1252: can't get a FOL formula based on the given lexical semantics
# 1258: can't get a FOL formula based on the given lexical semantics
# 1263: can't get a FOL formula based on the given lexical semantics
# 1265: can't get a FOL formula based on the given lexical semantics
# 1281: can't get a FOL formula based on the given lexical semantics
# 1288: can't get a FOL formula based on the given lexical semantics
# 1289: can't get a FOL formula based on the given lexical semantics
# 1300: can't get a FOL formula based on the given lexical semantics
# 1306: can't get a FOL formula based on the given lexical semantics
# 1310: can't get a FOL formula based on the given lexical semantics
# 1316: can't get a FOL formula based on the given lexical semantics
# 1322: can't get a FOL formula based on the given lexical semantics
# 1325: can't get a FOL formula based on the given lexical semantics
# 1343: can't get a FOL formula based on the given lexical semantics
# 1347: can't get a FOL formula based on the given lexical semantics
# 1356: can't get a FOL formula based on the given lexical semantics
# 1374: can't get a FOL formula based on the given lexical semantics
# 1397: can't get a FOL formula based on the given lexical semantics
# 1433: can't get a FOL formula based on the given lexical semantics
# 1440: can't get a FOL formula based on the given lexical semantics
# 1451: can't get a FOL formula based on the given lexical semantics
# 1468: can't get a FOL formula based on the given lexical semantics
# 1471: can't get a FOL formula based on the given lexical semantics
# 1472: can't get a FOL formula based on the given lexical semantics
# 1496: can't get a FOL formula based on the given lexical semantics
# 1500: can't get a FOL formula based on the given lexical semantics
# 1512: can't get a FOL formula based on the given lexical semantics
# 1515: can't get a FOL formula based on the given lexical semantics
# 1516: can't get a FOL formula based on the given lexical semantics
# 1539: can't get a FOL formula based on the given lexical semantics
# 1543: can't get a FOL formula based on the given lexical semantics
# 1548: can't get a FOL formula based on the given lexical semantics
# 1554: can't get a FOL formula based on the given lexical semantics
# 1562: can't get a FOL formula based on the given lexical semantics
# 1564: can't get a FOL formula based on the given lexical semantics
# 1581: can't get a FOL formula based on the given lexical semantics
# 1583: can't get a FOL formula based on the given lexical semantics
# 1594: can't get a FOL formula based on the given lexical semantics
# 1596: can't get a FOL formula based on the given lexical semantics
# 1597: can't get a FOL formula based on the given lexical semantics
# 1600: can't get a FOL formula based on the given lexical semantics
# 1602: can't get a FOL formula based on the given lexical semantics
# 1603: can't get a FOL formula based on the given lexical semantics
# 1605: can't get a FOL formula based on the given lexical semantics
# 1619: can't get a FOL formula based on the given lexical semantics
# 1634: can't get a FOL formula based on the given lexical semantics
# 1642: can't get a FOL formula based on the given lexical semantics
# 1644: can't get a FOL formula based on the given lexical semantics
# 1645: can't get a FOL formula based on the given lexical semantics
# 1654: can't get a FOL formula based on the given lexical semantics
# 1672: can't get a FOL formula based on the given lexical semantics
# 1681: can't get a FOL formula based on the given lexical semantics
# 1684: can't get a FOL formula based on the given lexical semantics
# 1695: can't get a FOL formula based on the given lexical semantics
# 1698: can't get a FOL formula based on the given lexical semantics
# 1704: can't get a FOL formula based on the given lexical semantics
# 1709: can't get a FOL formula based on the given lexical semantics
# 1710: can't get a FOL formula based on the given lexical semantics
# 1713: can't get a FOL formula based on the given lexical semantics
# 1720: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# 1732: can't get a FOL formula based on the given lexical semantics
# 1744: can't get a FOL formula based on the given lexical semantics
# 1749: can't get a FOL formula based on the given lexical semantics
# 1758: can't get a FOL formula based on the given lexical semantics
# 1760: can't get a FOL formula based on the given lexical semantics
# 1767: can't get a FOL formula based on the given lexical semantics
# 1790: can't get a FOL formula based on the given lexical semantics
# 1793: can't get a FOL formula based on the given lexical semantics
# 1794: can't get a FOL formula based on the given lexical semantics
# 1796: can't get a FOL formula based on the given lexical semantics
# 1797: can't get a FOL formula based on the given lexical semantics
# 1799: can't get a FOL formula based on the given lexical semantics
# ((s\np)\ (s\np))/ (s\np) no such category
# 1800: missing lexical semantics
# 1805: can't get a FOL formula based on the given lexical semantics
# 1813: can't get a FOL formula based on the given lexical semantics
# 1817: can't get a FOL formula based on the given lexical semantics
# 1819: can't get a FOL formula based on the given lexical semantics
# 1821: can't get a FOL formula based on the given lexical semantics
# 1824: can't get a FOL formula based on the given lexical semantics
# 1827: can't get a FOL formula based on the given lexical semantics
# 1836: can't get a FOL formula based on the given lexical semantics
# 1843: can't get a FOL formula based on the given lexical semantics
# 1845: can't get a FOL formula based on the given lexical semantics
# 1863: can't get a FOL formula based on the given lexical semantics
# 1885: can't get a FOL formula based on the given lexical semantics
# 1889: can't get a FOL formula based on the given lexical semantics
# 1891: can't get a FOL formula based on the given lexical semantics
# 1893: can't get a FOL formula based on the given lexical semantics
# 1895: can't get a FOL formula based on the given lexical semantics
# 1899: can't get a FOL formula based on the given lexical semantics
# 1901: can't get a FOL formula based on the given lexical semantics
# 1911: can't get a FOL formula based on the given lexical semantics
# 1920: can't get a FOL formula based on the given lexical semantics
# 1938: can't get a FOL formula based on the given lexical semantics
# 1966: can't get a FOL formula based on the given lexical semantics
# conj no such category
# 1968: missing lexical semantics
# conj no such category
# 1971: missing lexical semantics
# 1980: can't get a FOL formula based on the given lexical semantics
# 1982: can't get a FOL formula based on the given lexical semantics
# 1983: can't get a FOL formula based on the given lexical semantics
# 1985: can't get a FOL formula based on the given lexical semantics
# 1986: can't get a FOL formula based on the given lexical semantics
# 2003: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# Could not find a proof: return 'neutral'
# 2044: can't get a FOL formula based on the given lexical semantics
# 2057: can't get a FOL formula based on the given lexical semantics
# 2060: can't get a FOL formula based on the given lexical semantics
# 2062: can't get a FOL formula based on the given lexical semantics
# 2063: can't get a FOL formula based on the given lexical semantics
# 2083: can't get a FOL formula based on the given lexical semantics
# 2085: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# 2095: can't get a FOL formula based on the given lexical semantics
# 2106: can't get a FOL formula based on the given lexical semantics
# 2111: can't get a FOL formula based on the given lexical semantics
# 2128: can't get a FOL formula based on the given lexical semantics
# 2134: can't get a FOL formula based on the given lexical semantics
# 2137: can't get a FOL formula based on the given lexical semantics
# 2152: can't get a FOL formula based on the given lexical semantics
# 2154: can't get a FOL formula based on the given lexical semantics
# 2155: can't get a FOL formula based on the given lexical semantics
# 2156: can't get a FOL formula based on the given lexical semantics
# 2158: can't get a FOL formula based on the given lexical semantics
# 2159: can't get a FOL formula based on the given lexical semantics
# 2160: can't get a FOL formula based on the given lexical semantics
# 2161: can't get a FOL formula based on the given lexical semantics
# 2174: can't get a FOL formula based on the given lexical semantics
# 2193: can't get a FOL formula based on the given lexical semantics
# 2194: can't get a FOL formula based on the given lexical semantics
# 2197: can't get a FOL formula based on the given lexical semantics
# 2200: can't get a FOL formula based on the given lexical semantics
# 2201: can't get a FOL formula based on the given lexical semantics
# 2204: can't get a FOL formula based on the given lexical semantics
# 2209: can't get a FOL formula based on the given lexical semantics
# 2211: can't get a FOL formula based on the given lexical semantics
# 2214: can't get a FOL formula based on the given lexical semantics
# 2216: can't get a FOL formula based on the given lexical semantics
# 2219: can't get a FOL formula based on the given lexical semantics
# 2220: can't get a FOL formula based on the given lexical semantics
# 2223: can't get a FOL formula based on the given lexical semantics
# 2224: can't get a FOL formula based on the given lexical semantics
# 2225: can't get a FOL formula based on the given lexical semantics
# 2227: can't get a FOL formula based on the given lexical semantics
# 2249: can't get a FOL formula based on the given lexical semantics
# 2256: can't get a FOL formula based on the given lexical semantics
# 2262: can't get a FOL formula based on the given lexical semantics
# 2265: can't get a FOL formula based on the given lexical semantics
# 2271: can't get a FOL formula based on the given lexical semantics
# 2283: can't get a FOL formula based on the given lexical semantics
# 2292: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# 2298: can't get a FOL formula based on the given lexical semantics
# 2323: can't get a FOL formula based on the given lexical semantics
# 2324: can't get a FOL formula based on the given lexical semantics
# 2326: can't get a FOL formula based on the given lexical semantics
# 2336: can't get a FOL formula based on the given lexical semantics
# 2337: can't get a FOL formula based on the given lexical semantics
# 2342: can't get a FOL formula based on the given lexical semantics
# 2361: can't get a FOL formula based on the given lexical semantics
# 2378: can't get a FOL formula based on the given lexical semantics
# 2380: can't get a FOL formula based on the given lexical semantics
# 2382: can't get a FOL formula based on the given lexical semantics
# 2384: can't get a FOL formula based on the given lexical semantics
# 2398: can't get a FOL formula based on the given lexical semantics
# 2428: can't get a FOL formula based on the given lexical semantics
# 2432: can't get a FOL formula based on the given lexical semantics
# 2433: can't get a FOL formula based on the given lexical semantics
# 2434: can't get a FOL formula based on the given lexical semantics
# 2439: can't get a FOL formula based on the given lexical semantics
# 2449: can't get a FOL formula based on the given lexical semantics
# 2451: can't get a FOL formula based on the given lexical semantics
# 2452: can't get a FOL formula based on the given lexical semantics
# ((s\np)/np)/np no such category
# 2454: missing lexical semantics
# 2460: can't get a FOL formula based on the given lexical semantics
# 2462: can't get a FOL formula based on the given lexical semantics
# 2464: can't get a FOL formula based on the given lexical semantics
# 2478: can't get a FOL formula based on the given lexical semantics
# 2484: can't get a FOL formula based on the given lexical semantics
# 2501: can't get a FOL formula based on the given lexical semantics
# 2507: can't get a FOL formula based on the given lexical semantics
# 2519: can't get a FOL formula based on the given lexical semantics
# 2520: can't get a FOL formula based on the given lexical semantics
# 2522: can't get a FOL formula based on the given lexical semantics
# 2523: can't get a FOL formula based on the given lexical semantics
# 2524: can't get a FOL formula based on the given lexical semantics
# 2526: can't get a FOL formula based on the given lexical semantics
# 2547: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# 2573: can't get a FOL formula based on the given lexical semantics
# 2580: can't get a FOL formula based on the given lexical semantics
# 2585: can't get a FOL formula based on the given lexical semantics
# 2587: can't get a FOL formula based on the given lexical semantics
# 2603: can't get a FOL formula based on the given lexical semantics
# 2611: can't get a FOL formula based on the given lexical semantics
# 2614: can't get a FOL formula based on the given lexical semantics
# 2620: can't get a FOL formula based on the given lexical semantics
# 2629: can't get a FOL formula based on the given lexical semantics
# 2645: can't get a FOL formula based on the given lexical semantics
# 2658: can't get a FOL formula based on the given lexical semantics
# 2659: can't get a FOL formula based on the given lexical semantics
# 2661: can't get a FOL formula based on the given lexical semantics
# 2663: can't get a FOL formula based on the given lexical semantics
# 2665: can't get a FOL formula based on the given lexical semantics
# 2667: can't get a FOL formula based on the given lexical semantics
# 2671: can't get a FOL formula based on the given lexical semantics
# 2674: can't get a FOL formula based on the given lexical semantics
# 2694: can't get a FOL formula based on the given lexical semantics
# 2695: can't get a FOL formula based on the given lexical semantics
# 2697: can't get a FOL formula based on the given lexical semantics
# 2698: can't get a FOL formula based on the given lexical semantics
# 2699: can't get a FOL formula based on the given lexical semantics
# 2700: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# 2723: can't get a FOL formula based on the given lexical semantics
# 2725: can't get a FOL formula based on the given lexical semantics
# 2727: can't get a FOL formula based on the given lexical semantics
# 2729: can't get a FOL formula based on the given lexical semantics
# 2732: can't get a FOL formula based on the given lexical semantics
# 2733: can't get a FOL formula based on the given lexical semantics
# 2737: can't get a FOL formula based on the given lexical semantics
# 2740: can't get a FOL formula based on the given lexical semantics
# 2742: can't get a FOL formula based on the given lexical semantics
# 2745: can't get a FOL formula based on the given lexical semantics
# 2747: can't get a FOL formula based on the given lexical semantics
# 2769: can't get a FOL formula based on the given lexical semantics
# 2771: can't get a FOL formula based on the given lexical semantics
# 2790: can't get a FOL formula based on the given lexical semantics
# 2793: can't get a FOL formula based on the given lexical semantics
# 2794: can't get a FOL formula based on the given lexical semantics
# 2796: can't get a FOL formula based on the given lexical semantics
# 2805: can't get a FOL formula based on the given lexical semantics
# 2819: can't get a FOL formula based on the given lexical semantics
# 2820: can't get a FOL formula based on the given lexical semantics
# 2823: can't get a FOL formula based on the given lexical semantics
# 2824: can't get a FOL formula based on the given lexical semantics
# 2825: can't get a FOL formula based on the given lexical semantics
# 2826: can't get a FOL formula based on the given lexical semantics
# 2841: can't get a FOL formula based on the given lexical semantics
# 2843: can't get a FOL formula based on the given lexical semantics
# 2846: can't get a FOL formula based on the given lexical semantics
# 2852: can't get a FOL formula based on the given lexical semantics
# 2873: can't get a FOL formula based on the given lexical semantics
# 2882: can't get a FOL formula based on the given lexical semantics
# 2888: can't get a FOL formula based on the given lexical semantics
# 2904: can't get a FOL formula based on the given lexical semantics
# 2944: can't get a FOL formula based on the given lexical semantics
# 2949: can't get a FOL formula based on the given lexical semantics
# 2962: can't get a FOL formula based on the given lexical semantics
# 2979: can't get a FOL formula based on the given lexical semantics
# 2987: can't get a FOL formula based on the given lexical semantics
# 2990: can't get a FOL formula based on the given lexical semantics
# 2993: can't get a FOL formula based on the given lexical semantics
# 2999: can't get a FOL formula based on the given lexical semantics
# 3000: can't get a FOL formula based on the given lexical semantics
# 3008: can't get a FOL formula based on the given lexical semantics
# 3011: can't get a FOL formula based on the given lexical semantics
# 3013: can't get a FOL formula based on the given lexical semantics
# 3025: can't get a FOL formula based on the given lexical semantics
# 3035: can't get a FOL formula based on the given lexical semantics
# 3037: can't get a FOL formula based on the given lexical semantics
# 3045: can't get a FOL formula based on the given lexical semantics
# 3052: can't get a FOL formula based on the given lexical semantics
# 3058: can't get a FOL formula based on the given lexical semantics
# 3060: can't get a FOL formula based on the given lexical semantics
# 3066: can't get a FOL formula based on the given lexical semantics
# 3067: can't get a FOL formula based on the given lexical semantics
# 3070: can't get a FOL formula based on the given lexical semantics
# 3090: can't get a FOL formula based on the given lexical semantics
# 3096: can't get a FOL formula based on the given lexical semantics
# 3099: can't get a FOL formula based on the given lexical semantics
# 3101: can't get a FOL formula based on the given lexical semantics
# 3103: can't get a FOL formula based on the given lexical semantics
# 3104: can't get a FOL formula based on the given lexical semantics
# 3106: can't get a FOL formula based on the given lexical semantics
# 3108: can't get a FOL formula based on the given lexical semantics
# 3116: can't get a FOL formula based on the given lexical semantics
# 3120: can't get a FOL formula based on the given lexical semantics
# 3124: can't get a FOL formula based on the given lexical semantics
# 3125: can't get a FOL formula based on the given lexical semantics
# 3131: can't get a FOL formula based on the given lexical semantics
# 3133: can't get a FOL formula based on the given lexical semantics
# 3135: can't get a FOL formula based on the given lexical semantics
# 3137: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# 3144: can't get a FOL formula based on the given lexical semantics
# 3168: can't get a FOL formula based on the given lexical semantics
# 3172: can't get a FOL formula based on the given lexical semantics
# 3190: can't get a FOL formula based on the given lexical semantics
# 3195: can't get a FOL formula based on the given lexical semantics
# 3204: can't get a FOL formula based on the given lexical semantics
# 3205: can't get a FOL formula based on the given lexical semantics
# 3206: can't get a FOL formula based on the given lexical semantics
# 3207: can't get a FOL formula based on the given lexical semantics
# 3209: can't get a FOL formula based on the given lexical semantics
# 3210: can't get a FOL formula based on the given lexical semantics
# 3211: can't get a FOL formula based on the given lexical semantics
# 3212: can't get a FOL formula based on the given lexical semantics
# 3225: can't get a FOL formula based on the given lexical semantics
# 3231: can't get a FOL formula based on the given lexical semantics
# 3234: can't get a FOL formula based on the given lexical semantics
# 3235: can't get a FOL formula based on the given lexical semantics
# 3236: can't get a FOL formula based on the given lexical semantics
# 3237: can't get a FOL formula based on the given lexical semantics
# 3251: can't get a FOL formula based on the given lexical semantics
# 3267: can't get a FOL formula based on the given lexical semantics
# 3276: can't get a FOL formula based on the given lexical semantics
# 3282: can't get a FOL formula based on the given lexical semantics
# 3289: can't get a FOL formula based on the given lexical semantics
# 3293: can't get a FOL formula based on the given lexical semantics
# 3308: can't get a FOL formula based on the given lexical semantics
# 3310: can't get a FOL formula based on the given lexical semantics
# 3333: can't get a FOL formula based on the given lexical semantics
# 3337: can't get a FOL formula based on the given lexical semantics
# 3341: can't get a FOL formula based on the given lexical semantics
# 3343: can't get a FOL formula based on the given lexical semantics
# 3360: can't get a FOL formula based on the given lexical semantics
# 3365: can't get a FOL formula based on the given lexical semantics
# 3381: can't get a FOL formula based on the given lexical semantics
# 3391: can't get a FOL formula based on the given lexical semantics
# 3423: can't get a FOL formula based on the given lexical semantics
# 3430: can't get a FOL formula based on the given lexical semantics
# np/np no such category
# 3431: missing lexical semantics
# 3434: can't get a FOL formula based on the given lexical semantics
# 3458: can't get a FOL formula based on the given lexical semantics
# 3463: can't get a FOL formula based on the given lexical semantics
# 3475: can't get a FOL formula based on the given lexical semantics
# 3481: can't get a FOL formula based on the given lexical semantics
# 3482: can't get a FOL formula based on the given lexical semantics
# 3483: can't get a FOL formula based on the given lexical semantics
# ...
# 9082: can't get a FOL formula based on the given lexical semantics
# 9084: can't get a FOL formula based on the given lexical semantics
# 9088: can't get a FOL formula based on the given lexical semantics
# 9114: can't get a FOL formula based on the given lexical semantics
# 9115: can't get a FOL formula based on the given lexical semantics
# 9116: can't get a FOL formula based on the given lexical semantics
# 9118: can't get a FOL formula based on the given lexical semantics
# 9119: can't get a FOL formula based on the given lexical semantics
# 9120: can't get a FOL formula based on the given lexical semantics
# 9130: can't get a FOL formula based on the given lexical semantics
# 9135: can't get a FOL formula based on the given lexical semantics
# 9138: can't get a FOL formula based on the given lexical semantics
# 9143: can't get a FOL formula based on the given lexical semantics
# 9144: can't get a FOL formula based on the given lexical semantics
# 9145: can't get a FOL formula based on the given lexical semantics
# 9149: can't get a FOL formula based on the given lexical semantics
# 9151: can't get a FOL formula based on the given lexical semantics
# 9152: can't get a FOL formula based on the given lexical semantics
# 9154: can't get a FOL formula based on the given lexical semantics
# 9158: can't get a FOL formula based on the given lexical semantics
# 9164: can't get a FOL formula based on the given lexical semantics
# 9178: can't get a FOL formula based on the given lexical semantics
# 9179: can't get a FOL formula based on the given lexical semantics
# 9180: can't get a FOL formula based on the given lexical semantics
# 9190: can't get a FOL formula based on the given lexical semantics
# 9191: can't get a FOL formula based on the given lexical semantics
# 9195: can't get a FOL formula based on the given lexical semantics
# 9197: can't get a FOL formula based on the given lexical semantics
# 9199: can't get a FOL formula based on the given lexical semantics
# 9201: can't get a FOL formula based on the given lexical semantics
# 9204: can't get a FOL formula based on the given lexical semantics
# 9205: can't get a FOL formula based on the given lexical semantics
# 9207: can't get a FOL formula based on the given lexical semantics
# 9209: can't get a FOL formula based on the given lexical semantics
# 9210: can't get a FOL formula based on the given lexical semantics
# 9218: can't get a FOL formula based on the given lexical semantics
# 9220: can't get a FOL formula based on the given lexical semantics
# 9221: can't get a FOL formula based on the given lexical semantics
# 9225: can't get a FOL formula based on the given lexical semantics
# 9226: can't get a FOL formula based on the given lexical semantics
# 9227: can't get a FOL formula based on the given lexical semantics
# 9228: can't get a FOL formula based on the given lexical semantics
# 9243: can't get a FOL formula based on the given lexical semantics
# 9244: can't get a FOL formula based on the given lexical semantics
# 9245: can't get a FOL formula based on the given lexical semantics
# 9246: can't get a FOL formula based on the given lexical semantics
# 9251: can't get a FOL formula based on the given lexical semantics
# 9252: can't get a FOL formula based on the given lexical semantics
# 9253: can't get a FOL formula based on the given lexical semantics
# 9258: can't get a FOL formula based on the given lexical semantics
# 9260: can't get a FOL formula based on the given lexical semantics
# 9261: can't get a FOL formula based on the given lexical semantics
# 9265: can't get a FOL formula based on the given lexical semantics
# 9266: can't get a FOL formula based on the given lexical semantics
# 9270: can't get a FOL formula based on the given lexical semantics
# 9271: can't get a FOL formula based on the given lexical semantics
# 9283: can't get a FOL formula based on the given lexical semantics
# np/np no such category
# 9286: missing lexical semantics
# 9289: can't get a FOL formula based on the given lexical semantics
# 9290: can't get a FOL formula based on the given lexical semantics
# np/np no such category
# 9291: missing lexical semantics
# 9310: can't get a FOL formula based on the given lexical semantics
# 9311: can't get a FOL formula based on the given lexical semantics
# 9316: can't get a FOL formula based on the given lexical semantics
# 9317: can't get a FOL formula based on the given lexical semantics
# 9318: can't get a FOL formula based on the given lexical semantics
# 9322: other problems
# 9324: other problems
# 9325: other problems
# 9332: can't get a FOL formula based on the given lexical semantics
# 9333: can't get a FOL formula based on the given lexical semantics
# 9334: can't get a FOL formula based on the given lexical semantics
# 9341: can't get a FOL formula based on the given lexical semantics
# 9345: can't get a FOL formula based on the given lexical semantics
# 9346: can't get a FOL formula based on the given lexical semantics
# 9347: can't get a FOL formula based on the given lexical semantics
# 9396: can't get a FOL formula based on the given lexical semantics
# 9397: can't get a FOL formula based on the given lexical semantics
# 9398: can't get a FOL formula based on the given lexical semantics
# 9399: can't get a FOL formula based on the given lexical semantics
# 9403: can't get a FOL formula based on the given lexical semantics
# 9406: can't get a FOL formula based on the given lexical semantics
# 9409: can't get a FOL formula based on the given lexical semantics
# 9410: can't get a FOL formula based on the given lexical semantics
# 9411: can't get a FOL formula based on the given lexical semantics
# 9415: can't get a FOL formula based on the given lexical semantics
# 9416: can't get a FOL formula based on the given lexical semantics
# 9417: can't get a FOL formula based on the given lexical semantics
# 9418: can't get a FOL formula based on the given lexical semantics
# 9419: can't get a FOL formula based on the given lexical semantics
# 9420: can't get a FOL formula based on the given lexical semantics
# 9421: can't get a FOL formula based on the given lexical semantics
# 9422: can't get a FOL formula based on the given lexical semantics
# 9428: can't get a FOL formula based on the given lexical semantics
# 9429: can't get a FOL formula based on the given lexical semantics
# 9432: can't get a FOL formula based on the given lexical semantics
# 9440: can't get a FOL formula based on the given lexical semantics
# 9441: can't get a FOL formula based on the given lexical semantics
# 9443: can't get a FOL formula based on the given lexical semantics
# 9446: can't get a FOL formula based on the given lexical semantics
# 9460: can't get a FOL formula based on the given lexical semantics
# 9463: can't get a FOL formula based on the given lexical semantics
# 9464: can't get a FOL formula based on the given lexical semantics
# 9466: can't get a FOL formula based on the given lexical semantics
# 9468: can't get a FOL formula based on the given lexical semantics
# 9472: can't get a FOL formula based on the given lexical semantics
# 9474: can't get a FOL formula based on the given lexical semantics
# 9486: can't get a FOL formula based on the given lexical semantics
# 9487: can't get a FOL formula based on the given lexical semantics
# 9503: can't get a FOL formula based on the given lexical semantics
# 9507: can't get a FOL formula based on the given lexical semantics
# 9508: can't get a FOL formula based on the given lexical semantics
# 9509: can't get a FOL formula based on the given lexical semantics
# 9511: can't get a FOL formula based on the given lexical semantics
# 9533: can't get a FOL formula based on the given lexical semantics
# 9534: can't get a FOL formula based on the given lexical semantics
# 9536: can't get a FOL formula based on the given lexical semantics
# 9539: can't get a FOL formula based on the given lexical semantics
# 9568: can't get a FOL formula based on the given lexical semantics
# 9573: can't get a FOL formula based on the given lexical semantics
# 9582: can't get a FOL formula based on the given lexical semantics
# 9585: can't get a FOL formula based on the given lexical semantics
# 9597: can't get a FOL formula based on the given lexical semantics
# 9598: can't get a FOL formula based on the given lexical semantics
# 9601: can't get a FOL formula based on the given lexical semantics
# 9603: can't get a FOL formula based on the given lexical semantics
# 9606: can't get a FOL formula based on the given lexical semantics
# 9608: can't get a FOL formula based on the given lexical semantics
# 9611: can't get a FOL formula based on the given lexical semantics
# 9612: can't get a FOL formula based on the given lexical semantics
# 9613: can't get a FOL formula based on the given lexical semantics
# 9614: can't get a FOL formula based on the given lexical semantics
# 9618: can't get a FOL formula based on the given lexical semantics
# 9619: can't get a FOL formula based on the given lexical semantics
# 9620: can't get a FOL formula based on the given lexical semantics
# 9621: can't get a FOL formula based on the given lexical semantics
# 9622: can't get a FOL formula based on the given lexical semantics
# 9625: can't get a FOL formula based on the given lexical semantics
# 9626: can't get a FOL formula based on the given lexical semantics
# 9628: can't get a FOL formula based on the given lexical semantics
# 9629: can't get a FOL formula based on the given lexical semantics
# 9630: can't get a FOL formula based on the given lexical semantics
# 9633: can't get a FOL formula based on the given lexical semantics
# 9640: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# 9654: can't get a FOL formula based on the given lexical semantics
# 9655: can't get a FOL formula based on the given lexical semantics
# 9658: can't get a FOL formula based on the given lexical semantics
# 9660: can't get a FOL formula based on the given lexical semantics
# 9661: can't get a FOL formula based on the given lexical semantics
# 9663: can't get a FOL formula based on the given lexical semantics
# 9664: can't get a FOL formula based on the given lexical semantics
# Could not find a proof: return 'neutral'
# 9671: can't get a FOL formula based on the given lexical semantics
# 9672: can't get a FOL formula based on the given lexical semantics
# 9673: can't get a FOL formula based on the given lexical semantics
# 9674: can't get a FOL formula based on the given lexical semantics
# 9688: can't get a FOL formula based on the given lexical semantics
# 9705: can't get a FOL formula based on the given lexical semantics
# 9707: can't get a FOL formula based on the given lexical semantics
# 9711: can't get a FOL formula based on the given lexical semantics
# 9712: can't get a FOL formula based on the given lexical semantics
# 9714: can't get a FOL formula based on the given lexical semantics
# 9725: can't get a FOL formula based on the given lexical semantics
# 9727: can't get a FOL formula based on the given lexical semantics
# 9728: can't get a FOL formula based on the given lexical semantics
# 9729: can't get a FOL formula based on the given lexical semantics
# 9734: can't get a FOL formula based on the given lexical semantics
# 9735: can't get a FOL formula based on the given lexical semantics
# 9737: can't get a FOL formula based on the given lexical semantics
# 9739: can't get a FOL formula based on the given lexical semantics
# 9740: can't get a FOL formula based on the given lexical semantics
# 9741: can't get a FOL formula based on the given lexical semantics
# 9742: can't get a FOL formula based on the given lexical semantics
# 9743: can't get a FOL formula based on the given lexical semantics
# 9750: can't get a FOL formula based on the given lexical semantics
# 9751: can't get a FOL formula based on the given lexical semantics
# 9754: can't get a FOL formula based on the given lexical semantics
# 9755: can't get a FOL formula based on the given lexical semantics
# 9756: can't get a FOL formula based on the given lexical semantics
# 9761: can't get a FOL formula based on the given lexical semantics
# 9762: can't get a FOL formula based on the given lexical semantics
# 9768: can't get a FOL formula based on the given lexical semantics
# 9772: can't get a FOL formula based on the given lexical semantics
# 9775: can't get a FOL formula based on the given lexical semantics
# 9781: can't get a FOL formula based on the given lexical semantics
# 9783: can't get a FOL formula based on the given lexical semantics
# 9785: can't get a FOL formula based on the given lexical semantics
# 9791: can't get a FOL formula based on the given lexical semantics
# 9792: can't get a FOL formula based on the given lexical semantics
# 9794: can't get a FOL formula based on the given lexical semantics
# 9796: can't get a FOL formula based on the given lexical semantics
# 9797: can't get a FOL formula based on the given lexical semantics
# 9808: can't get a FOL formula based on the given lexical semantics
# 9809: can't get a FOL formula based on the given lexical semantics
# 9813: can't get a FOL formula based on the given lexical semantics
# 9826: can't get a FOL formula based on the given lexical semantics
# 9830: can't get a FOL formula based on the given lexical semantics
# 9831: can't get a FOL formula based on the given lexical semantics
# 9832: can't get a FOL formula based on the given lexical semantics
# 9852: can't get a FOL formula based on the given lexical semantics
# 9854: can't get a FOL formula based on the given lexical semantics
# 9857: can't get a FOL formula based on the given lexical semantics
# 9861: can't get a FOL formula based on the given lexical semantics
# 9862: can't get a FOL formula based on the given lexical semantics
# 9865: can't get a FOL formula based on the given lexical semantics
# 9867: can't get a FOL formula based on the given lexical semantics
# 9872: can't get a FOL formula based on the given lexical semantics
# 9873: can't get a FOL formula based on the given lexical semantics
# 9888: can't get a FOL formula based on the given lexical semantics
# 9890: can't get a FOL formula based on the given lexical semantics
# 9891: can't get a FOL formula based on the given lexical semantics
# 9892: can't get a FOL formula based on the given lexical semantics
# 9894: can't get a FOL formula based on the given lexical semantics
# 9896: can't get a FOL formula based on the given lexical semantics
# 9899: can't get a FOL formula based on the given lexical semantics
# 9901: can't get a FOL formula based on the given lexical semantics
# 9906: can't get a FOL formula based on the given lexical semantics
# 9908: can't get a FOL formula based on the given lexical semantics
# 9918: can't get a FOL formula based on the given lexical semantics
# 9923: can't get a FOL formula based on the given lexical semantics
# 9924: can't get a FOL formula based on the given lexical semantics
# 9925: can't get a FOL formula based on the given lexical semantics
# ((s\np)\ (s\np))/s no such category
# 9932: missing lexical semantics
# 9941: can't get a FOL formula based on the given lexical semantics
# 9945: can't get a FOL formula based on the given lexical semantics
# 9952: can't get a FOL formula based on the given lexical semantics
# 9956: can't get a FOL formula based on the given lexical semantics
# 9959: can't get a FOL formula based on the given lexical semantics
# 9964: can't get a FOL formula based on the given lexical semantics
# 9965: can't get a FOL formula based on the given lexical semantics
# 9966: can't get a FOL formula based on the given lexical semantics
# 9972: can't get a FOL formula based on the given lexical semantics
# 9977: can't get a FOL formula based on the given lexical semantics
# 9979: can't get a FOL formula based on the given lexical semantics
# 9986: can't get a FOL formula based on the given lexical semantics
# 9989: can't get a FOL formula based on the given lexical semantics
# 9990: can't get a FOL formula based on the given lexical semantics
# 9991: can't get a FOL formula based on the given lexical semantics
# 9995: can't get a FOL formula based on the given lexical semantics
# 9996: can't get a FOL formula based on the given lexical semantics

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# result analysis
# accuracy(total)
print("correct problems: ",len(data[data['label'] == data['result']]))
print("total problems: ",len(data))
print("total accuracy: ",len(data[data['label'] == data['result']])/len(data))
print("\n")
# accuracy(translated problems)
translate_data = data[data['p_fol'] != '']
print("correct problems: ",len(translate_data[translate_data['label'] == translate_data['result']]))
print("translated problems: ",len(translate_data))
print("accuracy(translated problems): ",len(translate_data[translate_data['label'] == translate_data['result']])/len(translate_data))
print("\n")
# label distribution
print("the distribution of gold labels:")
print(data['label'].value_counts(normalize = True))
print("\nthe distribution of labels we get:")
print(data['result'].value_counts(normalize = True))
# confusion matrix
print("\nconfusion matrix")
print("contradiction neutral entailment")
print(confusion_matrix(data['label'], data['result']))
print("\n")
# precision
print("precise: ")
print(precision_score(data['label'], data['result'], average=None))
print("\n")
# recall
print("recall: ")
print(recall_score(data['label'], data['result'], average=None))
# Out:
# correct problems:  3471
# total problems:  4927
# total accuracy:  0.7044854881266491
#
#
# correct problems:  2205
# translated problems:  2804
# accuracy(translated problems):  0.786376604850214
#
#
# the distribution of gold labels:
# unknown    0.566876
# yes        0.286990
# no         0.146134
# Name: label, dtype: float64
#
# the distribution of labels we get:
# unknown    0.845545
# yes        0.116704
# no         0.037751
# Name: result, dtype: float64
#
# confusion matrix
# contradiction neutral entailment
# [[ 168  548    4]
#  [  17 2754   22]
#  [   1  864  549]]
#
#
# precise:
# [0.90322581 0.66106577 0.95478261]
#
#
# recall:
# [0.23333333 0.98603652 0.38826025]

# %%
# problems we labeled wrong
wrong_data = data[data['label'] != data['result']]

print("wrong problems: \n")
for i in range(0,len(wrong_data)):
    print(wrong_data.iloc[i]['problem_id'], "label: ", wrong_data.iloc[i]['label'], "   result: ", wrong_data.iloc[i]['result'])
    print("premise: ", wrong_data.iloc[i]['p_sen'])
    print("add_premise: ", wrong_data.iloc[i]['add_fol'])
    print("hypothesis: ", wrong_data.iloc[i]['h_sen'])
    print("\n")
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#
#
# 4008 label:  yes    result:  unknown
# premise:  A man is recklessly climbing a rope
# add_premise:
# hypothesis:  A man is climbing up a rope
#
#
# 4016 label:  no    result:  unknown
# premise:  The woman is putting down the kangaroo
# add_premise:
# hypothesis:  The woman is picking up the kangaroo
#
#
# 4018 label:  yes    result:  unknown
# premise:  The woman is picking up a baby kangaroo
# add_premise:
# hypothesis:  The lady is picking up the kangaroo
#
#
# 4022 label:  no    result:  unknown
# premise:  The woman is not picking up a baby kangaroo
# add_premise:
# hypothesis:  The woman is picking up the kangaroo
#
#
# 4024 label:  yes    result:  unknown
# premise:  The woman is picking up a baby kangaroo
# add_premise:
# hypothesis:  The woman is picking up the kangaroo
#
#
# 4025 label:  yes    result:  unknown
# premise:  A man is breaking tiles with his hands
# add_premise:  []
# hypothesis:  Tiles are being broken with his hands by a man
#
#
# 4027 label:  yes    result:  unknown
# premise:  A man is breaking wooden boards with his hand
# add_premise:
# hypothesis:  A man is breaking boards made of wood with his hand
#
#
# 4048 label:  no    result:  unknown
# premise:  There is no man dancing on the road
# add_premise:
# hypothesis:  A man is dancing on the road
#
#
# 4055 label:  no    result:  unknown
# premise:  A dog is running on the road
# add_premise:
# hypothesis:  There is no dog running on the road
#
#
# 4057 label:  no    result:  unknown
# premise:  There is no man running on the road
# add_premise:
# hypothesis:  A man is running on the road
#
#
# 4064 label:  no    result:  unknown
# premise:  A man is inside the house and is throwing blades at a close target
# add_premise:
# hypothesis:  A man is outside and is throwing blades at a close target
#
#
# 4092 label:  no    result:  unknown
# premise:  The person is not drawing
# add_premise:  []
# hypothesis:  A man is drawing a picture
#
#
# 4101 label:  no    result:  unknown
# premise:  There is no one playing the guitar
# add_premise:
# hypothesis:  Someone is playing the guitar
#
#
# 4110 label:  no    result:  unknown
# premise:  A man is eating a pizza
# add_premise:
# hypothesis:  There is no man eating a pizza
#
#
# 4116 label:  yes    result:  unknown
# premise:  A cute panda is lying down
# add_premise:
# hypothesis:  A panda that is cute is lying down
#
#
# 4128 label:  no    result:  unknown
# premise:  There is no dog bouncing on a trampoline
# add_premise:
# hypothesis:  A dog is bouncing on a trampoline
#
#
# 4139 label:  no    result:  unknown
# premise:  There are no kids jumping on a trampoline
# add_premise:
# hypothesis:  Several kids are jumping on a trampoline
#
#
# 4150 label:  yes    result:  unknown
# premise:  A woman is cutting an onion
# add_premise:  []
# hypothesis:  A woman is not cutting meat
#
#
# 4175 label:  no    result:  unknown
# premise:  A woman is slicing an eggplant
# add_premise:
# hypothesis:  There is no woman slicing an eggplant
#
#
# 4182 label:  no    result:  unknown
# premise:  There is no dog eating a doll
# add_premise:
# hypothesis:  A dog is eating a doll
#
#
# 4184 label:  no    result:  unknown
# premise:  A dog is playing with a toy
# add_premise:
# hypothesis:  There is no dog playing with a toy
#
#
# 4192 label:  yes    result:  unknown
# premise:  A man is dancing
# add_premise:  []
# hypothesis:  A man is performing a dance
#
#
# 4203 label:  yes    result:  unknown
# premise:  A man is cutting a slice of bread
# add_premise:  ['all x.(man(x) -> person(x))', 'all x.(man(x) <-> piece(x))']
# hypothesis:  A person is slicing a piece of bread
#
#
# 4204 label:  no    result:  unknown
# premise:  A person is slicing a piece of bread
# add_premise:  []
# hypothesis:  Nobody is slicing a piece of bread
#
#
# 4206 label:  no    result:  unknown
# premise:  Nobody is slicing a piece of bread
# add_premise:  ['all x.(piece(x) <-> man(x))']
# hypothesis:  A man is slicing some bread
#
#
# 4211 label:  no    result:  unknown
# premise:  There is no woman stroking a lemur
# add_premise:
# hypothesis:  A woman is stroking a lemur
#
#
# 4222 label:  no    result:  unknown
# premise:  The animal with big eyes is sleeping
# add_premise:  []
# hypothesis:  The animal with big eyes is eating
#
#
# 4225 label:  yes    result:  unknown
# premise:  A lemur is eating quickly
# add_premise:  ['all x.(lemur(x) -> animal(x))']
# hypothesis:  The animal with big eyes is eating
#
#
# 4230 label:  yes    result:  unknown
# premise:  Two men are talking
# add_premise:  []
# hypothesis:  Two people are talking
#
#
# 4240 label:  no    result:  unknown
# premise:  There is no man playing an electronic keyboard
# add_premise:
# hypothesis:  A man is playing an electronic keyboard
#
#
# 4249 label:  no    result:  unknown
# premise:  There is no clown singing and people are not dancing
# add_premise:
# hypothesis:  A clown is singing and people are dancing
#
#
# 4255 label:  no    result:  unknown
# premise:  There is no clown singing
# add_premise:
# hypothesis:  A clown is singing and people are dancing
#
#
# 4268 label:  yes    result:  unknown
# premise:  A person is quickly cutting mushrooms with a knife
# add_premise:  []
# hypothesis:  A person is quickly chopping mushrooms with a knife
#
#
# 4270 label:  yes    result:  unknown
# premise:  A person is quickly cutting mushrooms with a knife
# add_premise:  ['all x.(quickly(x) <-> rapidly(x))']
# hypothesis:  A man is rapidly chopping some mushrooms with a knife
#
#
# 4276 label:  no    result:  unknown
# premise:  A man and a woman are shaking hands
# add_premise:  []
# hypothesis:  A man and a woman are not shaking hands
#
#
# 4281 label:  yes    result:  unknown
# premise:  An old woman is shaking hands with a man
# add_premise:  ['all x.(woman(x) -> person(x))', 'all x.(man(x) -> person(x))']
# hypothesis:  Two persons are shaking hands
#
#
# 4285 label:  no    result:  unknown
# premise:  There is no woman chopping up an octopus
# add_premise:
# hypothesis:  A woman is chopping up an octopus
#
#
# 4286 label:  yes    result:  unknown
# premise:  The woman is slicing cooked octopus
# add_premise:
# hypothesis:  The woman is cutting cooked octopus
#
#
# 4292 label:  yes    result:  unknown
# premise:  The woman is cutting cooked octopus
# add_premise:
# hypothesis:  A woman is chopping up an octopus
#
#
# 4294 label:  unknown    result:  yes
# premise:  A plane is landing
# add_premise:  ['all x.(land(x) -> take(x))']
# hypothesis:  A plane is taking off
#
#
# 4296 label:  no    result:  unknown
# premise:  An airplane is taking off
# add_premise:
# hypothesis:  There is no airplane taking off
#
#
# 4297 label:  yes    result:  unknown
# premise:  An aircraft is taking off
# add_premise:  []
# hypothesis:  A plane is taking off
#
#
# 4298 label:  no    result:  unknown
# premise:  A plane is taking off
# add_premise:
# hypothesis:  There is no airplane taking off
#
#
# 4303 label:  no    result:  unknown
# premise:  A man is shooting guns
# add_premise:
# hypothesis:  There is no man shooting guns
#
#
# 4326 label:  yes    result:  unknown
# premise:  The man is painting
# add_premise:  []
# hypothesis:  A man is drawing
#
#
# 4333 label:  yes    result:  unknown
# premise:  A woman is picking a can
# add_premise:
# hypothesis:  A woman is taking a can
#
#
# 4343 label:  no    result:  unknown
# premise:  A man is eating a banana
# add_premise:
# hypothesis:  There is no man eating a banana
#
#
# 4345 label:  no    result:  unknown
# premise:  Someone is peeling a banana
# add_premise:
# hypothesis:  There is no one peeling a banana
#
#
# 4352 label:  no    result:  unknown
# premise:  There is no dog barking
# add_premise:
# hypothesis:  A dog is barking
#
#
# 4374 label:  no    result:  unknown
# premise:  Someone is playing a piano
# add_premise:
# hypothesis:  There is no one playing a piano
#
#
# 4380 label:  yes    result:  unknown
# premise:  A shoe is being tied by a man
# add_premise:  []
# hypothesis:  A man is tying a shoe
#
#
# 4383 label:  no    result:  unknown
# premise:  There is no man tying a shoe
# add_premise:
# hypothesis:  A man is tying a shoe
#
#
# 4391 label:  yes    result:  unknown
# premise:  A man is riding a horse in the desert
# add_premise:  []
# hypothesis:  A man is riding a horse in a sandy land
#
#
# 4397 label:  yes    result:  unknown
# premise:  A man is riding a horse in the desert
# add_premise:  []
# hypothesis:  A guy is riding a horse
#
#
# 4399 label:  no    result:  unknown
# premise:  There is no man cutting a paper plate
# add_premise:
# hypothesis:  A man is cutting a paper plate
#
#
# 4405 label:  no    result:  unknown
# premise:  There is no man cutting a paper plate
# add_premise:
# hypothesis:  The man is cutting a paper plate
#
#
# 4409 label:  yes    result:  unknown
# premise:  Two men in a race are flipping the tires of a tractor
# add_premise:  []
# hypothesis:  Two people in a race are flipping the tires of a tractor
#
#
# 4413 label:  yes    result:  unknown
# premise:  Two people in a race are flipping the tires of a tractor
# add_premise:  []
# hypothesis:  Two men are racing in a tire rolling competition
#
#
# 4416 label:  yes    result:  unknown
# premise:  An alligator is being patted on the mouth by a man
# add_premise:  ['all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  A man is patting an alligator on the mouth
#
#
# 4419 label:  no    result:  unknown
# premise:  A person is removing chopped vegetables from a pot on the stove
# add_premise:  []
# hypothesis:  A person is dropping chopped vegetables into a pot on the stove
#
#
# 4425 label:  yes    result:  unknown
# premise:  The men are having a conversation
# add_premise:  []
# hypothesis:  The men are talking
#
#
# 4427 label:  yes    result:  unknown
# premise:  Some old women are talking
# add_premise:
# hypothesis:  Some women are talking
#
#
# 4428 label:  unknown    result:  no
# premise:  Some women are talking
# add_premise:  []
# hypothesis:  Some women are not talking
#
#
# 4435 label:  no    result:  unknown
# premise:  A man is playing the guitar
# add_premise:
# hypothesis:  There is no man playing the guitar
#
#
# 4437 label:  no    result:  unknown
# premise:  A woman is putting on lipstick
# add_premise:
# hypothesis:  There is no woman putting on lipstick
#
#
# 4444 label:  no    result:  unknown
# premise:  There is no man singing to a woman
# add_premise:
# hypothesis:  A man is singing to a woman
#
#
# 4448 label:  unknown    result:  no
# premise:  A man is singing to a woman
# add_premise:  ['all x.(sing(x) -> talk(x))', 'all x.(sing(x) <-> talk(x))']
# hypothesis:  A man is not talking on the phone
#
#
# 4453 label:  no    result:  unknown
# premise:  A rhino is grazing in a field
# add_premise:
# hypothesis:  There is no rhino grazing in a field
#
#
# 4455 label:  no    result:  unknown
# premise:  The rhino is grazing on the grass
# add_premise:  []
# hypothesis:  The rhino is not grazing on the grass
#
#
# 4459 label:  no    result:  unknown
# premise:  There is no rhino grazing in a field
# add_premise:
# hypothesis:  The rhino is grazing on the grass
#
#
# 4460 label:  yes    result:  unknown
# premise:  A rhino is grazing in a field
# add_premise:  []
# hypothesis:  The rhino is grazing on the grass
#
#
# 4462 label:  no    result:  unknown
# premise:  There is no couple running towards the ocean
# add_premise:
# hypothesis:  A couple is running towards the ocean
#
#
# 4463 label:  yes    result:  unknown
# premise:  A man and a woman are running together and holding hands
# add_premise:
# hypothesis:  A couple is running and holding hands
#
#
# 4479 label:  yes    result:  unknown
# premise:  The boy is playing the piano
# add_premise:  ['all x.(piano(x) -> instrument(x))']
# hypothesis:  The boy is playing a musical instrument
#
#
# 4489 label:  no    result:  unknown
# premise:  There is no girl brushing her hair
# add_premise:
# hypothesis:  A girl is brushing her hair
#
#
# 4494 label:  yes    result:  unknown
# premise:  A girl is combing her hair
# add_premise:  []
# hypothesis:  A girl is styling her hair
#
#
# 4499 label:  yes    result:  unknown
# premise:  The patient is being helped by the doctor
# add_premise:  ['all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  The doctor is helping the patient
#
#
# 4506 label:  unknown    result:  no
# premise:  The doctor is helping the patient
# add_premise:  []
# hypothesis:  The doctors are not reviving a man
#
#
# 4518 label:  no    result:  unknown
# premise:  There is no man playing a flute
# add_premise:
# hypothesis:  A man is playing a flute
#
#
# 4527 label:  no    result:  unknown
# premise:  There is no man driving a car
# add_premise:
# hypothesis:  A man is driving a car
#
#
# 4538 label:  no    result:  unknown
# premise:  There is no cat sliding upside down under a couch
# add_premise:
# hypothesis:  A cat is sliding upside down under a couch
#
#
# 4542 label:  no    result:  unknown
# premise:  A cat is sliding upside down under a couch
# add_premise:  ['all x.(couch(x) -> furniture(x))']
# hypothesis:  A cat is not crawling under a piece of furniture
#
#
# 4547 label:  no    result:  unknown
# premise:  A woman is riding a horse
# add_premise:
# hypothesis:  There is no woman riding a horse
#
#
# 4554 label:  no    result:  unknown
# premise:  A man is emptying a plastic container
# add_premise:  ['all x.(empty(x) -> -fill(x))', 'all x.(fill(x) -> -empty(x))']
# hypothesis:  A man is filling a plastic container
#
#
# 4563 label:  no    result:  unknown
# premise:  Some men are fighting
# add_premise:
# hypothesis:  There are no men fighting
#
#
# 4568 label:  yes    result:  unknown
# premise:  A group of men is fighting
# add_premise:  []
# hypothesis:  Two men are fighting
#
#
# 4572 label:  no    result:  unknown
# premise:  There is no policewoman singing at karaoke
# add_premise:
# hypothesis:  A couple of policewomen are singing karaoke
#
#
# 4589 label:  yes    result:  unknown
# premise:  A hamster is singing
# add_premise:  ['all x.(hamster(x) -> animal(x))']
# hypothesis:  A small animal is singing
#
#
# 4599 label:  no    result:  unknown
# premise:  There is no man playing a guitar
# add_premise:
# hypothesis:  A man is playing a guitar
#
#
# 4600 label:  yes    result:  unknown
# premise:  A man is singing and playing a guitar
# add_premise:
# hypothesis:  A man is performing with a guitar
#
#
# 4602 label:  yes    result:  unknown
# premise:  A man is performing with a guitar
# add_premise:  []
# hypothesis:  A man is playing a guitar
#
#
# 4604 label:  yes    result:  unknown
# premise:  A man is singing and playing a guitar
# add_premise:
# hypothesis:  A guitar is being played by a man
#
#
# 4608 label:  no    result:  unknown
# premise:  A man is driving a car
# add_premise:
# hypothesis:  There is no man driving a car
#
#
# 4620 label:  yes    result:  unknown
# premise:  The boy is shortening the grass by the curb with scissors
# add_premise:  ['all x.(shorten(x) -> cut(x))', 'all x.(shorten(x) <-> cut(x))']
# hypothesis:  A boy is cutting grass with scissors
#
#
# 4622 label:  yes    result:  unknown
# premise:  The boy is cutting the grass by the curb with scissors
# add_premise:  ['all x.(boy(x) -> kid(x))']
# hypothesis:  A kid is cutting grass with scissors
#
#
# 4623 label:  no    result:  unknown
# premise:  The boy is cutting the grass by the curb with scissors
# add_premise:
# hypothesis:  There is no boy cutting grass with scissors
#
#
# 4624 label:  yes    result:  unknown
# premise:  The boy is cutting the grass by the curb with scissors
# add_premise:  []
# hypothesis:  A boy is cutting grass with scissors
#
#
# 4628 label:  no    result:  unknown
# premise:  The baby is not laughing and crawling
# add_premise:
# hypothesis:  The baby is laughing and crawling
#
#
# 4647 label:  yes    result:  unknown
# premise:  A man is cutting a big rope with a sword
# add_premise:  []
# hypothesis:  A man is cutting a rope with a sword
#
#
# 4649 label:  yes    result:  unknown
# premise:  A man is cutting a thick rope with a sword
# add_premise:  []
# hypothesis:  A man is cutting a cord with a sword
#
#
# 4654 label:  yes    result:  unknown
# premise:  A man is walking along a path through a wilderness
# add_premise:  ['all x.(path(x) <-> track(x))']
# hypothesis:  A man is walking along a track through a wilderness
#
#
# 4655 label:  no    result:  unknown
# premise:  There is no man walking along a path through a wilderness
# add_premise:
# hypothesis:  A man is walking along a path through a wilderness
#
#
# 4675 label:  yes    result:  unknown
# premise:  A man is drilling a hole in a piece of wood
# add_premise:  ['all x.(man(x) -> someone(x))', 'all x.(piece(x) -> make(x))']
# hypothesis:  Someone is making a hole in a strip of wood with a drill
#
#
# 4684 label:  no    result:  unknown
# premise:  A woman is slicing garlic
# add_premise:  []
# hypothesis:  A woman is not slicing garlic
#
#
# 4690 label:  yes    result:  unknown
# premise:  A man is holding a small animal in one hand
# add_premise:  []
# hypothesis:  A man is holding an ani
#
#
# 4692 label:  yes    result:  unknown
# premise:  A man is showing off a small monkey
# add_premise:
# hypothesis:  A man is exhibiting a small monkey
#
#
# 4706 label:  unknown    result:  no
# premise:  A group of men is playing soccer on the beach
# add_premise:  []
# hypothesis:  A group of boys is not playing soccer on the beach
#
#
# 4708 label:  yes    result:  unknown
# premise:  A man is cutting pieces of butter into a mixing bowl
# add_premise:  []
# hypothesis:  A man is adding pieces of butter to a mixing bowl
#
#
# 4709 label:  no    result:  unknown
# premise:  A man is cutting pieces of butter into a mixing bowl
# add_premise:
# hypothesis:  There is no man cutting pieces of butter into a mixing bowl
#
#
# 4721 label:  no    result:  unknown
# premise:  A monkey is practicing martial arts
# add_premise:
# hypothesis:  There is no monkey practicing martial arts
#
#
# 4732 label:  yes    result:  unknown
# premise:  A man is fixing a silencer to a gun
# add_premise:  ['all x.(gun(x) -> weapon(x))']
# hypothesis:  A man is fitting a silencer to a weapon
#
#
# 4733 label:  no    result:  unknown
# premise:  There is no man fitting a silencer to a pistol
# add_premise:
# hypothesis:  A man is fixing a silencer to a gun
#
#
# 4736 label:  yes    result:  unknown
# premise:  A man is fitting a silencer to a pistol
# add_premise:  ['all x.(pistol(x) -> gun(x))']
# hypothesis:  A man is fixing a silencer to a gun
#
#
# 4737 label:  yes    result:  unknown
# premise:  A man on a motorcycle is riding on one wheel
# add_premise:  []
# hypothesis:  A man on a motorcycle is doing a trick
#
#
# 4739 label:  yes    result:  unknown
# premise:  A person is performing acrobatics on a motorcycle
# add_premise:  []
# hypothesis:  A person is performing tricks on a motorcycle
#
#
# 4747 label:  yes    result:  unknown
# premise:  A man on a motorcycle is riding on one wheel
# add_premise:  ['all x.(man(x) -> person(x))']
# hypothesis:  A person is performing tricks on a motorcycle
#
#
# 4748 label:  yes    result:  unknown
# premise:  A little girl is playing the violin on a beach
# add_premise:  ['all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  The violin is being played by a little girl on a beach
#
#
# 4749 label:  no    result:  unknown
# premise:  A little girl is playing the violin on a beach
# add_premise:
# hypothesis:  There is no girl playing the violin on a beach
#
#
# 4750 label:  yes    result:  unknown
# premise:  The girl is sitting on the couch and is crocheting
# add_premise:
# hypothesis:  The girl is sitting on the sofa and crocheting
#
#
# 4768 label:  yes    result:  unknown
# premise:  The man is dropping sliced cucumbers into cold water
# add_premise:  []
# hypothesis:  The man is dropping sliced cucumbers into water
#
#
# 4784 label:  yes    result:  unknown
# premise:  A soda is being opened and drunk by a woman
# add_premise:
# hypothesis:  A woman is opening a soda and drinking it
#
#
# 4786 label:  yes    result:  unknown
# premise:  A woman is riding on an elephant
# add_premise:  ['all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  An elephant is being ridden by a woman
#
#
# 4787 label:  no    result:  unknown
# premise:  There is no woman riding on an elephant
# add_premise:
# hypothesis:  A woman is riding on an elephant
#
#
# 4818 label:  no    result:  unknown
# premise:  There is no person slicing an onion
# add_premise:
# hypothesis:  A person is slicing an onion
#
#
# 4827 label:  no    result:  unknown
# premise:  A man is slicing a potato into pieces
# add_premise:
# hypothesis:  There is no man slicing a potato into pieces
#
#
# 4828 label:  yes    result:  unknown
# premise:  A man is cutting a potato into pieces
# add_premise:  []
# hypothesis:  A man is cutting a potato
#
#
# 4829 label:  no    result:  unknown
# premise:  A man is cutting a potato
# add_premise:
# hypothesis:  There is no man slicing a potato into pieces
#
#
# 4830 label:  yes    result:  unknown
# premise:  A man is slicing a potato
# add_premise:  []
# hypothesis:  A man is slicing a potato into pieces
#
#
# 4834 label:  no    result:  unknown
# premise:  There is no girl filing her nails
# add_premise:
# hypothesis:  A girl is filing her nails
#
#
# 4854 label:  no    result:  unknown
# premise:  A man is playing an electronic keyboard
# add_premise:
# hypothesis:  There is no man playing an electronic keyboard
#
#
# 4870 label:  no    result:  unknown
# premise:  A woman is cutting potatoes
# add_premise:
# hypothesis:  There is no woman cutting potatoes
#
#
# 4878 label:  yes    result:  unknown
# premise:  A man is mixing vegetables in a pot
# add_premise:  ['all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  Vegetables are being mixed in a pot by a man
#
#
# 4884 label:  yes    result:  unknown
# premise:  Vegetables are being mixed in a pot by a man
# add_premise:  ['all x.(man(x) -> person(x))', 'all x.(vegetables(x) <-> vegetable(x))', 'all x.(patient(x) -> person(x))', 'all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  A person is stirring vegetables in a pot
#
#
# 4887 label:  yes    result:  unknown
# premise:  A man is doing pull-ups
# add_premise:
# hypothesis:  A man is doing exercises
#
#
# 4889 label:  yes    result:  unknown
# premise:  The man is doing exercises in a gym
# add_premise:  []
# hypothesis:  The man is exercising
#
#
# 4892 label:  no    result:  unknown
# premise:  The man is not exercising
# add_premise:
# hypothesis:  A man is doing pull-ups
#
#
# 4893 label:  yes    result:  unknown
# premise:  The man is exercising
# add_premise:  []
# hypothesis:  A man is doing exercises
#
#
# 4895 label:  yes    result:  unknown
# premise:  A man is doing pull-ups
# add_premise:
# hypothesis:  The man is exercising
#
#
# 4897 label:  no    result:  unknown
# premise:  There is no man carrying a woman
# add_premise:
# hypothesis:  A man is carrying a woman
#
#
# 4899 label:  no    result:  unknown
# premise:  There is no man sharpening a knife
# add_premise:
# hypothesis:  A man is sharpening a knife
#
#
# 4907 label:  yes    result:  unknown
# premise:  A cat is walking on the parquet
# add_premise:  ['all x.(parquet(x) -> floor(x))']
# hypothesis:  A cat is walking on a hardwood floor
#
#
# 4908 label:  no    result:  unknown
# premise:  A cat is walking on a hardwood floor
# add_premise:
# hypothesis:  There is no cat walking on a hardwood floor
#
#
# 4917 label:  no    result:  unknown
# premise:  A man is singing and playing a guitar
# add_premise:
# hypothesis:  There is no man singing and playing a guitar
#
#
# 4935 label:  yes    result:  unknown
# premise:  The military officer is shouting at the recruits
# add_premise:  []
# hypothesis:  The military officer is barking at the recruits
#
#
# 4955 label:  no    result:  unknown
# premise:  A child is walking down the street and a jeep is pulling up
# add_premise:
# hypothesis:  A child is walking down the street and a jeep is not pulling up
#
#
# 4956 label:  yes    result:  unknown
# premise:  A man in a car is pulling up beside a woman who is walking along the street
# add_premise:
# hypothesis:  A man in a car is pulling up beside a woman that is who along a road
#
#
# 4972 label:  yes    result:  unknown
# premise:  An onion is being chopped
# add_premise:  []
# hypothesis:  An onion is being sliced
#
#
# 4999 label:  yes    result:  unknown
# premise:  A big cat is opening a drawer made of plastic with its paws and is jumping inside
# add_premise:
# hypothesis:  A big cat is opening a plastic drawer with its paws and is jumping inside
#
#
# 5001 label:  yes    result:  unknown
# premise:  A cat is opening a drawer and jumping inside
# add_premise:
# hypothesis:  A cat is opening a drawer and climbing inside
#
#
# 5006 label:  yes    result:  unknown
# premise:  A small cat is opening a plastic drawer with its paws and jumping inside
# add_premise:
# hypothesis:  A cat is opening a drawer and climbing inside
#
#
# 5008 label:  yes    result:  unknown
# premise:  A man is cutting an onion
# add_premise:  []
# hypothesis:  A man is chopping an onion
#
#
# 5009 label:  no    result:  unknown
# premise:  There is no man cutting an onion
# add_premise:
# hypothesis:  A man is cutting an onion
#
#
# 5020 label:  yes    result:  unknown
# premise:  Makeup is being put on the man by the woman
# add_premise:  []
# hypothesis:  The woman is putting makeup on the man
#
#
# 5034 label:  no    result:  unknown
# premise:  The man is talking on the phone
# add_premise:  ['all x.(phone(x) <-> telephone(x))']
# hypothesis:  The man is not talking on the telephone
#
#
# 5042 label:  no    result:  unknown
# premise:  A woman is cutting an onion
# add_premise:
# hypothesis:  There is no woman cutting an onion
#
#
# 5055 label:  unknown    result:  no
# premise:  A man is not cutting an onion
# add_premise:  []
# hypothesis:  A man is opening a door
#
#
# 5059 label:  yes    result:  unknown
# premise:  A man is chopping a potato
# add_premise:  []
# hypothesis:  A man is slicing a potato
#
#
# 5062 label:  no    result:  unknown
# premise:  There is no man slicing a potato
# add_premise:
# hypothesis:  A man is cutting a potato
#
#
# 5069 label:  no    result:  unknown
# premise:  A woman is frying something in a pan
# add_premise:
# hypothesis:  There is no woman frying something in a pan
#
#
# 5076 label:  no    result:  unknown
# premise:  A man is playing the piano
# add_premise:
# hypothesis:  There is no man playing the piano
#
#
# 5084 label:  unknown    result:  yes
# premise:  A man is fishing in the river
# add_premise:  ['all x.(river(x) -> stream(x))']
# hypothesis:  A man is fishing in the stream
#
#
# 5094 label:  no    result:  unknown
# premise:  A man is loading a rifle with bullets
# add_premise:
# hypothesis:  There is no man loading a rifle with bullets
#
#
# 5095 label:  yes    result:  unknown
# premise:  A woman is seasoning a ham
# add_premise:  ['all x.(ham(x) -> meat(x))']
# hypothesis:  A woman is seasoning a piece of meat
#
#
# 5111 label:  yes    result:  unknown
# premise:  A man is riding a water toy in the water
# add_premise:  []
# hypothesis:  A man is playing with a water toy in the water
#
#
# 5112 label:  no    result:  unknown
# premise:  A man is riding a water toy in the water
# add_premise:
# hypothesis:  There is no man riding a water toy in the water
#
#
# 5129 label:  yes    result:  unknown
# premise:  A man is sprinkling shredded cheese on a pizza
# add_premise:  []
# hypothesis:  A man is sprinkling cheese on a pizza
#
#
# 5130 label:  no    result:  unknown
# premise:  A man is sprinkling shredded cheese on a pizza
# add_premise:
# hypothesis:  There is no man sprinkling shredded cheese on a pizza
#
#
# 5140 label:  yes    result:  unknown
# premise:  A man is having fun with water
# add_premise:  ['all x.(fun(x) <-> play(x))']
# hypothesis:  A man is playing with water
#
#
# 5150 label:  no    result:  unknown
# premise:  A lemur is hanging on a cord
# add_premise:
# hypothesis:  There is no lemur hanging on a cord
#
#
# 5157 label:  no    result:  unknown
# premise:  There is no woman putting a child in a waste bin
# add_premise:
# hypothesis:  A woman is putting a baby in a waste bin
#
#
# 5158 label:  yes    result:  unknown
# premise:  The woman is poking holes in the potato
# add_premise:  []
# hypothesis:  The woman is poking a potato
#
#
# 5159 label:  no    result:  unknown
# premise:  The woman is poking a potato
# add_premise:  []
# hypothesis:  The woman is not poking holes in the potato
#
#
# 5165 label:  yes    result:  unknown
# premise:  A man is pouring cleaner into the sink
# add_premise:  ['all x.(cleaner(x) <-> clean(x))']
# hypothesis:  A man is cleaning the sink
#
#
# 5174 label:  yes    result:  unknown
# premise:  A woman is deep frying food
# add_premise:
# hypothesis:  Food is being deep fried by a woman
#
#
# 5179 label:  no    result:  unknown
# premise:  A woman is not frying some food
# add_premise:
# hypothesis:  A woman is deep frying food
#
#
# 5181 label:  no    result:  unknown
# premise:  A woman is frying some food
# add_premise:
# hypothesis:  There is no woman deep frying food
#
#
# 5182 label:  yes    result:  unknown
# premise:  A woman is deep frying food
# add_premise:
# hypothesis:  A woman is frying some food
#
#
# 5193 label:  no    result:  unknown
# premise:  There is no baby talking
# add_premise:
# hypothesis:  A baby is talking
#
#
# 5194 label:  yes    result:  unknown
# premise:  A boy is saying a word
# add_premise:  []
# hypothesis:  A boy is saying something
#
#
# 5211 label:  no    result:  unknown
# premise:  There is no man riding a motorcycle
# add_premise:
# hypothesis:  A man is riding a motorcycle
#
#
# 5228 label:  yes    result:  unknown
# premise:  A tiger cub is roaring
# add_premise:  ['all x.(roar(x) -> sound(x))']
# hypothesis:  A tiger cub is making a sound
#
#
# 5229 label:  no    result:  unknown
# premise:  A tiger cub is making a sound
# add_premise:
# hypothesis:  There is no tiger cub making a sound
#
#
# 5230 label:  yes    result:  unknown
# premise:  A tiger is walking around
# add_premise:  []
# hypothesis:  A tiger is strolling around
#
#
# 5240 label:  no    result:  unknown
# premise:  A woman is placing food in a pot of hot water
# add_premise:  ['all x.(hot(x) -> -cold(x))', 'all x.(cold(x) -> -hot(x))']
# hypothesis:  A woman is placing food in a pot of cold water
#
#
# 5271 label:  no    result:  unknown
# premise:  Someone is folding a piece of paper
# add_premise:  ['all x.(someone(x) <-> person(x))']
# hypothesis:  A person is not folding a piece of paper
#
#
# 5273 label:  yes    result:  unknown
# premise:  A girl is using sign language
# add_premise:  []
# hypothesis:  A girl is communicating with sign language
#
#
# 5274 label:  no    result:  unknown
# premise:  There is no girl communicating with sign language
# add_premise:
# hypothesis:  A girl is communicating with sign language
#
#
# 5280 label:  no    result:  unknown
# premise:  A young girl is using sign language
# add_premise:
# hypothesis:  There is no girl communicating with sign language
#
#
# 5281 label:  yes    result:  unknown
# premise:  A girl is communicating with sign language
# add_premise:  []
# hypothesis:  A young girl is using sign language
#
#
# 5283 label:  no    result:  unknown
# premise:  A bunny is playing with a stuffed bunny
# add_premise:
# hypothesis:  There is no bunny playing with a stuffed bunny
#
#
# 5284 label:  yes    result:  unknown
# premise:  A rabbit is playing with a toy rabbit
# add_premise:  []
# hypothesis:  A rabbit is playing with a toy
#
#
# 5285 label:  no    result:  unknown
# premise:  There is no rabbit playing with a toy rabbit
# add_premise:
# hypothesis:  A rabbit is playing with a toy rabbit
#
#
# 5286 label:  yes    result:  unknown
# premise:  A bunny is playing with a stuffed bunny
# add_premise:  ['all x.(bunny(x) -> rabbit(x))']
# hypothesis:  A rabbit is playing with a toy
#
#
# 5287 label:  no    result:  unknown
# premise:  There is no rabbit playing with a toy rabbit
# add_premise:
# hypothesis:  A bunny is playing with a stuffed bunny
#
#
# 5289 label:  no    result:  unknown
# premise:  A rabbit is playing with a toy rabbit
# add_premise:
# hypothesis:  There is no bunny playing with a stuffed bunny
#
#
# 5290 label:  yes    result:  unknown
# premise:  A bunny is playing with a stuffed bunny
# add_premise:  ['all x.(bunny(x) -> rabbit(x))']
# hypothesis:  A rabbit is playing with a toy rabbit
#
#
# 5301 label:  no    result:  unknown
# premise:  There is no man slicing potatoes
# add_premise:
# hypothesis:  A man is slicing potatoes
#
#
# 5307 label:  no    result:  unknown
# premise:  The man is slicing a potato
# add_premise:
# hypothesis:  There is no man slicing potatoes
#
#
# 5315 label:  yes    result:  unknown
# premise:  A flute is being played by a girl
# add_premise:  ['all x.(flute(x) -> wind(x))', 'all x.(flute(x) -> instrument(x))', 'all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  A girl is playing a wind instrument
#
#
# 5323 label:  unknown    result:  no
# premise:  Someone is not playing piano
# add_premise:  ['all x.(someone(x) <-> person(x))', 'all x.(piano(x) -> keyboard(x))']
# hypothesis:  A person is playing a keyboard
#
#
# 5336 label:  yes    result:  unknown
# premise:  The man is adding seasoning to the water in a bowl
# add_premise:  []
# hypothesis:  Seasoning is being added to the water by the man
#
#
# 5337 label:  no    result:  unknown
# premise:  The man is adding seasoning to the water in a bowl
# add_premise:  []
# hypothesis:  The man is not adding seasoning to the/some water in a bowl
#
#
# 5364 label:  no    result:  unknown
# premise:  A man is playing a flute
# add_premise:
# hypothesis:  There is no man playing a flute
#
#
# 5388 label:  unknown    result:  no
# premise:  A man is not playing the drums
# add_premise:  []
# hypothesis:  A man is playing the guitar
#
#
# 5394 label:  yes    result:  unknown
# premise:  The man is putting chicken into the box
# add_premise:  ['all x.(chicken(x) -> food(x))']
# hypothesis:  A man is putting some food in a box
#
#
# 5396 label:  yes    result:  unknown
# premise:  The man is putting chicken into the container
# add_premise:  ['all x.(chicken(x) -> food(x))']
# hypothesis:  A man is putting some food in a container
#
#
# 5402 label:  no    result:  unknown
# premise:  A woman is placing skewers onto a rack
# add_premise:
# hypothesis:  There is no woman placing skewers onto a rack
#
#
# 5410 label:  yes    result:  unknown
# premise:  The little boy is singing and playing the guitar
# add_premise:
# hypothesis:  The little kid is singing and playing the guitar
#
#
# 5412 label:  yes    result:  unknown
# premise:  The little kid is singing and playing the guitar
# add_premise:
# hypothesis:  A baby is playing a guitar
#
#
# 5428 label:  yes    result:  unknown
# premise:  Someone is checking the email
# add_premise:  []
# hypothesis:  Someone is reading the email
#
#
# 5430 label:  yes    result:  unknown
# premise:  A man is reading the email
# add_premise:  ['all x.(man(x) -> someone(x))']
# hypothesis:  Someone is checking the email
#
#
# 5431 label:  no    result:  unknown
# premise:  Someone is not reading the email
# add_premise:  []
# hypothesis:  A man is reading the email
#
#
# 5444 label:  yes    result:  unknown
# premise:  Fish is being cooked by a woman
# add_premise:  ['all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  A woman is cooking fish
#
#
# 5445 label:  no    result:  unknown
# premise:  A woman is cooking fish
# add_premise:
# hypothesis:  There is no woman cooking fish
#
#
# 5451 label:  no    result:  unknown
# premise:  A woman is frying fish
# add_premise:
# hypothesis:  There is no woman cooking fish
#
#
# 5465 label:  no    result:  unknown
# premise:  There is no man mowing grass
# add_premise:
# hypothesis:  A man is mowing grass
#
#
# 5469 label:  no    result:  unknown
# premise:  A man is mowing grass
# add_premise:
# hypothesis:  There is no guy mowing the lawn
#
#
# 5484 label:  yes    result:  unknown
# premise:  The lady is cracking an egg into a bowl
# add_premise:  ['all x.(lady(x) -> person(x))']
# hypothesis:  The person is cracking eggs into a bowl
#
#
# 5485 label:  yes    result:  unknown
# premise:  The woman is cracking eggs into a bowl
# add_premise:  ['all x.(woman(x) -> lady(x))']
# hypothesis:  The lady is cracking an egg into a bowl
#
#
# 5490 label:  no    result:  unknown
# premise:  There is no man cutting tomatoes
# add_premise:
# hypothesis:  A man is cutting tomatoes
#
#
# 5508 label:  no    result:  unknown
# premise:  There is no man playing guitar
# add_premise:
# hypothesis:  A man is playing guitar
#
#
# 5544 label:  no    result:  unknown
# premise:  There is no man working on the laptop
# add_premise:
# hypothesis:  A man is working on the laptop
#
#
# 5562 label:  no    result:  unknown
# premise:  There is no girl riding a horse
# add_premise:
# hypothesis:  A girl is riding a horse
#
#
# 5567 label:  yes    result:  unknown
# premise:  The girl is trotting on the horse
# add_premise:  ['all x.(trot(x) -> ride(x))', 'all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  A horse is being ridden by a girl
#
#
# 5570 label:  yes    result:  unknown
# premise:  A man is breaking a slab of concrete with a sledge hammer
# add_premise:  ['all x.(slab(x) -> block(x))']
# hypothesis:  A man is breaking a block of concrete with a sledge hammer
#
#
# 5571 label:  no    result:  unknown
# premise:  A man is breaking a slab of concrete with a sledge hammer
# add_premise:
# hypothesis:  There is no man breaking a slab of concrete with a sledge hammer
#
#
# 5572 label:  yes    result:  unknown
# premise:  The man is using a sledgehammer to break a concrete block that is on another man
# add_premise:
# hypothesis:  The man is using a sledgehammer to break a concrete block that is on another person
#
#
# 5574 label:  yes    result:  unknown
# premise:  The man is using a sledgehammer to break a concrete block that is on another person
# add_premise:
# hypothesis:  A man is breaking a slab of concrete with a sledge hammer
#
#
# 5576 label:  yes    result:  unknown
# premise:  The man is using a sledgehammer to break a concrete block that is on another man
# add_premise:
# hypothesis:  A man is breaking a block of concrete with a sledge hammer
#
#
# 5577 label:  no    result:  unknown
# premise:  There is no man breaking a slab of concrete with a sledge hammer
# add_premise:
# hypothesis:  The man is using a sledgehammer to break a concrete block that is on another man
#
#
# 5578 label:  yes    result:  unknown
# premise:  The man is using a sledgehammer to break a concrete block that is on another man
# add_premise:
# hypothesis:  A man is breaking a slab of concrete with a sledge hammer
#
#
# 5590 label:  unknown    result:  yes
# premise:  A woman is eating a cupcake
# add_premise:  ['all x.(cupcake(x) -> cake(x))']
# hypothesis:  A woman is eating a cake
#
#
# 5592 label:  unknown    result:  yes
# premise:  A girl is eating a cupcake
# add_premise:  ['all x.(girl(x) -> woman(x))', 'all x.(cupcake(x) -> cake(x))']
# hypothesis:  A woman is eating a cake
#
#
# 5594 label:  unknown    result:  yes
# premise:  A cupcake is being eaten by a girl
# add_premise:  ['all x.(girl(x) -> woman(x))', 'all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  A woman is eating a cupcake
#
#
# 5596 label:  unknown    result:  yes
# premise:  A girl is eating a cupcake
# add_premise:  ['all x.(girl(x) -> woman(x))']
# hypothesis:  A woman is eating a cupcake
#
#
# 5598 label:  no    result:  unknown
# premise:  A man is speaking
# add_premise:
# hypothesis:  There is no man speaking
#
#
# 5600 label:  no    result:  unknown
# premise:  There is no man spitting
# add_premise:
# hypothesis:  A man is spitting
#
#
# 5606 label:  yes    result:  unknown
# premise:  A man is playing keyboards
# add_premise:  []
# hypothesis:  A man is playing an instrument
#
#
# 5616 label:  no    result:  unknown
# premise:  A man is cutting a boot with a sword
# add_premise:
# hypothesis:  There is no man cutting a boot with a sword
#
#
# 5622 label:  no    result:  unknown
# premise:  There is no man cutting a boot with a sword
# add_premise:
# hypothesis:  A man is severing the toe of an empty leather boot with a sword
#
#
# 5626 label:  yes    result:  unknown
# premise:  A man is wiping the edge of a bowl
# add_premise:  []
# hypothesis:  A man is cleaning the edge of a bowl
#
#
# 5635 label:  yes    result:  unknown
# premise:  A young boy is singing and playing a guitar
# add_premise:
# hypothesis:  A kid is singing and playing a guitar
#
#
# 5636 label:  no    result:  unknown
# premise:  A young boy is singing and playing a guitar
# add_premise:
# hypothesis:  There is no young boy singing and playing a guitar
#
#
# 5639 label:  yes    result:  unknown
# premise:  A young boy is singing and playing a guitar
# add_premise:
# hypothesis:  The guitar is being played by a kid
#
#
# 5648 label:  yes    result:  unknown
# premise:  Someone is stirring chili in a kettle
# add_premise:  ['all x.(kettle(x) -> pot(x))', 'all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  A pot of chili is being stirred by someone with a spoon
#
#
# 5681 label:  no    result:  unknown
# premise:  There is no woman slicing tofu
# add_premise:
# hypothesis:  A woman is slicing tofu
#
#
# 5690 label:  no    result:  unknown
# premise:  There is no man playing with a skull
# add_premise:
# hypothesis:  The man is playing with a skull
#
#
# 5699 label:  no    result:  unknown
# premise:  The man is sprinkling cheese on the pizza
# add_premise:
# hypothesis:  There is no man sprinkling cheese on the pizza
#
#
# 5702 label:  yes    result:  unknown
# premise:  Some cheese is being put on a pizza by a man
# add_premise:  []
# hypothesis:  The man is sprinkling cheese on the pizza
#
#
# 5703 label:  no    result:  unknown
# premise:  There is no man putting some cheese on a pizza
# add_premise:
# hypothesis:  The man is sprinkling cheese on the pizza
#
#
# 5704 label:  yes    result:  unknown
# premise:  The man is sprinkling cheese on the pizza
# add_premise:  []
# hypothesis:  A man is putting some cheese on a pizza
#
#
# 5708 label:  no    result:  unknown
# premise:  A man is shooting a shotgun
# add_premise:
# hypothesis:  There is no man shooting a shotgun
#
#
# 5714 label:  yes    result:  unknown
# premise:  A famous singer is dancing on the ceiling
# add_premise:  []
# hypothesis:  A great singer is dancing on the ceiling
#
#
# 5715 label:  no    result:  unknown
# premise:  There is no famous singer dancing on the ceiling
# add_premise:
# hypothesis:  A famous singer is dancing on the ceiling
#
#
# 5723 label:  yes    result:  unknown
# premise:  A cow is eating grass
# add_premise:  ['all x.(grass(x) -> graze(x))']
# hypothesis:  A cow is grazing
#
#
# 5727 label:  yes    result:  unknown
# premise:  Hay is being eaten by a cow
# add_premise:  ['all x.(eat(x) -> eating(x))', 'all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  A cow is eating grass
#
#
# 5729 label:  yes    result:  unknown
# premise:  A cow is eating hay
# add_premise:  []
# hypothesis:  A cow is grazing
#
#
# 5731 label:  yes    result:  unknown
# premise:  A cow is eating grass
# add_premise:  []
# hypothesis:  A cow is eating hay
#
#
# 5743 label:  yes    result:  unknown
# premise:  A tiger cub is playing with a ball
# add_premise:  []
# hypothesis:  A baby tiger is playing with a ball
#
#
# 5759 label:  yes    result:  unknown
# premise:  A man is talking to a woman
# add_premise:  ['all x.(talk(x) <-> speak(x))']
# hypothesis:  A man and a woman are speaking
#
#
# 5789 label:  no    result:  unknown
# premise:  There is no man cutting a fish
# add_premise:
# hypothesis:  A man is cutting a fish
#
#
# 5795 label:  no    result:  unknown
# premise:  A man is slicing a fish
# add_premise:
# hypothesis:  There is no man cutting a fish
#
#
# 5798 label:  no    result:  unknown
# premise:  A person is not frying
# add_premise:  []
# hypothesis:  A person is frying some food
#
#
# 5800 label:  no    result:  unknown
# premise:  A person is peeling a potato
# add_premise:
# hypothesis:  There is no person peeling a potato
#
#
# 5809 label:  no    result:  unknown
# premise:  A man is shooting with a bow
# add_premise:  []
# hypothesis:  A man is shooting with a gun
#
#
# 5817 label:  unknown    result:  yes
# premise:  A woman is dancing near a fire
# add_premise:  ['all x.(fire(x) -> fireplace(x))']
# hypothesis:  A woman is dancing near a fireplace
#
#
# 5818 label:  no    result:  unknown
# premise:  A woman is dancing near a fire
# add_premise:
# hypothesis:  There is no woman dancing near a fire
#
#
# 5854 label:  no    result:  unknown
# premise:  Someone is stirring noodles in the water
# add_premise:  []
# hypothesis:  Nobody is stirring noodles in the water
#
#
# 5862 label:  yes    result:  unknown
# premise:  Two women are dancing and singing in front of a crowd
# add_premise:
# hypothesis:  Two women are dancing and singing in front of many people
#
#
# 5866 label:  yes    result:  unknown
# premise:  Two women are dancing and singing in front of a crowd
# add_premise:
# hypothesis:  The persons are singing and dancing
#
#
# 5868 label:  yes    result:  unknown
# premise:  Two women are dancing and singing in front of a crowd
# add_premise:
# hypothesis:  The women are singing and dancing
#
#
# 5871 label:  yes    result:  unknown
# premise:  An animal is biting someone \'s finger
# add_premise:  ['all x.(someone(x) <-> somebody(x))']
# hypothesis:  An animal is biting somebody \'s hand
#
#
# 5878 label:  unknown    result:  yes
# premise:  A boy is skateboarding on a half pipe
# add_premise:  ['all x.(boy(x) -> man(x))']
# hypothesis:  A man is skateboarding on a half pipe
#
#
# 5880 label:  yes    result:  unknown
# premise:  A skateboarder is doing acrobatics on a half pipe
# add_premise:  []
# hypothesis:  A skateboarder is doing tricks on a half pipe
#
#
# 5917 label:  no    result:  unknown
# premise:  There is no woman slicing potatoes
# add_premise:
# hypothesis:  A woman is slicing potatoes
#
#
# 5932 label:  yes    result:  unknown
# premise:  A man is putting vegetables into a pot
# add_premise:  []
# hypothesis:  Vegetables are being put into a pot by a man
#
#
# 5934 label:  yes    result:  unknown
# premise:  Someone is pouring ingredients into a pot
# add_premise:  []
# hypothesis:  Someone is adding ingredients to a pot
#
#
# 5935 label:  no    result:  yes
# premise:  Nobody is pouring ingredients into a pot
# add_premise:  ['all x.(nobody(x) -> someone(x))']
# hypothesis:  Someone is pouring ingredients into a pot
#
#
# 5942 label:  no    result:  unknown
# premise:  The man is standing on a rocky mountain and gray clouds are in the background
# add_premise:
# hypothesis:  The man is not standing on a rocky mountain and gray clouds are not in the background
#
#
# 5953 label:  no    result:  unknown
# premise:  A dog is catching a ball
# add_premise:
# hypothesis:  There is no dog catching a ball
#
#
# 5961 label:  yes    result:  unknown
# premise:  A boy in a blue shirt has dirt on his face
# add_premise:
# hypothesis:  A boy in a blue dyed shirt has dirt on his face
#
#
# 5995 label:  no    result:  unknown
# premise:  There is no brown dog standing in the water
# add_premise:
# hypothesis:  A brown dog is standing in the water
#
#
# 5997 label:  no    result:  unknown
# premise:  A dog with golden fur is in the water
# add_premise:
# hypothesis:  A dog with golden fur is out of the water
#
#
# 6003 label:  yes    result:  unknown
# premise:  A girl in a blue sh
# add_premise:
# hypothesis:  A young girl in a blue shirt is walking on the sidewalk and holding up a pink sign
#
#
# 6004 label:  no    result:  unknown
# premise:  A young girl in a blue shirt is walking on the sidewalk and holding up a pink sign
# add_premise:
# hypothesis:  There is no young girl in a blue shirt walking on the sidewalk and holding up a pink sign
#
#
# 6009 label:  no    result:  unknown
# premise:  The girl is not carrying a sign and no group of people is following her
# add_premise:
# hypothesis:  A young girl in a blue shirt is walking on the sidewalk and holding up a pink sign
#
#
# 6011 label:  no    result:  unknown
# premise:  The girl is carrying a sign and a group of people is following her
# add_premise:
# hypothesis:  There is no young girl in a blue shirt walking on the sidewalk and holding up a pink sign
#
#
# 6025 label:  yes    result:  unknown
# premise:  A small dog is chasing a large brown cow
# add_premise:  []
# hypothesis:  A
#
#
# 6026 label:  no    result:  unknown
# premise:  A small dog is chasing a large brown cow
# add_premise:
# hypothesis:  There is no small dog chasing a large brown cow
#
#
# 6034 label:  yes    result:  unknown
# premise:  The small child is walking through the water and is being guided by another person
# add_premise:
# hypothesis:  The small child is wading through the water and is being guided by another person
#
#
# 6040 label:  no    result:  unknown
# premise:  The small child is wading through the water and is being guided by another person
# add_premise:
# hypothesis:  There is no young child splashing in the water
#
#
# 6057 label:  no    result:  unknown
# premise:  A brown dog is staring attentively at a brown and white dog
# add_premise:
# hypothesis:  There is no brown dog staring attentively at a brown and white dog
#
#
# 6076 label:  yes    result:  unknown
# premise:  A person wearing jeans is sitting happily on the top of a horse saddle
# add_premise:
# ...
# add_premise:
# hypothesis:  The snowboarder is not jumping off a snow covered hill
#
#
# 9145 label:  yes    result:  unknown
# premise:  The snowboarder is jumping off a snow covered hill
# add_premise:
# hypothesis:  The snowboarder is jumping off the snow
#
#
# 9157 label:  yes    result:  unknown
# premise:  A boy in a swimsuit is sitting on top of a circular fountain
# add_premise:  []
# hypothesis:  A boy in a swimsuit is sitting on a circular fountain
#
#
# 9158 label:  no    result:  unknown
# premise:  There is no boy in a swimsuit sitting on top of a circular fountain
# add_premise:
# hypothesis:  A boy in a swimsuit is sitting on top of a circular fountain
#
#
# 9168 label:  yes    result:  unknown
# premise:  A small brown and white dog is running on the sidewalk
# add_premise:  []
# hypothesis:  A little brown and white dog is running on the sidewalk
#
#
# 9178 label:  no    result:  unknown
# premise:  There is no person with a blue backpack hiking in rocky area
# add_premise:
# hypothesis:  A distant person with a blue backpack is hiking in rocky area
#
#
# 9179 label:  yes    result:  unknown
# premise:  A distant person with a blue backpack is hiking area full of rocks
# add_premise:
# hypothesis:  The person is hiking
#
#
# 9195 label:  yes    result:  unknown
# premise:  A lady is standing on the street and is surrounded by school children
# add_premise:
# hypothesis:  A lady is standing on the street and is surrounded by kids
#
#
# 9204 label:  yes    result:  unknown
# premise:  A woman is wearing paint and costume pieces and is riding a bike on a busy street
# add_premise:
# hypothesis:  A bike is being ridden by a woman wearing paint and costume pieces on a busy street
#
#
# 9207 label:  yes    result:  unknown
# premise:  A woman is wearing paint and costume pieces and is riding a bike on a empty street
# add_premise:
# hypothesis:  A girl in a strange outfit is riding the bike
#
#
# 9220 label:  yes    result:  unknown
# premise:  The black dog is carrying a blue and white ball in its mouth
# add_premise:
# hypothesis:  The black dog is carrying a blue and white toy in its mouth
#
#
# 9237 label:  yes    result:  unknown
# premise:  A girl in a uniform is playing the flute with a marching band
# add_premise:  []
# hypothesis:  A girl in a band is playing the flute
#
#
# 9256 label:  yes    result:  unknown
# premise:  A man is wearing a clear plastic cap and a mask
# add_premise:  []
# hypothesis:  A man is wearing a clear plastic cap and a face mask
#
#
# 9257 label:  no    result:  unknown
# premise:  A man is not wearing a clear plastic cap and a face mask
# add_premise:  []
# hypothesis:  A man is wearing a clear plastic cap and a face mask
#
#
# 9258 label:  yes    result:  unknown
# premise:  A man by a brick wall is wearing a mask around his mouth and a hair net
# add_premise:
# hypothesis:  A man by a wall made of bricks is wearing a mask around his mouth and a hair net
#
#
# 9265 label:  yes    result:  unknown
# premise:  Two dogs are in a kennel on their hind legs and are facing one another
# add_premise:
# hypothesis:  Two animals are in a kennel on their hind legs and are facing one another
#
#
# 9266 label:  yes    result:  unknown
# premise:  Two dogs are in a kennel on their hind legs and are facing one another
# add_premise:
# hypothesis:  Two cats are in a kennel on their hind legs and are facing one another
#
#
# 9267 label:  yes    result:  unknown
# premise:  A black dog and a yellow dog are playing with each other
# add_premise:  []
# hypothesis:  Two dogs are playing with each other
#
#
# 9268 label:  no    result:  unknown
# premise:  A black dog and a yellow dog are not playing with each other
# add_premise:  []
# hypothesis:  A black dog and a yellow dog are playing with each other
#
#
# 9276 label:  yes    result:  unknown
# premise:  Two women with dogs are walking on a forest path
# add_premise:  []
# hypothesis:  Two girl with dogs are walking on a forest path
#
#
# 9278 label:  yes    result:  unknown
# premise:  Two girl with dogs are walking on a forest path
# add_premise:  ['all x.(forest(x) <-> wood(x))']
# hypothesis:  Two dogs and two people are walking in the woods
#
#
# 9283 label:  yes    result:  unknown
# premise:  A man is snowboarding down a railing in the snow
# add_premise:
# hypothesis:  A person is snowboarding down a railing in the snow
#
#
# 9301 label:  yes    result:  unknown
# premise:  A man in a red shirt is doing a trick with the skateboard
# add_premise:  []
# hypothesis:  A man in a red shirt is doing a trick with a skateboard
#
#
# 9310 label:  yes    result:  unknown
# premise:  A snowboarder is grinding down a long concrete rail
# add_premise:
# hypothesis:  A snowboarder is grinding down a long rail
#
#
# 9311 label:  no    result:  unknown
# premise:  A snowboarder is grinding down a long concrete rail
# add_premise:
# hypothesis:  There is no snowboarder grinding down a long concrete rail
#
#
# 9312 label:  yes    result:  unknown
# premise:  A person is doing acrobatics on a snowboard
# add_premise:  []
# hypothesis:  A person is doing a trick on a snowboard
#
#
# 9320 label:  no    result:  unknown
# premise:  Three friends are making faces for the camera
# add_premise:  []
# hypothesis:  Three enemies are making faces for the camera
#
#
# 9322 label:  yes    result:  unknown
# premise:  Two men and a girl in front of a wood panel wall are posing with funny faces
# add_premise:
# hypothesis:  Two men and a girl in front of a wood panel wall are making funny faces
#
#
# 9332 label:  yes    result:  unknown
# premise:  A group of people is walking down the street and a person in a green hat is on the phone
# add_premise:
# hypothesis:  A group of people is walking down the street and a person in a hat is on the phone
#
#
# 9333 label:  no    result:  unknown
# premise:  A group of people is walking down the street and a person in a green hat is on the phone
# add_premise:
# hypothesis:  A group of people is not walking down the street and a person in a green hat is on the phone
#
#
# 9334 label:  yes    result:  unknown
# premise:  Four people are walking along a city sidewalk and the one in the green hat is talking on a cell phone
# add_premise:
# hypothesis:  A group of people is walking down the street and a person in a hat is on the phone
#
#
# 9341 label:  yes    result:  unknown
# premise:  A man is standing at dusk on an almost prist
# add_premise:
# hypothesis:  A man is standing at dusk on an almost pristine road covered by s
#
#
# 9378 label:  no    result:  unknown
# premise:  A man in green is kicking a soccer ball and a man in purple and white is rising up
# add_premise:  []
# hypothesis:  A man in green is kicking a soccer ball and a man in purple and white is falling down
#
#
# 9411 label:  yes    result:  unknown
# premise:  Two people dressed in green and red costumes are outside on the sidewalk
# add_premise:
# hypothesis:  Two people dressed in green and red costumes are outside near the street
#
#
# 9420 label:  yes    result:  unknown
# premise:  A dog is in an area full of s
# add_premise:
# hypothesis:  A dog is in a sandy area with the sand that is being stirred up into the air and several plants are in the background
#
#
# 9422 label:  yes    result:  unknown
# premise:  A dog is in the sand that is blowing in the air
# add_premise:
# hypothesis:  A dog is in the sand that is blowing in the wind
#
#
# 9428 label:  yes    result:  unknown
# premise:  A dog is in the sand that is blowing in the wind
# add_premise:
# hypothesis:  A dog is in a sandy area with the sand that is being stirred up into the air and several plants are in the background
#
#
# 9432 label:  no    result:  unknown
# premise:  The black and white dog is running indoors
# add_premise:
# hypothesis:  The black and white dog is running outdoors
#
#
# 9440 label:  yes    result:  unknown
# premise:  A woman wearing a blue shirt and high heels is standing on the sidewalk next to a man
# add_premise:
# hypothesis:  A woman wearing a blue shirt and high heels is standing on the sidewalk next to the man
#
#
# 9446 label:  yes    result:  unknown
# premise:  A woman wearing a blue shirt and high heels is standing on the sidewalk next to a man
# add_premise:
# hypothesis:  A man and a woman are standing on the curb
#
#
# 9458 label:  yes    result:  unknown
# premise:  A man on a green bike is performing tricks on a dirt ramp
# add_premise:  []
# hypothesis:  The man on a green bike is performing tricks on the dirt ramp
#
#
# 9460 label:  yes    result:  unknown
# premise:  A stuntman on a bike is in the air near a body of water
# add_premise:
# hypothesis:  A person on a bike is in the air near a body of water
#
#
# 9478 label:  yes    result:  unknown
# premise:  A black dog and a tan dog are fighting
# add_premise:  []
# hypothesis:  Two dogs are fighting
#
#
# 9480 label:  yes    result:  unknown
# premise:  A black dog and a white dog are wrestling on the ground
# add_premise:  ['all x.(wrestle(x) -> fight(x))']
# hypothesis:  Two dogs are fighting
#
#
# 9486 label:  no    result:  unknown
# premise:  A cluster of four brown dogs are playing in a field of brown grass
# add_premise:
# hypothesis:  There is no dog playing in a field of brown grass
#
#
# 9487 label:  yes    result:  unknown
# premise:  Four dogs are playing in a area covered by grass
# add_premise:
# hypothesis:  Four dogs are playing in a grassy area
#
#
# 9491 label:  yes    result:  unknown
# premise:  A group of four brown dogs are playing in a field of brown grass
# add_premise:  ['all x.(field(x) <-> area(x))']
# hypothesis:  Four dogs are playing in a grassy area
#
#
# 9503 label:  yes    result:  unknown
# premise:  A brown puppy is gnawing a metallic post that is stuck in the ground
# add_premise:
# hypothesis:  A brown dog is gnawing a metallic post that is stuck in the ground
#
#
# 9511 label:  yes    result:  unknown
# premise:  A brown puppy is gnawing a metallic post that is stuck in the ground
# add_premise:
# hypothesis:  A brown puppy is biting a pole
#
#
# 9533 label:  no    result:  unknown
# premise:  Two race cars are on a road in front of a grassy parking area
# add_premise:
# hypothesis:  No race car is on a road in front of a grassy parking area
#
#
# 9539 label:  yes    result:  unknown
# premise:  The rider dressed in orange is driving a motorcycle on one wheel
# add_premise:
# hypothesis:  The orange rider is driving a motorcycle on one wheel
#
#
# 9564 label:  no    result:  unknown
# premise:  A brown dog is running in the snow
# add_premise:  []
# hypothesis:  No dog is running through the snow
#
#
# 9566 label:  yes    result:  unknown
# premise:  An elderly man is sitting on a bench
# add_premise:  ['all x.(man(x) -> person(x))']
# hypothesis:  An old person is sitting on a bench
#
#
# 9568 label:  yes    result:  unknown
# premise:  An elderly woman is sitting on a bench and is wearing a gray jacket and black pants
# add_premise:
# hypothesis:  The woman is sitting on a bench and is wearing a gray jacket and black pants
#
#
# 9575 label:  yes    result:  unknown
# premise:  A dog is fetching a piece of wood out of very clear water
# add_premise:  []
# hypothesis:  A dog is fetching a stick out of very clear water
#
#
# 9585 label:  no    result:  unknown
# premise:  The lady is holding the paintbrush next to the artist \'s easel
# add_premise:
# hypothesis:  There is no lady holding the paintbrush next to the artist \'s easel
#
#
# 9597 label:  yes    result:  unknown
# premise:  A yellow dog is running down a sandy path
# add_premise:
# hypothesis:  A yellow dog is running down a path covered by sand
#
#
# 9601 label:  yes    result:  unknown
# premise:  A yellow dog is running down a sandy path
# add_premise:
# hypothesis:  A dog is running
#
#
# 9606 label:  yes    result:  unknown
# premise:  A dog is standing on one leg and is waiting for a soccer ball
# add_premise:
# hypothesis:  A dog is standing on one leg and is waiting for a ball
#
#
# 9613 label:  yes    result:  unknown
# premise:  Two men are seated on a camel and another camel is in the foreground
# add_premise:
# hypothesis:  Two people are seated on a camel and another camel is in the foreground
#
#
# 9622 label:  yes    result:  unknown
# premise:  A man is wearing a blue shirt and walking barefoot on a tennis court
# add_premise:
# hypothesis:  A person is wearing a blue shirt and walking barefoot on a tennis court
#
#
# 9660 label:  yes    result:  unknown
# premise:  A shirtless man is leading a horse that is pulling a carriage
# add_premise:
# hypothesis:  A shirtless man is leading a carriage that is being pulled by a horse
#
#
# 9661 label:  no    result:  unknown
# premise:  A shirtless woman is leading a horse that is pulling a carriage
# add_premise:
# hypothesis:  A shirtless man is leading a horse that is pulling a carriage
#
#
# 9664 label:  yes    result:  unknown
# premise:  A shirtless man is escorting a horse that is pulling a carriage along a road
# add_premise:
# hypothesis:  A shirtless man is leading a horse that is pulling a carriage
#
#
# 9670 label:  no    result:  unknown
# premise:  A young girl is playing on the edge of a fountain and an older woman is watching her
# add_premise:  []
# hypothesis:  A young girl is playing on the edge of a fountain and an older woman is not watching her
#
#
# 9671 label:  yes    result:  unknown
# premise:  A little girl and a woman wearing a yellow shirt are getting splashed by a city fountain
# add_premise:
# hypothesis:  A little girl and a woman wearing a yellow shirt are getting splashed near a fountain
#
#
# 9688 label:  no    result:  unknown
# premise:  There is no cyclist performing a jump on a bicycle
# add_premise:
# hypothesis:  A cyclist is performing a jump on a bicycle
#
#
# 9696 label:  yes    result:  unknown
# premise:  A woman is showing a puppy to an infant
# add_premise:  ['all x.(puppy(x) -> dog(x))']
# hypothesis:  A woman is showing a small dog to an infant
#
#
# 9705 label:  yes    result:  unknown
# premise:  A black and white dog with a large branch is running in the field
# add_premise:
# hypothesis:  A black and white dog with a large branch is running in the grass
#
#
# 9707 label:  yes    result:  unknown
# premise:  A black and white dog is carrying a big stick on the green grass
# add_premise:
# hypothesis:  A black and white dog is carrying a huge stick on the green grass
#
#
# 9711 label:  yes    result:  unknown
# premise:  A black and white dog with a large branch is running in the grass
# add_premise:
# hypothesis:  A black and white dog is carrying a huge stick on the green grass
#
#
# 9714 label:  yes    result:  unknown
# premise:  A boy wearing a striped shirt is running barefoot on the sandy hill
# add_premise:
# hypothesis:  A kid wearing a striped shirt is running barefoot on the sandy hill
#
#
# 9716 label:  yes    result:  unknown
# premise:  A boy is running on the beach
# add_premise:  []
# hypothesis:  A boy is running through the sand
#
#
# 9725 label:  yes    result:  unknown
# premise:  A motorcycle racer is riding a red and black bike
# add_premise:
# hypothesis:  The motorcycle racer is riding a red and black bike
#
#
# 9734 label:  yes    result:  unknown
# premise:  A woman is wearing ear protection and is firing a gun at an indoor shooting range
# add_premise:
# hypothesis:  The woman is wearing ear protection and is firing a gun at an indoor shooting range
#
#
# 9737 label:  yes    result:  unknown
# premise:  A woman is wearing ear protection and is firing a gun at an outdoor shooting range
# add_premise:
# hypothesis:  A woman is shooting at target practice
#
#
# 9740 label:  yes    result:  unknown
# premise:  A woman is wearing ear protection and is firing a gun at an indoor shooting range
# add_premise:
# hypothesis:  A woman is shooting at target practice
#
#
# 9741 label:  yes    result:  unknown
# premise:  Two young boys are looking up at the camera and one is sticking out his tongue
# add_premise:
# hypothesis:  Two kids are looking up at the camera and one is sticking out his tongue
#
#
# 9743 label:  yes    result:  unknown
# premise:  The little boy is sticking his tongue out for the camera and another boy is looking on
# add_premise:
# hypothesis:  A little boy is sticking his tongue out for the camera and another boy is looking on
#
#
# 9750 label:  yes    result:  unknown
# premise:  The large dog is walking outside and is carrying a colorful toy in its mouth
# add_premise:
# hypothesis:  The large dog is walking outside and is holding a colorful toy in its mouth

# %%
# examples of problems we translated successfully

print("translated problems: \n")
for i in range(0,int(len(translate_data)/10)):
  print(translate_data.iloc[i]['problem_id'], "gold label: ", translate_data.iloc[i]['label'], "   result: ", translate_data.iloc[i]['result'])
  print("premise: ", translate_data.iloc[i]['p_sen'])
  print("premise fol: ", translate_data.iloc[i]['p_fol'])
  print("add_premise: ", translate_data.iloc[i]['add_fol'])
  print("hypothesis: ", translate_data.iloc[i]['h_sen'])
  print("hypothesis fol: ", translate_data.iloc[i]['h_fol'])
  print("\n")
# Out:
# translated problems:
#
# 7 gold label:  unknown    result:  unknown
# premise:  A group of boys in a yard is playing and a man is standing in the background
# premise fol:  (exists x.(group(x) & exists z2182.(boy(z2182) & exists z2181.(yard(z2181) & in(z2182,z2181) & of(x,z2182) & exists z2184.(play(z2184) & argu1(z2184,x) & True(z2184))))) & exists x.(man(x) & exists z2186.(stand(z2186) & argu1(z2186,x) & exists z2185.(background(z2185) & in(z2186,z2185) & True(z2186)))))
# add_premise:  []
# hypothesis:  The young boys are playing outdoors and the man is smiling nearby
# hypothesis fol:  (exists x.(exists z2187.(young(z2187) & argu1(x,z2187) & boy(x)) & exists z2188.(outdoors(z2188) & exists e.(play(e) & argu1(e,x) & argu2(e,z2188) & True(e)))) & exists x.(man(x) & exists z2190.(smile(z2190) & argu1(z2190,x) & exists s.(nearby(s) & argu1(z2190,s) & True(z2190)))))
#
#
# 10 gold label:  yes    result:  unknown
# premise:  A brown dog is attacking another animal in front of the tall man in pants
# premise fol:  exists x.(exists z2196.(brown(z2196) & argu1(x,z2196) & dog(x)) & exists z2200.(animal(z2200) & all y.(animal(y) -> -(z2200 = y)) & exists e.(attack(e) & argu1(e,x) & argu2(e,z2200) & exists z2200.(front(z2200) & exists z2199.(exists z2197.(tall(z2197) & argu1(z2199,z2197) & man(z2199)) & exists z2198.(pants(z2198) & in(z2199,z2198) & of(z2200,z2199) & in(e,z2200) & True(e)))))))
# add_premise:  []
# hypothesis:  A brown dog is attacking another animal in front of the man in pants
# hypothesis fol:  exists x.(exists z2201.(brown(z2201) & argu1(x,z2201) & dog(x)) & exists z2204.(animal(z2204) & all y.(animal(y) -> -(z2204 = y)) & exists e.(attack(e) & argu1(e,x) & argu2(e,z2204) & exists z2204.(front(z2204) & exists z2203.(man(z2203) & exists z2202.(pants(z2202) & in(z2203,z2202) & of(z2204,z2203) & in(e,z2204) & True(e)))))))
#
#
# 11 gold label:  unknown    result:  unknown
# premise:  A brown dog is attacking another animal in front of the man in pants
# premise fol:  exists x.(exists z2205.(brown(z2205) & argu1(x,z2205) & dog(x)) & exists z2208.(animal(z2208) & all y.(animal(y) -> -(z2208 = y)) & exists e.(attack(e) & argu1(e,x) & argu2(e,z2208) & exists z2208.(front(z2208) & exists z2207.(man(z2207) & exists z2206.(pants(z2206) & in(z2207,z2206) & of(z2208,z2207) & in(e,z2208) & True(e)))))))
# add_premise:  []
# hypothesis:  A brown dog is helping another animal in front of the man in pants
# hypothesis fol:  exists x.(exists z2209.(brown(z2209) & argu1(x,z2209) & dog(x)) & exists z2212.(animal(z2212) & all y.(animal(y) -> -(z2212 = y)) & exists e.(help(e) & argu1(e,x) & argu2(e,z2212) & exists z2212.(front(z2212) & exists z2211.(man(z2211) & exists z2210.(pants(z2210) & in(z2211,z2210) & of(z2212,z2211) & in(e,z2212) & True(e)))))))
#
#
# 19 gold label:  yes    result:  unknown
# premise:  A person in a black jacket is doing tricks on a motorbike
# premise fol:  exists x.(person(x) & exists z2232.(exists z2231.(black(z2231) & argu1(z2232,z2231) & jacket(z2232)) & in(x,z2232) & exists z2233.(trick(z2233) & exists e.(do(e) & argu1(e,x) & argu2(e,z2233) & exists z2233.(motorbike(z2233) & on(e,z2233) & True(e))))))
# add_premise:  []
# hypothesis:  A man in a black jacket is doing tricks on a motorbike
# hypothesis fol:  exists x.(man(x) & exists z2235.(exists z2234.(black(z2234) & argu1(z2235,z2234) & jacket(z2235)) & in(x,z2235) & exists z2236.(trick(z2236) & exists e.(do(e) & argu1(e,x) & argu2(e,z2236) & exists z2236.(motorbike(z2236) & on(e,z2236) & True(e))))))
#
#
# 21 gold label:  unknown    result:  unknown
# premise:  A person in a black jacket is doing tricks on a motorbike
# premise fol:  exists x.(person(x) & exists z2240.(exists z2239.(black(z2239) & argu1(z2240,z2239) & jacket(z2240)) & in(x,z2240) & exists z2241.(trick(z2241) & exists e.(do(e) & argu1(e,x) & argu2(e,z2241) & exists z2241.(motorbike(z2241) & on(e,z2241) & True(e))))))
# add_premise:  []
# hypothesis:  A person on a black motorbike is doing tricks with a jacket
# hypothesis fol:  exists x.(person(x) & exists z2243.(exists z2242.(black(z2242) & argu1(z2243,z2242) & motorbike(z2243)) & on(x,z2243) & exists z2244.(trick(z2244) & exists e.(do(e) & argu1(e,z2244) & argu2(e,x) & exists z2244.(jacket(z2244) & with(e,z2244)) & True(e)))))
#
#
# 22 gold label:  yes    result:  yes
# premise:  A skilled person is riding a bicycle on one wheel
# premise fol:  exists x.(exists z2245.(skilled(z2245) & argu1(x,z2245) & person(x)) & exists z2247.(bicycle(z2247) & exists e.(ride(e) & argu1(e,x) & argu2(e,z2247) & exists z2247.(exists z2246.(one(z2246) & argu1(z2247,z2246) & wheel(z2247)) & on(e,z2247) & True(e)))))
# add_premise:  []
# hypothesis:  A person is riding the bicycle on one wheel
# hypothesis fol:  exists x.(person(x) & exists z2249.(bicycle(z2249) & exists e.(ride(e) & argu1(e,x) & argu2(e,z2249) & exists z2249.(exists z2248.(one(z2248) & argu1(z2249,z2248) & wheel(z2249)) & on(e,z2249) & True(e)))))
#
#
# 23 gold label:  no    result:  yes
# premise:  Nobody is riding the bicycle on one wheel
# premise fol:  exists x.(nobody(x) & exists z2251.(bicycle(z2251) & exists e.(ride(e) & argu1(e,x) & argu2(e,z2251) & exists z2251.(exists z2250.(one(z2250) & argu1(z2251,z2250) & wheel(z2251)) & on(e,z2251) & True(e)))))
# add_premise:  ['all x.(nobody(x) -> person(x))']
# hypothesis:  A person is riding the bicycle on one wheel
# hypothesis fol:  exists x.(person(x) & exists z2253.(bicycle(z2253) & exists e.(ride(e) & argu1(e,x) & argu2(e,z2253) & exists z2253.(exists z2252.(one(z2252) & argu1(z2253,z2252) & wheel(z2253)) & on(e,z2253) & True(e)))))
#
#
# 29 gold label:  unknown    result:  unknown
# premise:  A person is riding the bicycle on one wheel
# premise fol:  exists x.(person(x) & exists z2259.(bicycle(z2259) & exists e.(ride(e) & argu1(e,x) & argu2(e,z2259) & exists z2259.(exists z2258.(one(z2258) & argu1(z2259,z2258) & wheel(z2259)) & on(e,z2259) & True(e)))))
# add_premise:  []
# hypothesis:  A person in a black jacket is doing tricks on a motorbike
# hypothesis fol:  exists x.(person(x) & exists z2261.(exists z2260.(black(z2260) & argu1(z2261,z2260) & jacket(z2261)) & in(x,z2261) & exists z2262.(trick(z2262) & exists e.(do(e) & argu1(e,x) & argu2(e,z2262) & exists z2262.(motorbike(z2262) & on(e,z2262) & True(e))))))
#
#
# 41 gold label:  yes    result:  unknown
# premise:  Two people are kickboxing and spectators are watching
# premise fol:  (exists x.(exists z2286.(two(z2286) & argu1(x,z2286) & people(x)) & exists z2288.(kickbox(z2288) & argu1(z2288,x) & True(z2288))) & exists x.(spectator(x) & exists z2290.(watch(z2290) & argu1(z2290,x) & True(z2290))))
# add_premise:  []
# hypothesis:  Two people are fighting and spectators are watching
# hypothesis fol:  (exists x.(exists z2291.(two(z2291) & argu1(x,z2291) & people(x)) & exists z2293.(fight(z2293) & argu1(z2293,x) & True(z2293))) & exists x.(spectator(x) & exists z2295.(watch(z2295) & argu1(z2295,x) & True(z2295))))
#
#
# 43 gold label:  unknown    result:  unknown
# premise:  Two spectators are kickboxing and some people are watching
# premise fol:  (exists x.(exists z2296.(two(z2296) & argu1(x,z2296) & spectator(x)) & exists z2298.(kickbox(z2298) & argu1(z2298,x) & True(z2298))) & exists x.(people(x) & exists z2300.(watch(z2300) & argu1(z2300,x) & True(z2300))))
# add_premise:  []
# hypothesis:  Two people are kickboxing and spectators are watching
# hypothesis fol:  (exists x.(exists z2301.(two(z2301) & argu1(x,z2301) & people(x)) & exists z2303.(kickbox(z2303) & argu1(z2303,x) & True(z2303))) & exists x.(spectator(x) & exists z2305.(watch(z2305) & argu1(z2305,x) & True(z2305))))
#
#
# 46 gold label:  unknown    result:  unknown
# premise:  Two people are kickboxing and spectators are watching
# premise fol:  (exists x.(exists z2306.(two(z2306) & argu1(x,z2306) & people(x)) & exists z2308.(kickbox(z2308) & argu1(z2308,x) & True(z2308))) & exists x.(spectator(x) & exists z2310.(watch(z2310) & argu1(z2310,x) & True(z2310))))
# add_premise:  []
# hypothesis:  Two young women are sparring in a kickboxing fight
# hypothesis fol:  exists x.(exists z2311.(two(z2311) & argu1(x,z2311) & exists z2311.(young(z2311) & argu1(x,z2311) & woman(x))) & exists z2314.(spar(z2314) & argu1(z2314,x) & exists z2313.(exists z2312.(kickboxing(z2312) & argu1(z2313,z2312) & fight(z2313)) & in(z2314,z2313) & True(z2314))))
#
#
# 48 gold label:  unknown    result:  unknown
# premise:  Two women are sparring in a kickboxing match
# premise fol:  exists x.(exists z2315.(two(z2315) & argu1(x,z2315) & woman(x)) & exists z2318.(spar(z2318) & argu1(z2318,x) & exists z2317.(exists z2316.(kickboxing(z2316) & argu1(z2317,z2316) & match(z2317)) & in(z2318,z2317) & True(z2318))))
# add_premise:  ['all x.(woman(x) -> people(x))', 'all x.(match(x) -> fight(x))', 'all x.(spar(x) -> fight(x))']
# hypothesis:  Two people are fighting and spectators are watching
# hypothesis fol:  (exists x.(exists z2319.(two(z2319) & argu1(x,z2319) & people(x)) & exists z2321.(fight(z2321) & argu1(z2321,x) & True(z2321))) & exists x.(spectator(x) & exists z2323.(watch(z2323) & argu1(z2323,x) & True(z2323))))
#
#
# 50 gold label:  unknown    result:  unknown
# premise:  Two spectators are kickboxing and some people are watching
# premise fol:  (exists x.(exists z2324.(two(z2324) & argu1(x,z2324) & spectator(x)) & exists z2326.(kickbox(z2326) & argu1(z2326,x) & True(z2326))) & exists x.(people(x) & exists z2328.(watch(z2328) & argu1(z2328,x) & True(z2328))))
# add_premise:  []
# hypothesis:  Two women are sparring in a kickboxing match
# hypothesis fol:  exists x.(exists z2329.(two(z2329) & argu1(x,z2329) & woman(x)) & exists z2332.(spar(z2332) & argu1(z2332,x) & exists z2331.(exists z2330.(kickboxing(z2330) & argu1(z2331,z2330) & match(z2331)) & in(z2332,z2331) & True(z2332))))
#
#
# 51 gold label:  unknown    result:  unknown
# premise:  Two people are kickboxing and spectators are watching
# premise fol:  (exists x.(exists z2333.(two(z2333) & argu1(x,z2333) & people(x)) & exists z2335.(kickbox(z2335) & argu1(z2335,x) & True(z2335))) & exists x.(spectator(x) & exists z2337.(watch(z2337) & argu1(z2337,x) & True(z2337))))
# add_premise:  []
# hypothesis:  Two women are sparring in a kickboxing match
# hypothesis fol:  exists x.(exists z2338.(two(z2338) & argu1(x,z2338) & woman(x)) & exists z2341.(spar(z2341) & argu1(z2341,x) & exists z2340.(exists z2339.(kickboxing(z2339) & argu1(z2340,z2339) & match(z2340)) & in(z2341,z2340) & True(z2341))))
#
#
# 52 gold label:  yes    result:  unknown
# premise:  Kids in red shirts are playing in the leaves
# premise fol:  exists x.(kids(x) & exists z2343.(exists z2342.(red(z2342) & argu1(z2343,z2342) & shirt(z2343)) & in(x,z2343) & exists z2345.(play(z2345) & argu1(z2345,x) & exists z2344.(leaf(z2344) & in(z2345,z2344) & True(z2345)))))
# add_premise:  []
# hypothesis:  Children in red shirts are playing in the leaves
# hypothesis fol:  exists x.(children(x) & exists z2347.(exists z2346.(red(z2346) & argu1(z2347,z2346) & shirt(z2347)) & in(x,z2347) & exists z2349.(play(z2349) & argu1(z2349,x) & exists z2348.(leaf(z2348) & in(z2349,z2348) & True(z2349)))))
#
#
# 53 gold label:  unknown    result:  unknown
# premise:  Children in red shirts are playing in the leaves
# premise fol:  exists x.(children(x) & exists z2351.(exists z2350.(red(z2350) & argu1(z2351,z2350) & shirt(z2351)) & in(x,z2351) & exists z2353.(play(z2353) & argu1(z2353,x) & exists z2352.(leaf(z2352) & in(z2353,z2352) & True(z2353)))))
# add_premise:  []
# hypothesis:  Children in red shirts are sleeping in the leaves
# hypothesis fol:  exists x.(children(x) & exists z2355.(exists z2354.(red(z2354) & argu1(z2355,z2354) & shirt(z2355)) & in(x,z2355) & exists z2357.(sleep(z2357) & argu1(z2357,x) & exists z2356.(leaf(z2356) & in(z2357,z2356) & True(z2357)))))
#
#
# 57 gold label:  unknown    result:  unknown
# premise:  Three boys are jumping in the leaves
# premise fol:  exists x.(exists z2364.(three(z2364) & argu1(x,z2364) & boy(x)) & exists z2366.(jump(z2366) & argu1(z2366,x) & exists z2365.(leaf(z2365) & in(z2366,z2365) & True(z2366))))
# add_premise:  ['all x.(boy(x) -> children(x))']
# hypothesis:  Children in red shirts are playing in the leaves
# hypothesis fol:  exists x.(children(x) & exists z2368.(exists z2367.(red(z2367) & argu1(z2368,z2367) & shirt(z2368)) & in(x,z2368) & exists z2370.(play(z2370) & argu1(z2370,x) & exists z2369.(leaf(z2369) & in(z2370,z2369) & True(z2370)))))
#
#
# 59 gold label:  unknown    result:  unknown
# premise:  Kids in red shirts are playing in the leaves
# premise fol:  exists x.(kids(x) & exists z2372.(exists z2371.(red(z2371) & argu1(z2372,z2371) & shirt(z2372)) & in(x,z2372) & exists z2374.(play(z2374) & argu1(z2374,x) & exists z2373.(leaf(z2373) & in(z2374,z2373) & True(z2374)))))
# add_premise:  ['all x.(kids(x) <-> kid(x))']
# hypothesis:  Three kids are jumping in the leaves
# hypothesis fol:  exists x.(exists z2375.(three(z2375) & argu1(x,z2375) & kid(x)) & exists z2377.(jump(z2377) & argu1(z2377,x) & exists z2376.(leaf(z2376) & in(z2377,z2376) & True(z2377))))
#
#
# 60 gold label:  unknown    result:  unknown
# premise:  Children in red shirts are sleeping in the leaves
# premise fol:  exists x.(children(x) & exists z2379.(exists z2378.(red(z2378) & argu1(z2379,z2378) & shirt(z2379)) & in(x,z2379) & exists z2381.(sleep(z2381) & argu1(z2381,x) & exists z2380.(leaf(z2380) & in(z2381,z2380) & True(z2381)))))
# add_premise:  ['all x.(children(x) <-> kid(x))']
# hypothesis:  Three kids are jumping in the leaves
# hypothesis fol:  exists x.(exists z2382.(three(z2382) & argu1(x,z2382) & kid(x)) & exists z2384.(jump(z2384) & argu1(z2384,x) & exists z2383.(leaf(z2383) & in(z2384,z2383) & True(z2384))))
#
#
# 74 gold label:  yes    result:  unknown
# premise:  A little girl is looking at a woman in costume
# premise fol:  exists x.(exists z2417.(little(z2417) & argu1(x,z2417) & girl(x)) & exists e.(look(e) & argu1(e,x) & exists z2419.(woman(z2419) & exists z2418.(costume(z2418) & in(z2419,z2418) & at(e,z2419))) & True(e)))
# add_premise:  []
# hypothesis:  A young girl is looking at a woman in costume
# hypothesis fol:  exists x.(exists z2420.(young(z2420) & argu1(x,z2420) & girl(x)) & exists e.(look(e) & argu1(e,x) & exists z2422.(woman(z2422) & exists z2421.(costume(z2421) & in(z2422,z2421) & at(e,z2422))) & True(e)))
#
#
# 75 gold label:  unknown    result:  unknown
# premise:  A little girl is looking at a woman in costume
# premise fol:  exists x.(exists z2423.(little(z2423) & argu1(x,z2423) & girl(x)) & exists e.(look(e) & argu1(e,x) & exists z2425.(woman(z2425) & exists z2424.(costume(z2424) & in(z2425,z2424) & at(e,z2425))) & True(e)))
# add_premise:  ['all x.(woman(x) -> -man(x))', 'all x.(man(x) -> -woman(x))']
# hypothesis:  The little girl is looking at a man in costume
# hypothesis fol:  exists x.(exists z2426.(little(z2426) & argu1(x,z2426) & girl(x)) & exists e.(look(e) & argu1(e,x) & exists z2428.(man(z2428) & exists z2427.(costume(z2427) & in(z2428,z2427) & at(e,z2428))) & True(e)))
#
#
# 76 gold label:  unknown    result:  unknown
# premise:  A little girl is looking at a woman in costume
# premise fol:  exists x.(exists z2429.(little(z2429) & argu1(x,z2429) & girl(x)) & exists e.(look(e) & argu1(e,x) & exists z2431.(woman(z2431) & exists z2430.(costume(z2430) & in(z2431,z2430) & at(e,z2431))) & True(e)))
# add_premise:  []
# hypothesis:  A little girl in costume looks like a woman
# hypothesis fol:  exists x.(exists z2432.(little(z2432) & argu1(x,z2432) & girl(x)) & exists z2433.(costume(z2433) & in(x,z2433) & exists e.(look(e) & argu1(e,x) & exists z2434.(woman(z2434) & like(e,z2434)) & True(e))))
#
#
# 80 gold label:  unknown    result:  unknown
# premise:  Masked people are looking in the same direction in a forest
# premise fol:  exists x.(exists z2435.(masked(z2435) & argu1(x,z2435) & people(x)) & exists e.(look(e) & argu1(e,x) & exists z2438.(exists z2436.(same(z2436) & argu1(z2438,z2436) & direction(z2438)) & exists z2437.(forest(z2437) & in(z2438,z2437) & in(e,z2438))) & True(e)))
# add_premise:  []
# hypothesis:  A little girl is looking at a woman in costume
# hypothesis fol:  exists x.(exists z2439.(little(z2439) & argu1(x,z2439) & girl(x)) & exists e.(look(e) & argu1(e,x) & exists z2441.(woman(z2441) & exists z2440.(costume(z2440) & in(z2441,z2440) & at(e,z2441))) & True(e)))
#
#
# 89 gold label:  yes    result:  yes
# premise:  A man is jumping into an empty swimming pool
# premise fol:  exists x.(man(x) & exists z2448.(jump(z2448) & argu1(z2448,x) & exists z2447.(exists z2446.(empty(z2446) & argu1(z2447,z2446) & exists z2446.(swimming(z2446) & argu1(z2447,z2446) & pool(z2447))) & into(z2448,z2447) & True(z2448))))
# add_premise:  []
# hypothesis:  A man is jumping into an empty pool
# hypothesis fol:  exists x.(man(x) & exists z2451.(jump(z2451) & argu1(z2451,x) & exists z2450.(exists z2449.(empty(z2449) & argu1(z2450,z2449) & pool(z2450)) & into(z2451,z2450) & True(z2451))))
#
#
# 92 gold label:  unknown    result:  unknown
# premise:  A lone biker is jumping in the air
# premise fol:  exists x.(exists z2452.(lone(z2452) & argu1(x,z2452) & biker(x)) & exists z2454.(jump(z2454) & argu1(z2454,x) & exists z2453.(air(z2453) & in(z2454,z2453) & True(z2454))))
# add_premise:  []
# hypothesis:  A man is jumping into an empty swimming pool
# hypothesis fol:  exists x.(man(x) & exists z2457.(jump(z2457) & argu1(z2457,x) & exists z2456.(exists z2455.(empty(z2455) & argu1(z2456,z2455) & exists z2455.(swimming(z2455) & argu1(z2456,z2455) & pool(z2456))) & into(z2457,z2456) & True(z2457))))
#
#
# 95 gold label:  unknown    result:  unknown
# premise:  A man is jumping into an empty pool
# premise fol:  exists x.(man(x) & exists z2460.(jump(z2460) & argu1(z2460,x) & exists z2459.(exists z2458.(empty(z2458) & argu1(z2459,z2458) & pool(z2459)) & into(z2460,z2459) & True(z2460))))
# add_premise:  []
# hypothesis:  A biker is jumping in the
# hypothesis fol:  exists x.(biker(x) & exists z2462.(jump(z2462) & argu1(z2462,x) & exists z2461.(air(z2461) & in(z2462,z2461) & True(z2462))))
#
#
# 108 gold label:  unknown    result:  unknown
# premise:  A player is throwing the ball
# premise fol:  exists x.(player(x) & exists z2481.(ball(z2481) & exists e.(throw(e) & argu1(e,x) & argu2(e,z2481) & True(e))))
# add_premise:  []
# hypothesis:  A player is running with the ball
# hypothesis fol:  exists x.(player(x) & exists e.(run(e) & argu1(e,x) & exists z2482.(ball(z2482) & with(e,z2482)) & True(e)))
#
#
# 109 gold label:  yes    result:  unknown
# premise:  Two groups of people are playing football
# premise fol:  exists x.(exists z2483.(two(z2483) & argu1(x,z2483) & group(x)) & exists z2484.(people(z2484) & of(x,z2484) & exists z2485.(football(z2485) & exists e.(play(e) & argu1(e,x) & argu2(e,z2485) & True(e)))))
# add_premise:  ['all x.(play(x) -> compete(x))']
# hypothesis:  Two teams are competing in a football match
# hypothesis fol:  exists x.(exists z2486.(two(z2486) & argu1(x,z2486) & team(x)) & exists e.(compete(e) & argu1(e,x) & exists z2488.(exists z2487.(football(z2487) & argu1(z2488,z2487) & match(z2488)) & in(e,z2488)) & True(e)))
#
#
# 110 gold label:  unknown    result:  unknown
# premise:  Two teams are competing in a football match
# premise fol:  exists x.(exists z2489.(two(z2489) & argu1(x,z2489) & team(x)) & exists e.(compete(e) & argu1(e,x) & exists z2491.(exists z2490.(football(z2490) & argu1(z2491,z2490) & match(z2491)) & in(e,z2491)) & True(e)))
# add_premise:  []
# hypothesis:  Two teams are competing in a baseball game
# hypothesis fol:  exists x.(exists z2492.(two(z2492) & argu1(x,z2492) & team(x)) & exists e.(compete(e) & argu1(e,x) & exists z2494.(exists z2493.(baseball(z2493) & argu1(z2494,z2493) & game(z2494)) & in(e,z2494)) & True(e)))
#
#
# 111 gold label:  yes    result:  unknown
# premise:  Two teams are competing in a football match
# premise fol:  exists x.(exists z2495.(two(z2495) & argu1(x,z2495) & team(x)) & exists e.(compete(e) & argu1(e,x) & exists z2497.(exists z2496.(football(z2496) & argu1(z2497,z2496) & match(z2497)) & in(e,z2497)) & True(e)))
# add_premise:  ['all x.(match(x) -> play(x))', 'all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  Football is being played by two competing teams
# hypothesis fol:  exists x.(football(x) & exists z2500.(play(z2500) & patient(z2500,x) & exists z2499.(exists z2498.(two(z2498) & argu1(z2499,z2498) & exists z2498.(compete(z2498) & argu1(z2499,z2498) & team(z2499))) & by(z2500,z2499) & True(z2500))))
#
#
# 114 gold label:  unknown    result:  unknown
# premise:  A player is running with the ball
# premise fol:  exists x.(player(x) & exists e.(run(e) & argu1(e,x) & exists z2501.(ball(z2501) & with(e,z2501)) & True(e)))
# add_premise:  ['all x.(run(x) -> play(x))', 'all x.(run(x) <-> play(x))', 'all x.(run(x) -> compete(x))', 'all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  Football is being played by two competing teams
# hypothesis fol:  exists x.(football(x) & exists z2504.(play(z2504) & patient(z2504,x) & exists z2503.(exists z2502.(two(z2502) & argu1(z2503,z2502) & exists z2502.(compete(z2502) & argu1(z2503,z2502) & team(z2503))) & by(z2504,z2503) & True(z2504))))
#
#
# 115 gold label:  unknown    result:  unknown
# premise:  Two teams are competing in a football match
# premise fol:  exists x.(exists z2505.(two(z2505) & argu1(x,z2505) & team(x)) & exists e.(compete(e) & argu1(e,x) & exists z2507.(exists z2506.(football(z2506) & argu1(z2507,z2506) & match(z2507)) & in(e,z2507)) & True(e)))
# add_premise:  ['all x.(match(x) -> play(x))']
# hypothesis:  A man who is playing is running with the ball in his hands
# hypothesis fol:  exists z2510.(man(z2510) & exists z2509.(play(z2509) & argu1(z2509,z2510) & x) & exists z2513.(run(z2513) & argu1(z2513,z2510) & exists z2511.(ball(z2511) & with(z2513,z2511) & exists z2512.(male(z2512) & exists y.(user(y,z2512) & hand(y) & in(z2513,y) & True(z2513))))))
#
#
# 144 gold label:  unknown    result:  unknown
# premise:  A group of friends are riding the current in a raft
# premise fol:  exists x.(group(x) & exists z2571.(friend(z2571) & of(x,z2571) & exists z2572.(current(z2572) & exists e.(ride(e) & argu1(e,x) & argu2(e,z2572) & exists z2572.(raft(z2572) & in(e,z2572) & True(e))))))
# add_premise:  ['all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  Preservers are being worn by a group of people who are practicing water safety
# hypothesis fol:  exists z2578.(preservers(z2578) & exists z2577.(wear(z2577) & patient(z2577,z2578) & exists z2576.(group(z2576) & exists z2575.(people(z2575) & exists z2574.(exists z2573.(water(z2573) & argu1(z2574,z2573) & safety(z2574)) & exists e.(practice(e) & argu1(e,z2575) & argu2(e,z2574) & x)) & of(z2576,z2575) & by(z2577,z2576) & True(z2577)))))
#
#
# 149 gold label:  yes    result:  unknown
# premise:  A deer is jumping over a fence
# premise fol:  exists x.(deer(x) & exists z2585.(jump(z2585) & argu1(z2585,x) & exists z2584.(fence(z2584) & over(z2585,z2584) & True(z2585))))
# add_premise:  []
# hypothesis:  A deer is jumping over the enclosure
# hypothesis fol:  exists x.(deer(x) & exists z2587.(jump(z2587) & argu1(z2587,x) & exists z2586.(enclosure(z2586) & over(z2587,z2586) & True(z2587))))
#
#
# 151 gold label:  yes    result:  yes
# premise:  A wild deer is jumping a fence
# premise fol:  exists x.(exists z2588.(wild(z2588) & argu1(x,z2588) & deer(x)) & exists z2589.(fence(z2589) & exists e.(jump(e) & argu1(e,x) & argu2(e,z2589) & True(e))))
# add_premise:  []
# hypothesis:  A deer is jumping a fence
# hypothesis fol:  exists x.(deer(x) & exists z2590.(fence(z2590) & exists e.(jump(e) & argu1(e,x) & argu2(e,z2590) & True(e))))
#
#
# 153 gold label:  yes    result:  unknown
# premise:  A wild deer is jumping a fence
# premise fol:  exists x.(exists z2593.(wild(z2593) & argu1(x,z2593) & deer(x)) & exists z2594.(fence(z2594) & exists e.(jump(e) & argu1(e,x) & argu2(e,z2594) & True(e))))
# add_premise:  []
# hypothesis:  A deer is jumping over a fence
# hypothesis fol:  exists x.(deer(x) & exists z2596.(jump(z2596) & argu1(z2596,x) & exists z2595.(fence(z2595) & over(z2596,z2595) & True(z2596))))
#
#
# 155 gold label:  unknown    result:  unknown
# premise:  A deer is jumping over the enclosure
# premise fol:  exists x.(deer(x) & exists z2599.(jump(z2599) & argu1(z2599,x) & exists z2598.(enclosure(z2598) & over(z2599,z2598) & True(z2599))))
# add_premise:  []
# hypothesis:  A deer is jumping a fence
# hypothesis fol:  exists x.(deer(x) & exists z2600.(fence(z2600) & exists e.(jump(e) & argu1(e,x) & argu2(e,z2600) & True(e))))
#
#
# 156 gold label:  no    result:  unknown
# premise:  A deer is jumping a fence
# premise fol:  exists x.(deer(x) & exists z2601.(fence(z2601) & exists e.(jump(e) & argu1(e,x) & argu2(e,z2601) & True(e))))
# add_premise:  []
# hypothesis:  A deer is not jumping over the fence
# hypothesis fol:  exists x.(deer(x) & -exists z2603.(jump(z2603) & argu1(z2603,x) & exists z2602.(fence(z2602) & over(z2603,z2602) & True(z2603))))
#
#
# 157 gold label:  yes    result:  unknown
# premise:  A deer is jumping over a fence
# premise fol:  exists x.(deer(x) & exists z2605.(jump(z2605) & argu1(z2605,x) & exists z2604.(fence(z2604) & over(z2605,z2604) & True(z2605))))
# add_premise:  []
# hypothesis:  A deer is jumping a fence
# hypothesis fol:  exists x.(deer(x) & exists z2606.(fence(z2606) & exists e.(jump(e) & argu1(e,x) & argu2(e,z2606) & True(e))))
#
#
# 167 gold label:  yes    result:  yes
# premise:  A boy is hitting a baseball
# premise fol:  exists x.(boy(x) & exists z2624.(baseball(z2624) & exists e.(hit(e) & argu1(e,x) & argu2(e,z2624) & True(e))))
# add_premise:  ['all x.(boy(x) -> child(x))']
# hypothesis:  A child is hitting a baseball
# hypothesis fol:  exists x.(child(x) & exists z2625.(baseball(z2625) & exists e.(hit(e) & argu1(e,x) & argu2(e,z2625) & True(e))))
#
#
# 168 gold label:  no    result:  unknown
# premise:  A child is hitting a baseball
# premise fol:  exists x.(child(x) & exists z2626.(baseball(z2626) & exists e.(hit(e) & argu1(e,x) & argu2(e,z2626) & True(e))))
# add_premise:  ['all x.(hit(x) -> -miss(x))', 'all x.(miss(x) -> -hit(x))']
# hypothesis:  A child is missing a baseball
# hypothesis fol:  exists x.(child(x) & exists z2627.(baseball(z2627) & exists e.(miss(e) & argu1(e,x) & argu2(e,z2627) & True(e))))
#
#
# 169 gold label:  yes    result:  unknown
# premise:  A family is watching a little boy who is hitting a baseball
# premise fol:  exists z2631.(family(z2631) & exists z2630.(exists z2628.(little(z2628) & argu1(z2630,z2628) & boy(z2630)) & exists z2629.(baseball(z2629) & exists e.(hit(e) & argu1(e,z2630) & argu2(e,z2629) & x)) & exists e.(watch(e) & argu1(e,z2631) & argu2(e,z2630) & True(e))))
# add_premise:  []
# hypothesis:  A family is watching a boy who is hitting a baseball
# hypothesis fol:  exists z2634.(family(z2634) & exists z2633.(boy(z2633) & exists z2632.(baseball(z2632) & exists e.(hit(e) & argu1(e,z2633) & argu2(e,z2632) & x)) & exists e.(watch(e) & argu1(e,z2634) & argu2(e,z2633) & True(e))))
#
#
# 172 gold label:  yes    result:  unknown
# premise:  A family is watching a boy who is hitting a baseball
# premise fol:  exists z2639.(family(z2639) & exists z2638.(boy(z2638) & exists z2637.(baseball(z2637) & exists e.(hit(e) & argu1(e,z2638) & argu2(e,z2637) & x)) & exists e.(watch(e) & argu1(e,z2639) & argu2(e,z2638) & True(e))))
# add_premise:  ['all x.(boy(x) -> child(x))']
# hypothesis:  A child is hitting a baseball
# hypothesis fol:  exists x.(child(x) & exists z2640.(baseball(z2640) & exists e.(hit(e) & argu1(e,x) & argu2(e,z2640) & True(e))))
#
#
# 175 gold label:  yes    result:  unknown
# premise:  A family is watching a little boy who is hitting a baseball
# premise fol:  exists z2646.(family(z2646) & exists z2645.(exists z2643.(little(z2643) & argu1(z2645,z2643) & boy(z2645)) & exists z2644.(baseball(z2644) & exists e.(hit(e) & argu1(e,z2645) & argu2(e,z2644) & x)) & exists e.(watch(e) & argu1(e,z2646) & argu2(e,z2645) & True(e))))
# add_premise:  []
# hypothesis:  A boy is hitting a baseball
# hypothesis fol:  exists x.(boy(x) & exists z2647.(baseball(z2647) & exists e.(hit(e) & argu1(e,x) & argu2(e,z2647) & True(e))))
#
#
# 177 gold label:  yes    result:  unknown
# premise:  A family is watching a little boy who is hitting a baseball
# premise fol:  exists z2651.(family(z2651) & exists z2650.(exists z2648.(little(z2648) & argu1(z2650,z2648) & boy(z2650)) & exists z2649.(baseball(z2649) & exists e.(hit(e) & argu1(e,z2650) & argu2(e,z2649) & x)) & exists e.(watch(e) & argu1(e,z2651) & argu2(e,z2650) & True(e))))
# add_premise:  ['all x.(boy(x) -> child(x))']
# hypothesis:  A child is hitting a baseball
# hypothesis fol:  exists x.(child(x) & exists z2652.(baseball(z2652) & exists e.(hit(e) & argu1(e,x) & argu2(e,z2652) & True(e))))
#
#
# 178 gold label:  yes    result:  unknown
# premise:  A large group of Asian people is eating at a restaurant
# premise fol:  exists x.(exists z2653.(large(z2653) & argu1(x,z2653) & group(x)) & exists z2655.(exists z2654.(asian(z2654) & argu1(z2655,z2654) & people(z2655)) & of(x,z2655) & exists e.(eat(e) & argu1(e,x) & exists z2656.(restaurant(z2656) & at(e,z2656)) & True(e))))
# add_premise:  []
# hypothesis:  A group of people from Asia is eating at a restaurant
# hypothesis fol:  exists x.(group(x) & exists z2658.(people(z2658) & exists z2657.(asia(z2657) & from(z2658,z2657) & of(x,z2658) & exists e.(eat(e) & argu1(e,x) & exists z2659.(restaurant(z2659) & at(e,z2659)) & True(e)))))
#
#
# 179 gold label:  unknown    result:  unknown
# premise:  A large group of Asian people is eating at a restaurant
# premise fol:  exists x.(exists z2660.(large(z2660) & argu1(x,z2660) & group(x)) & exists z2662.(exists z2661.(asian(z2661) & argu1(z2662,z2661) & people(z2662)) & of(x,z2662) & exists e.(eat(e) & argu1(e,x) & exists z2663.(restaurant(z2663) & at(e,z2663)) & True(e))))
# add_premise:  []
# hypothesis:  A small group of people is waiting to eat in a restaurant
# hypothesis fol:  exists x.(exists z2664.(small(z2664) & argu1(x,z2664) & group(x)) & exists z2665.(people(z2665) & of(x,z2665) & exists z2667.(eat(z2667) & argu1(z2667,x) & exists z2666.(restaurant(z2666) & in(z2667,z2666) & True(z2667)))))
#
#
# 180 gold label:  unknown    result:  unknown
# premise:  A large group of Asian people is eating at a restaurant
# premise fol:  exists x.(exists z2668.(large(z2668) & argu1(x,z2668) & group(x)) & exists z2670.(exists z2669.(asian(z2669) & argu1(z2670,z2669) & people(z2670)) & of(x,z2670) & exists e.(eat(e) & argu1(e,x) & exists z2671.(restaurant(z2671) & at(e,z2671)) & True(e))))
# add_premise:  []
# hypothesis:  A group of people in a large Asian restaurant is eating
# hypothesis fol:  exists x.(group(x) & exists z2674.(people(z2674) & exists z2673.(exists z2672.(large(z2672) & argu1(z2673,z2672) & exists z2672.(asian(z2672) & argu1(z2673,z2672) & restaurant(z2673))) & in(z2674,z2673) & of(x,z2674) & exists z2676.(eat(z2676) & argu1(z2676,x) & True(z2676)))))
#
#
# 181 gold label:  yes    result:  unknown
# premise:  Various people are eating at red tables in a crowded restaurant with purple lights
# premise fol:  exists x.(exists z2677.(various(z2677) & argu1(x,z2677) & people(x)) & exists e.(eat(e) & argu1(e,x) & exists z2683.(exists z2678.(red(z2678) & argu1(z2683,z2678) & table(z2683)) & exists z2682.(exists z2679.(crowded(z2679) & argu1(z2682,z2679) & restaurant(z2682)) & exists z2681.(exists z2680.(purple(z2680) & argu1(z2681,z2680) & light(z2681)) & with(z2682,z2681) & in(z2683,z2682) & at(e,z2683)))) & True(e)))
# add_premise:  []
# hypothesis:  Various customers are eating in a crowded restaurant with purple lights
# hypothesis fol:  exists x.(exists z2684.(various(z2684) & argu1(x,z2684) & customer(x)) & exists z2689.(eat(z2689) & argu1(z2689,x) & exists z2688.(exists z2685.(crowded(z2685) & argu1(z2688,z2685) & restaurant(z2688)) & exists z2687.(exists z2686.(purple(z2686) & argu1(z2687,z2686) & light(z2687)) & with(z2688,z2687) & in(z2689,z2688) & True(z2689)))))
#
#
# 182 gold label:  unknown    result:  unknown
# premise:  Few people are eating at red tables in a restaurant without lights
# premise fol:  exists x.(exists z2690.(few(z2690) & argu1(x,z2690) & people(x)) & exists e.(eat(e) & argu1(e,x) & exists z2694.(exists z2691.(red(z2691) & argu1(z2694,z2691) & table(z2694)) & exists z2693.(restaurant(z2693) & exists z2692.(light(z2692) & without(z2693,z2692) & in(z2694,z2693) & at(e,z2694)))) & True(e)))
# add_premise:  []
# hypothesis:  Various people are eating at red tables in a crowded restaurant with purple lights
# hypothesis fol:  exists x.(exists z2695.(various(z2695) & argu1(x,z2695) & people(x)) & exists e.(eat(e) & argu1(e,x) & exists z2701.(exists z2696.(red(z2696) & argu1(z2701,z2696) & table(z2701)) & exists z2700.(exists z2697.(crowded(z2697) & argu1(z2700,z2697) & restaurant(z2700)) & exists z2699.(exists z2698.(purple(z2698) & argu1(z2699,z2698) & light(z2699)) & with(z2700,z2699) & in(z2701,z2700) & at(e,z2701)))) & True(e)))
#
#
# 187 gold label:  unknown    result:  unknown
# premise:  A group of people from Asia is eating at a restaurant
# premise fol:  exists x.(group(x) & exists z2703.(people(z2703) & exists z2702.(asia(z2702) & from(z2703,z2702) & of(x,z2703) & exists e.(eat(e) & argu1(e,x) & exists z2704.(restaurant(z2704) & at(e,z2704)) & True(e)))))
# add_premise:  []
# hypothesis:  Various people are eating at red tables in a crowded restaurant with purple lights
# hypothesis fol:  exists x.(exists z2705.(various(z2705) & argu1(x,z2705) & people(x)) & exists e.(eat(e) & argu1(e,x) & exists z2711.(exists z2706.(red(z2706) & argu1(z2711,z2706) & table(z2711)) & exists z2710.(exists z2707.(crowded(z2707) & argu1(z2710,z2707) & restaurant(z2710)) & exists z2709.(exists z2708.(purple(z2708) & argu1(z2709,z2708) & light(z2709)) & with(z2710,z2709) & in(z2711,z2710) & at(e,z2711)))) & True(e)))
#
#
# 189 gold label:  unknown    result:  unknown
# premise:  A group of people in a large Asian restaurant is eating
# premise fol:  exists x.(group(x) & exists z2714.(people(z2714) & exists z2713.(exists z2712.(large(z2712) & argu1(z2713,z2712) & exists z2712.(asian(z2712) & argu1(z2713,z2712) & restaurant(z2713))) & in(z2714,z2713) & of(x,z2714) & exists z2716.(eat(z2716) & argu1(z2716,x) & True(z2716)))))
# add_premise:  []
# hypothesis:  Various people are eating at red tables in a crowded restaurant with purple lights
# hypothesis fol:  exists x.(exists z2717.(various(z2717) & argu1(x,z2717) & people(x)) & exists e.(eat(e) & argu1(e,x) & exists z2723.(exists z2718.(red(z2718) & argu1(z2723,z2718) & table(z2723)) & exists z2722.(exists z2719.(crowded(z2719) & argu1(z2722,z2719) & restaurant(z2722)) & exists z2721.(exists z2720.(purple(z2720) & argu1(z2721,z2720) & light(z2721)) & with(z2722,z2721) & in(z2723,z2722) & at(e,z2723)))) & True(e)))
#
#
# 190 gold label:  unknown    result:  unknown
# premise:  A large group of Asian people is eating at a restaurant
# premise fol:  exists x.(exists z2724.(large(z2724) & argu1(x,z2724) & group(x)) & exists z2726.(exists z2725.(asian(z2725) & argu1(z2726,z2725) & people(z2726)) & of(x,z2726) & exists e.(eat(e) & argu1(e,x) & exists z2727.(restaurant(z2727) & at(e,z2727)) & True(e))))
# add_premise:  []
# hypothesis:  Various people are eating at red tables in a crowded restaurant with purple lights
# hypothesis fol:  exists x.(exists z2728.(various(z2728) & argu1(x,z2728) & people(x)) & exists e.(eat(e) & argu1(e,x) & exists z2734.(exists z2729.(red(z2729) & argu1(z2734,z2729) & table(z2734)) & exists z2733.(exists z2730.(crowded(z2730) & argu1(z2733,z2730) & restaurant(z2733)) & exists z2732.(exists z2731.(purple(z2731) & argu1(z2732,z2731) & light(z2732)) & with(z2733,z2732) & in(z2734,z2733) & at(e,z2734)))) & True(e)))
#
#
# 203 gold label:  unknown    result:  unknown
# premise:  A motorcyclist with a red helmet is riding a blue motorcycle down the road
# premise fol:  exists x.(motorcyclist(x) & exists z2740.(exists z2739.(red(z2739) & argu1(z2740,z2739) & helmet(z2740)) & with(x,z2740) & exists z2742.(exists z2741.(blue(z2741) & argu1(z2742,z2741) & motorcycle(z2742)) & exists e.(ride(e) & argu1(e,x) & argu2(e,z2742) & exists z2742.(road(z2742) & down(e,z2742) & True(e))))))
# add_premise:  []
# hypothesis:  A motorcyclist without a helmet is waiting on a blue motorcycle near the road
# hypothesis fol:  exists x.(motorcyclist(x) & exists z2743.(helmet(z2743) & without(x,z2743) & exists e.(wait(e) & argu1(e,x) & exists z2746.(exists z2744.(blue(z2744) & argu1(z2746,z2744) & motorcycle(z2746)) & exists z2745.(road(z2745) & near(z2746,z2745) & on(e,z2746))) & True(e))))
#
#
# 204 gold label:  yes    result:  unknown
# premise:  A man with a helmet painted red is riding a blue motorcycle down the road
# premise fol:  exists x.(man(x) & exists z2748.(exists z2747.(helmet(z2747) & argu1(z2748,z2747) & exists z2747.(paint(z2747) & argu1(z2748,z2747) & red(z2748))) & with(x,z2748) & exists z2750.(exists z2749.(blue(z2749) & argu1(z2750,z2749) & motorcycle(z2750)) & exists e.(ride(e) & argu1(e,x) & argu2(e,z2750) & exists z2750.(road(z2750) & down(e,z2750) & True(e))))))
# add_premise:  ['all x.(motorcycle(x) <-> motorbike(x))']
# hypothesis:  A motorcyclist is riding a motorbike along a roadway
# hypothesis fol:  exists x.(motorcyclist(x) & exists z2751.(motorbike(z2751) & exists e.(ride(e) & argu1(e,x) & argu2(e,z2751) & exists z2751.(roadway(z2751) & along(e,z2751) & True(e)))))
#
#
# 208 gold label:  yes    result:  unknown
# premise:  A motorcyclist with a red helmet is riding a blue motorcycle down the road
# premise fol:  exists x.(motorcyclist(x) & exists z2758.(exists z2757.(red(z2757) & argu1(z2758,z2757) & helmet(z2758)) & with(x,z2758) & exists z2760.(exists z2759.(blue(z2759) & argu1(z2760,z2759) & motorcycle(z2760)) & exists e.(ride(e) & argu1(e,x) & argu2(e,z2760) & exists z2760.(road(z2760) & down(e,z2760) & True(e))))))
# add_premise:  ['all x.(motorcycle(x) <-> motorbike(x))']
# hypothesis:  A motorcyclist is riding a motorbike along a roadway
# hypothesis fol:  exists x.(motorcyclist(x) & exists z2761.(motorbike(z2761) & exists e.(ride(e) & argu1(e,x) & argu2(e,z2761) & exists z2761.(roadway(z2761) & along(e,z2761) & True(e)))))
#
#
# 209 gold label:  yes    result:  unknown
# premise:  A dog is catching a stick in the air and another is watching
# premise fol:  (exists x.(dog(x) & exists z2763.(stick(z2763) & exists z2762.(air(z2762) & in(z2763,z2762) & exists e.(catch(e) & argu1(e,x) & argu2(e,z2763) & True(e))))) & \Q.exists x.(exists z2765.(watch(z2765) & argu1(z2765,x) & True(z2765)) & all y.(exists x.(watch(x) & argu1(x,y) & True(x)) -> -(x = y)) & Q(x)))
# add_premise:  []
# hypothesis:  A dog is leaping high in the air and another is watching
# hypothesis fol:  (exists x.(dog(x) & exists z2768.(leap(z2768) & argu1(z2768,x) & exists s.(high(s) & argu1(z2768,s) & exists z2767.(air(z2767) & in(z2768,z2767) & True(z2768))))) & \Q.exists x.(exists z2770.(watch(z2770) & argu1(z2770,x) & True(z2770)) & all y.(exists x.(watch(x) & argu1(x,y) & True(x)) -> -(x = y)) & Q(x)))
#
#
# 212 gold label:  unknown    result:  unknown
# premise:  Two dogs are playing by a tree
# premise fol:  exists x.(exists z2773.(two(z2773) & argu1(x,z2773) & dog(x)) & exists z2775.(play(z2775) & argu1(z2775,x) & exists z2774.(tree(z2774) & by(z2775,z2774) & True(z2775))))
# add_premise:  []
# hypothesis:  Two dogs are sleeping by a tree
# hypothesis fol:  exists x.(exists z2776.(two(z2776) & argu1(x,z2776) & dog(x)) & exists z2778.(sleep(z2778) & argu1(z2778,x) & exists z2777.(tree(z2777) & by(z2778,z2777) & True(z2778))))
#
#
# 213 gold label:  unknown    result:  unknown
# premise:  A dog is leaping high in the air and another is watching
# premise fol:  (exists x.(dog(x) & exists z2781.(leap(z2781) & argu1(z2781,x) & exists s.(high(s) & argu1(z2781,s) & exists z2780.(air(z2780) & in(z2781,z2780) & True(z2781))))) & \Q.exists x.(exists z2783.(watch(z2783) & argu1(z2783,x) & True(z2783)) & all y.(exists x.(watch(x) & argu1(x,y) & True(x)) -> -(x = y)) & Q(x)))
# add_premise:  []
# hypothesis:  Two dogs are playing by a plant
# hypothesis fol:  exists x.(exists z2784.(two(z2784) & argu1(x,z2784) & dog(x)) & exists z2786.(play(z2786) & argu1(z2786,x) & exists z2785.(plant(z2785) & by(z2786,z2785) & True(z2786))))
#
#
# 214 gold label:  unknown    result:  unknown
# premise:  A dog is leaping high in the air and another is watching
# premise fol:  (exists x.(dog(x) & exists z2789.(leap(z2789) & argu1(z2789,x) & exists s.(high(s) & argu1(z2789,s) & exists z2788.(air(z2788) & in(z2789,z2788) & True(z2789))))) & \Q.exists x.(exists z2791.(watch(z2791) & argu1(z2791,x) & True(z2791)) & all y.(exists x.(watch(x) & argu1(x,y) & True(x)) -> -(x = y)) & Q(x)))
# add_premise:  []
# hypothesis:  Two dogs are sleeping by a tree
# hypothesis fol:  exists x.(exists z2792.(two(z2792) & argu1(x,z2792) & dog(x)) & exists z2794.(sleep(z2794) & argu1(z2794,x) & exists z2793.(tree(z2793) & by(z2794,z2793) & True(z2794))))
#
#
# 220 gold label:  unknown    result:  unknown
# premise:  The dancer is dancing in front of the sound equipment
# premise fol:  exists x.(dancer(x) & exists z2798.(dance(z2798) & argu1(z2798,x) & exists z2797.(front(z2797) & exists z2796.(exists z2795.(sound(z2795) & argu1(z2796,z2795) & equipment(z2796)) & of(z2797,z2796) & in(z2798,z2797) & True(z2798)))))
# add_premise:  []
# hypothesis:  The blond girl is dancing in front of the sound equipment
# hypothesis fol:  exists x.(exists z2799.(blond(z2799) & argu1(x,z2799) & girl(x)) & exists z2803.(dance(z2803) & argu1(z2803,x) & exists z2802.(front(z2802) & exists z2801.(exists z2800.(sound(z2800) & argu1(z2801,z2800) & equipment(z2801)) & of(z2802,z2801) & in(z2803,z2802) & True(z2803)))))
#
#
# 221 gold label:  unknown    result:  unknown
# premise:  The blond girl is dancing behind the sound equipment
# premise fol:  exists x.(exists z2804.(blond(z2804) & argu1(x,z2804) & girl(x)) & exists z2807.(dance(z2807) & argu1(z2807,x) & exists z2806.(exists z2805.(sound(z2805) & argu1(z2806,z2805) & equipment(z2806)) & behind(z2807,z2806) & True(z2807))))
# add_premise:  []
# hypothesis:  The blond girl is dancing in front of the sound equipment
# hypothesis fol:  exists x.(exists z2808.(blond(z2808) & argu1(x,z2808) & girl(x)) & exists z2812.(dance(z2812) & argu1(z2812,x) & exists z2811.(front(z2811) & exists z2810.(exists z2809.(sound(z2809) & argu1(z2810,z2809) & equipment(z2810)) & of(z2811,z2810) & in(z2812,z2811) & True(z2812)))))
#
#
# 222 gold label:  yes    result:  unknown
# premise:  The blond girl is dancing in front of the sound equipment
# premise fol:  exists x.(exists z2813.(blond(z2813) & argu1(x,z2813) & girl(x)) & exists z2817.(dance(z2817) & argu1(z2817,x) & exists z2816.(front(z2816) & exists z2815.(exists z2814.(sound(z2814) & argu1(z2815,z2814) & equipment(z2815)) & of(z2816,z2815) & in(z2817,z2816) & True(z2817)))))
# add_premise:  ['all x.(dance(x) <-> dancing(x))']
# hypothesis:  The equipment in front of the blond dancing girl is sound
# hypothesis fol:  exists x.(equipment(x) & exists z2820.(front(z2820) & exists z2819.(exists z2818.(blond(z2818) & argu1(z2819,z2818) & exists z2818.(dancing(z2818) & argu1(z2819,z2818) & girl(z2819))) & of(z2820,z2819) & in(x,z2820) & exists z2822.(sound(z2822) & argu1(z2822,x) & True(z2822)))))
#
#
# 231 gold label:  yes    result:  yes
# premise:  Three Asian kids are dancing and a serious man is looking
# premise fol:  (exists x.(exists z2831.(three(z2831) & argu1(x,z2831) & exists z2831.(asian(z2831) & argu1(x,z2831) & kid(x))) & exists z2833.(dance(z2833) & argu1(z2833,x) & True(z2833))) & exists x.(exists z2834.(serious(z2834) & argu1(x,z2834) & man(x)) & exists z2836.(look(z2836) & argu1(z2836,x) & True(z2836))))
# add_premise:  []
# hypothesis:  Three Asian kids are dancing and a man is looking
# hypothesis fol:  (exists x.(exists z2837.(three(z2837) & argu1(x,z2837) & exists z2837.(asian(z2837) & argu1(x,z2837) & kid(x))) & exists z2839.(dance(z2839) & argu1(z2839,x) & True(z2839))) & exists x.(man(x) & exists z2841.(look(z2841) & argu1(z2841,x) & True(z2841))))
#
#
# 242 gold label:  unknown    result:  unknown
# premise:  A woman is wearing an Egyptian headdress
# premise fol:  exists x.(woman(x) & exists z2856.(exists z2855.(egyptian(z2855) & argu1(z2856,z2855) & headdress(z2856)) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2856) & True(e))))
# add_premise:  []
# hypothesis:  An Egyptian is wearing a woman \'s headdress
# hypothesis fol:  exists x.(egyptian(x) & exists z2858.(woman(z2858) & exists z2857.(argu1(z2857,z2858) & headdress(z2857) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2857) & True(e)))))
#
#
# 243 gold label:  unknown    result:  unknown
# premise:  The woman is wearing glasses and a black headdress
# premise fol:  exists x.(woman(x) & exists z2860.(glass(z2860) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2860) & True(e))) & exists z2861.(exists z2859.(black(z2859) & argu1(z2861,z2859) & headdress(z2861)) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2861) & True(e))))
# add_premise:  []
# hypothesis:  The woman with a black hat is wearing sunglasses
# hypothesis fol:  exists x.(woman(x) & exists z2863.(exists z2862.(black(z2862) & argu1(z2863,z2862) & hat(z2863)) & with(x,z2863) & exists z2864.(sunglass(z2864) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2864) & True(e)))))
#
#
# 245 gold label:  unknown    result:  unknown
# premise:  The black woman is wearing glasses over the headdress
# premise fol:  exists x.(exists z2865.(black(z2865) & argu1(x,z2865) & woman(x)) & exists z2866.(glass(z2866) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2866) & exists z2866.(headdress(z2866) & over(e,z2866) & True(e)))))
# add_premise:  []
# hypothesis:  The woman is wearing glasses and a black headdress
# hypothesis fol:  exists x.(woman(x) & exists z2868.(glass(z2868) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2868) & True(e))) & exists z2869.(exists z2867.(black(z2867) & argu1(z2869,z2867) & headdress(z2869)) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2869) & True(e))))
#
#
# 246 gold label:  unknown    result:  unknown
# premise:  A woman is wearing an Egyptian headdress
# premise fol:  exists x.(woman(x) & exists z2871.(exists z2870.(egyptian(z2870) & argu1(z2871,z2870) & headdress(z2871)) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2871) & True(e))))
# add_premise:  []
# hypothesis:  The woman with a black hat is wearing sunglasses
# hypothesis fol:  exists x.(woman(x) & exists z2873.(exists z2872.(black(z2872) & argu1(z2873,z2872) & hat(z2873)) & with(x,z2873) & exists z2874.(sunglass(z2874) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2874) & True(e)))))
#
#
# 250 gold label:  unknown    result:  unknown
# premise:  A woman is wearing an Indian headdress
# premise fol:  exists x.(woman(x) & exists z2876.(exists z2875.(indian(z2875) & argu1(z2876,z2875) & headdress(z2876)) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2876) & True(e))))
# add_premise:  []
# hypothesis:  The woman is wearing glasses and a black headdress
# hypothesis fol:  exists x.(woman(x) & exists z2878.(glass(z2878) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2878) & True(e))) & exists z2879.(exists z2877.(black(z2877) & argu1(z2879,z2877) & headdress(z2879)) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2879) & True(e))))
#
#
# 251 gold label:  unknown    result:  unknown
# premise:  The woman is wearing glasses and a black headdress
# premise fol:  exists x.(woman(x) & exists z2881.(glass(z2881) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2881) & True(e))) & exists z2882.(exists z2880.(black(z2880) & argu1(z2882,z2880) & headdress(z2882)) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2882) & True(e))))
# add_premise:  []
# hypothesis:  An Egyptian is wearing a woman \'s headdress
# hypothesis fol:  exists x.(egyptian(x) & exists z2884.(woman(z2884) & exists z2883.(argu1(z2883,z2884) & headdress(z2883) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2883) & True(e)))))
#
#
# 252 gold label:  unknown    result:  unknown
# premise:  The woman is wearing glasses and a black headdress
# premise fol:  exists x.(woman(x) & exists z2886.(glass(z2886) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2886) & True(e))) & exists z2887.(exists z2885.(black(z2885) & argu1(z2887,z2885) & headdress(z2887)) & exists e.(wear(e) & argu1(e,x) & argu2(e,z2887) & True(e))))
# add_premise:  []
# hypothesis:  A woman is wearing an Egyptian headdress
# ...
# hypothesis fol:  exists x.(band(x) & exists z5067.(perform(z5067) & argu1(z5067,x) & exists z5066.(stage(z5066) & on(z5067,z5066) & True(z5067))))
#
#
# 1262 gold label:  yes    result:  unknown
# premise:  A band is performing onstage
# premise fol:  exists x.(band(x) & exists z5069.(perform(z5069) & argu1(z5069,x) & exists s.(onstage(s) & argu1(z5069,s) & True(z5069))))
# add_premise:  []
# hypothesis:  A band is playing onstage
# hypothesis fol:  exists x.(band(x) & exists z5071.(play(z5071) & argu1(z5071,x) & exists s.(onstage(s) & argu1(z5071,s) & True(z5071))))
#
#
# 1264 gold label:  yes    result:  unknown
# premise:  A band is performing onstage
# premise fol:  exists x.(band(x) & exists z5076.(perform(z5076) & argu1(z5076,x) & exists s.(onstage(s) & argu1(z5076,s) & True(z5076))))
# add_premise:  ['all x.(onstage(x) -> stage(x))']
# hypothesis:  A band is performing on a stage
# hypothesis fol:  exists x.(band(x) & exists z5078.(perform(z5078) & argu1(z5078,x) & exists z5077.(stage(z5077) & on(z5078,z5077) & True(z5078))))
#
#
# 1267 gold label:  no    result:  unknown
# premise:  A band is not performing on a stage
# premise fol:  exists x.(band(x) & -exists z5083.(perform(z5083) & argu1(z5083,x) & exists z5082.(stage(z5082) & on(z5083,z5082) & True(z5083))))
# add_premise:  ['all x.(stage(x) -> onstage(x))']
# hypothesis:  A band is playing onstage
# hypothesis fol:  exists x.(band(x) & exists z5085.(play(z5085) & argu1(z5085,x) & exists s.(onstage(s) & argu1(z5085,s) & True(z5085))))
#
#
# 1269 gold label:  unknown    result:  unknown
# premise:  A man is shaking a drink
# premise fol:  exists x.(man(x) & exists z5086.(drink(z5086) & exists e.(shake(e) & argu1(e,x) & argu2(e,z5086) & True(e))))
# add_premise:  []
# hypothesis:  A man is mixing
# hypothesis fol:  exists x.(man(x) & exists z5088.(mix(z5088) & argu1(z5088,x) & True(z5088)))
#
#
# 1272 gold label:  no    result:  no
# premise:  A man is mowing a lawn
# premise fol:  exists x.(man(x) & exists z5089.(lawn(z5089) & exists e.(mow(e) & argu1(e,x) & argu2(e,z5089) & True(e))))
# add_premise:  []
# hypothesis:  A man is not mowing a lawn
# hypothesis fol:  exists x.(man(x) & -exists z5091.(lawn(z5091) & exists e.(mow(e) & argu1(e,x) & argu2(e,z5091) & True(e))))
#
#
# 1277 gold label:  unknown    result:  unknown
# premise:  A man is mixing
# premise fol:  exists x.(man(x) & exists z5093.(mix(z5093) & argu1(z5093,x) & True(z5093)))
# add_premise:  []
# hypothesis:  A man is mowing a lawn
# hypothesis fol:  exists x.(man(x) & exists z5094.(lawn(z5094) & exists e.(mow(e) & argu1(e,x) & argu2(e,z5094) & True(e))))
#
#
# 1278 gold label:  unknown    result:  unknown
# premise:  A man is dancing
# premise fol:  exists x.(man(x) & exists z5096.(dance(z5096) & argu1(z5096,x) & True(z5096)))
# add_premise:  ['all x.(dance(x) -> move(x))']
# hypothesis:  A man is moving gracefully
# hypothesis fol:  exists x.(man(x) & exists z5098.(move(z5098) & argu1(z5098,x) & exists s.(gracefully(s) & argu1(z5098,s) & True(z5098))))
#
#
# 1279 gold label:  no    result:  unknown
# premise:  A man is sitting
# premise fol:  exists x.(man(x) & exists z5100.(sit(z5100) & argu1(z5100,x) & True(z5100)))
# add_premise:  []
# hypothesis:  A man is dancing
# hypothesis fol:  exists x.(man(x) & exists z5102.(dance(z5102) & argu1(z5102,x) & True(z5102)))
#
#
# 1285 gold label:  unknown    result:  unknown
# premise:  A man is sitting
# premise fol:  exists x.(man(x) & exists z5106.(sit(z5106) & argu1(z5106,x) & True(z5106)))
# add_premise:  []
# hypothesis:  A man is walking outside
# hypothesis fol:  exists x.(man(x) & exists z5108.(walk(z5108) & argu1(z5108,x) & exists s.(outside(s) & argu1(z5108,s) & True(z5108))))
#
#
# 1286 gold label:  unknown    result:  unknown
# premise:  A man is dancing
# premise fol:  exists x.(man(x) & exists z5110.(dance(z5110) & argu1(z5110,x) & True(z5110)))
# add_premise:  []
# hypothesis:  A man is walking outside
# hypothesis fol:  exists x.(man(x) & exists z5112.(walk(z5112) & argu1(z5112,x) & exists s.(outside(s) & argu1(z5112,s) & True(z5112))))
#
#
# 1290 gold label:  unknown    result:  unknown
# premise:  A cat is stuck on a moving ceiling fan
# premise fol:  exists x.(cat(x) & exists e.(stick(e) & argu1(e,x) & exists z5119.(exists z5118.(move(z5118) & argu1(z5119,z5118) & exists z5118.(ceiling(z5118) & argu1(z5119,z5118) & fan(z5119))) & on(e,z5119)) & True(e)))
# add_premise:  []
# hypothesis:  A cat is playing on a moving ceiling fan
# hypothesis fol:  exists x.(cat(x) & exists e.(play(e) & argu1(e,x) & exists z5121.(exists z5120.(move(z5120) & argu1(z5121,z5120) & exists z5120.(ceiling(z5120) & argu1(z5121,z5120) & fan(z5121))) & on(e,z5121)) & True(e)))
#
#
# 1295 gold label:  unknown    result:  unknown
# premise:  A cat is swinging on a fan
# premise fol:  exists x.(cat(x) & exists e.(swing(e) & argu1(e,x) & exists z5122.(fan(z5122) & on(e,z5122)) & True(e)))
# add_premise:  ['all x.(swing(x) -> move(x))']
# hypothesis:  A cat is stuck on a moving ceiling fan
# hypothesis fol:  exists x.(cat(x) & exists e.(stick(e) & argu1(e,x) & exists z5124.(exists z5123.(move(z5123) & argu1(z5124,z5123) & exists z5123.(ceiling(z5123) & argu1(z5124,z5123) & fan(z5124))) & on(e,z5124)) & True(e)))
#
#
# 1296 gold label:  yes    result:  unknown
# premise:  A man is making music with a flute
# premise fol:  exists x.(man(x) & exists z5125.(music(z5125) & exists e.(make(e) & argu1(e,z5125) & argu2(e,x) & exists z5125.(flute(z5125) & with(e,z5125)) & True(e))))
# add_premise:  ['all x.(make(x) -> play(x))']
# hypothesis:  A man is playing flute
# hypothesis fol:  exists x.(man(x) & exists z5126.(flute(z5126) & exists e.(play(e) & argu1(e,x) & argu2(e,z5126) & True(e))))
#
#
# 1298 gold label:  unknown    result:  unknown
# premise:  A man is playing baseball with a flute
# premise fol:  exists x.(man(x) & exists z5127.(baseball(z5127) & exists e.(play(e) & argu1(e,z5127) & argu2(e,x) & exists z5127.(flute(z5127) & with(e,z5127)) & True(e))))
# add_premise:  []
# hypothesis:  A man is playing flute
# hypothesis fol:  exists x.(man(x) & exists z5128.(flute(z5128) & exists e.(play(e) & argu1(e,x) & argu2(e,z5128) & True(e))))
#
#
# 1299 gold label:  yes    result:  unknown
# premise:  A man is playing soccer
# premise fol:  exists x.(man(x) & exists z5129.(soccer(z5129) & exists e.(play(e) & argu1(e,x) & argu2(e,z5129) & True(e))))
# add_premise:  ['all x.(soccer(x) -> game(x))']
# hypothesis:  A man is playing a game with a ball
# hypothesis fol:  exists x.(man(x) & exists z5130.(game(z5130) & exists e.(play(e) & argu1(e,x) & argu2(e,z5130) & exists z5130.(ball(z5130) & with(e,z5130) & True(e)))))
#
#
# 1301 gold label:  unknown    result:  unknown
# premise:  A man is playing soccer
# premise fol:  exists x.(man(x) & exists z5132.(soccer(z5132) & exists e.(play(e) & argu1(e,x) & argu2(e,z5132) & True(e))))
# add_premise:  []
# hypothesis:  A soccer man is playing piano
# hypothesis fol:  exists x.(exists z5133.(soccer(z5133) & argu1(x,z5133) & man(x)) & exists z5134.(piano(z5134) & exists e.(play(e) & argu1(e,x) & argu2(e,z5134) & True(e))))
#
#
# 1304 gold label:  unknown    result:  unknown
# premise:  A soccer man is playing piano
# premise fol:  exists x.(exists z5135.(soccer(z5135) & argu1(x,z5135) & man(x)) & exists z5136.(piano(z5136) & exists e.(play(e) & argu1(e,x) & argu2(e,z5136) & True(e))))
# add_premise:  []
# hypothesis:  A man is playing flute
# hypothesis fol:  exists x.(man(x) & exists z5137.(flute(z5137) & exists e.(play(e) & argu1(e,x) & argu2(e,z5137) & True(e))))
#
#
# 1307 gold label:  unknown    result:  unknown
# premise:  A man is playing baseball with a flute
# premise fol:  exists x.(man(x) & exists z5139.(baseball(z5139) & exists e.(play(e) & argu1(e,z5139) & argu2(e,x) & exists z5139.(flute(z5139) & with(e,z5139)) & True(e))))
# add_premise:  []
# hypothesis:  A man is playing soccer
# hypothesis fol:  exists x.(man(x) & exists z5140.(soccer(z5140) & exists e.(play(e) & argu1(e,x) & argu2(e,z5140) & True(e))))
#
#
# 1309 gold label:  yes    result:  unknown
# premise:  A man is frying a tortilla
# premise fol:  exists x.(man(x) & exists z5141.(tortilla(z5141) & exists e.(fry(e) & argu1(e,x) & argu2(e,z5141) & True(e))))
# add_premise:  ['all x.(tortilla(x) -> food(x))']
# hypothesis:  A man is frying food
# hypothesis fol:  exists x.(man(x) & exists z5142.(food(z5142) & exists e.(frying(e) & argu1(e,x) & argu2(e,z5142) & True(e))))
#
#
# 1312 gold label:  no    result:  unknown
# premise:  A person is performing a card trick
# premise fol:  exists x.(person(x) & exists z5145.(exists z5144.(card(z5144) & argu1(z5145,z5144) & trick(z5145)) & exists e.(perform(e) & argu1(e,x) & argu2(e,z5145) & True(e))))
# add_premise:  []
# hypothesis:  Nobody is performing a card trick
# hypothesis fol:  exists x.(nobody(x) & exists z5147.(exists z5146.(card(z5146) & argu1(z5147,z5146) & trick(z5147)) & exists e.(perform(e) & argu1(e,x) & argu2(e,z5147) & True(e))))
#
#
# 1313 gold label:  unknown    result:  unknown
# premise:  A person is doing a trick with some cards
# premise fol:  exists x.(person(x) & exists z5149.(trick(z5149) & exists z5148.(card(z5148) & with(z5149,z5148) & exists e.(do(e) & argu1(e,x) & argu2(e,z5149) & True(e)))))
# add_premise:  []
# hypothesis:  A man is frying a tortilla
# hypothesis fol:  exists x.(man(x) & exists z5150.(tortilla(z5150) & exists e.(fry(e) & argu1(e,x) & argu2(e,z5150) & True(e))))
#
#
# 1314 gold label:  unknown    result:  unknown
# premise:  A man is frying a tortilla
# premise fol:  exists x.(man(x) & exists z5151.(tortilla(z5151) & exists e.(fry(e) & argu1(e,x) & argu2(e,z5151) & True(e))))
# add_premise:  []
# hypothesis:  Nobody is performing a card trick
# hypothesis fol:  exists x.(nobody(x) & exists z5153.(exists z5152.(card(z5152) & argu1(z5153,z5152) & trick(z5153)) & exists e.(perform(e) & argu1(e,x) & argu2(e,z5153) & True(e))))
#
#
# 1315 gold label:  unknown    result:  unknown
# premise:  A person is performing a card trick
# premise fol:  exists x.(person(x) & exists z5155.(exists z5154.(card(z5154) & argu1(z5155,z5154) & trick(z5155)) & exists e.(perform(e) & argu1(e,x) & argu2(e,z5155) & True(e))))
# add_premise:  []
# hypothesis:  A man is frying food
# hypothesis fol:  exists x.(man(x) & exists z5156.(food(z5156) & exists e.(frying(e) & argu1(e,x) & argu2(e,z5156) & True(e))))
#
#
# 1320 gold label:  unknown    result:  unknown
# premise:  A boy is spanking a man with a plastic sword
# premise fol:  exists x.(boy(x) & exists z5162.(man(z5162) & exists z5161.(exists z5160.(plastic(z5160) & argu1(z5161,z5160) & sword(z5161)) & with(z5162,z5161) & exists e.(spank(e) & argu1(e,x) & argu2(e,z5162) & True(e)))))
# add_premise:  []
# hypothesis:  A man is spanking a boy with a plastic sword
# hypothesis fol:  exists x.(man(x) & exists z5165.(boy(z5165) & exists z5164.(exists z5163.(plastic(z5163) & argu1(z5164,z5163) & sword(z5164)) & with(z5165,z5164) & exists e.(spank(e) & argu1(e,x) & argu2(e,z5165) & True(e)))))
#
#
# 1323 gold label:  unknown    result:  yes
# premise:  A boy is whacking a man with a sword
# premise fol:  exists x.(boy(x) & exists z5168.(man(z5168) & exists e.(whack(e) & argu1(e,z5168) & argu2(e,x) & exists z5168.(sword(z5168) & with(e,z5168)) & True(e))))
# add_premise:  []
# hypothesis:  A man is whacking a boy with a sword
# hypothesis fol:  exists x.(man(x) & exists z5169.(boy(z5169) & exists e.(whack(e) & argu1(e,x) & argu2(e,z5169) & exists z5169.(sword(z5169) & with(e,z5169) & True(e)))))
#
#
# 1324 gold label:  yes    result:  unknown
# premise:  A boy is spanking a man with a plastic sword
# premise fol:  exists x.(boy(x) & exists z5172.(man(z5172) & exists z5171.(exists z5170.(plastic(z5170) & argu1(z5171,z5170) & sword(z5171)) & with(z5172,z5171) & exists e.(spank(e) & argu1(e,x) & argu2(e,z5172) & True(e)))))
# add_premise:  ['all x.(sword(x) -> weapon(x))', 'all x.(boy(x) -> kid(x))', 'all x all y (patient(x,y) <-> argu2(x,y))', 'all x all y (by(x,y) <-> argu1(x,y))']
# hypothesis:  A man is being hit by a kid with a weapon
# hypothesis fol:  exists x.(man(x) & exists z5175.(hit(z5175) & patient(z5175,x) & exists z5173.(kid(z5173) & by(z5175,z5173) & exists z5174.(weapon(z5174) & with(z5175,z5174) & True(z5175)))))
#
#
# 1327 gold label:  unknown    result:  unknown
# premise:  A boy is spanking a man with a toy weapon
# premise fol:  exists x.(boy(x) & exists z5179.(man(z5179) & exists e.(spank(e) & argu1(e,z5179) & argu2(e,x) & exists z5179.(exists z5178.(toy(z5178) & argu1(z5179,z5178) & weapon(z5179)) & with(e,z5179)) & True(e))))
# add_premise:  []
# hypothesis:  A boy is whacking a man with a sword
# hypothesis fol:  exists x.(boy(x) & exists z5180.(man(z5180) & exists e.(whack(e) & argu1(e,z5180) & argu2(e,x) & exists z5180.(sword(z5180) & with(e,z5180)) & True(e))))
#
#
# 1330 gold label:  yes    result:  unknown
# premise:  A boy is spanking a man with a plastic sword
# premise fol:  exists x.(boy(x) & exists z5183.(man(z5183) & exists z5182.(exists z5181.(plastic(z5181) & argu1(z5182,z5181) & sword(z5182)) & with(z5183,z5182) & exists e.(spank(e) & argu1(e,x) & argu2(e,z5183) & True(e)))))
# add_premise:  []
# hypothesis:  A boy is whacking a man with a sword
# hypothesis fol:  exists x.(boy(x) & exists z5184.(man(z5184) & exists e.(whack(e) & argu1(e,z5184) & argu2(e,x) & exists z5184.(sword(z5184) & with(e,z5184)) & True(e))))
#
#
# 1331 gold label:  yes    result:  unknown
# premise:  The young lady is measuring the ankle of another woman
# premise fol:  exists x.(exists z5185.(young(z5185) & argu1(x,z5185) & lady(x)) & exists z5187.(ankle(z5187) & exists z5186.(woman(z5186) & all y.(woman(y) -> -(z5186 = y)) & of(z5187,z5186) & exists e.(measure(e) & argu1(e,x) & argu2(e,z5187) & True(e)))))
# add_premise:  []
# hypothesis:  The lady is measuring the ankle of another woman
# hypothesis fol:  exists x.(lady(x) & exists z5189.(ankle(z5189) & exists z5188.(woman(z5188) & all y.(woman(y) -> -(z5188 = y)) & of(z5189,z5188) & exists e.(measure(e) & argu1(e,x) & argu2(e,z5189) & True(e)))))
#
#
# 1332 gold label:  no    result:  no
# premise:  The lady is not measuring the ankle of another woman
# premise fol:  exists x.(lady(x) & -exists z5192.(ankle(z5192) & exists z5190.(woman(z5190) & all y.(woman(y) -> -(z5190 = y)) & of(z5192,z5190) & exists e.(measure(e) & argu1(e,x) & argu2(e,z5192) & True(e)))))
# add_premise:  []
# hypothesis:  The lady is measuring the ankle of another woman
# hypothesis fol:  exists x.(lady(x) & exists z5194.(ankle(z5194) & exists z5193.(woman(z5193) & all y.(woman(y) -> -(z5193 = y)) & of(z5194,z5193) & exists e.(measure(e) & argu1(e,x) & argu2(e,z5194) & True(e)))))
#
#
# 1334 gold label:  unknown    result:  unknown
# premise:  The woman is measuring a man
# premise fol:  exists x.(woman(x) & exists z5195.(man(z5195) & exists e.(measure(e) & argu1(e,x) & argu2(e,z5195) & True(e))))
# add_premise:  []
# hypothesis:  The woman is measuring the other woman
# hypothesis fol:  exists x.(woman(x) & exists z5197.(exists z5196.(other(z5196) & argu1(z5197,z5196) & woman(z5197)) & exists e.(measure(e) & argu1(e,x) & argu2(e,z5197) & True(e))))
#
#
# 1337 gold label:  yes    result:  unknown
# premise:  The young lady is measuring the ankle of another woman
# premise fol:  exists x.(exists z5198.(young(z5198) & argu1(x,z5198) & lady(x)) & exists z5200.(ankle(z5200) & exists z5199.(woman(z5199) & all y.(woman(y) -> -(z5199 = y)) & of(z5200,z5199) & exists e.(measure(e) & argu1(e,x) & argu2(e,z5200) & True(e)))))
# add_premise:  []
# hypothesis:  The woman is measuring the other woman
# hypothesis fol:  exists x.(woman(x) & exists z5202.(exists z5201.(other(z5201) & argu1(z5202,z5201) & woman(z5202)) & exists e.(measure(e) & argu1(e,x) & argu2(e,z5202) & True(e))))
#
#
# 1338 gold label:  unknown    result:  unknown
# premise:  The woman is measuring the other woman
# premise fol:  exists x.(woman(x) & exists z5204.(exists z5203.(other(z5203) & argu1(z5204,z5203) & woman(z5204)) & exists e.(measure(e) & argu1(e,x) & argu2(e,z5204) & True(e))))
# add_premise:  []
# hypothesis:  The lady is not measuring the ankle of another woman
# hypothesis fol:  exists x.(lady(x) & -exists z5207.(ankle(z5207) & exists z5205.(woman(z5205) & all y.(woman(y) -> -(z5205 = y)) & of(z5207,z5205) & exists e.(measure(e) & argu1(e,x) & argu2(e,z5207) & True(e)))))
